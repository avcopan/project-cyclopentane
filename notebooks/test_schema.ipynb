# %%
from importlib import reload

import automech

mech = automech.from_smiles(
    rxn_smis=[
        "[OH].C>>[CH3].O",
        "CC.[OH]>>O.C[CH2]",
        "CC.[CH3]>>C.C[CH2]"
    ],
    name_dct={
        "C": "C",
        "[CH3]": "Cy",
        "CC": "C2",
        "C[CH2]": "C2y1",
        "[OH]": "OH",
    },
)
automech.display_reactions(
    mech,
    [
        "C + OH + M => H2O + Cy + M",
        "Cy + C2 = C2y1 + C",
    ],
)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# rxn_df = shape: (2, 3)
# ┌──────────────┬───────────────┬────────────┐
# │ reactants    ┆ products      ┆ formula    │
# │ ---          ┆ ---           ┆ ---        │
# │ list[str]    ┆ list[str]     ┆ struct[3]  │
# ╞══════════════╪═══════════════╪════════════╡
# │ ["OH", "C"]  ┆ ["Cy", "H2O"] ┆ {1,5,1}    │
# │ ["C2", "Cy"] ┆ ["C", "C2y1"] ┆ {3,9,null} │
# └──────────────┴───────────────┴────────────┘
# Species `name`=>`smiles` translation
#   reactants = ['[OH]', 'C']
#   products = ['[CH3]', 'O']
# ...
# Species `name`=>`smiles` translation
#   reactants = ['CC', '[CH3]']
#   products = ['C', 'C[CH2]']
# ...
