# %%
from pathlib import Path

import util
from util import p_, workflow

import automech

file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
par_mech = workflow.read_parent_mechanism(root_path=root_path)

# %%
# # Generate submechanism
# from automol.graph import enum

# from automech.species import Species

# gen_mech = automech.from_smiles(spc_smis=["C1=CCCC1"], src_mech=par_mech)
# #  - Abstractions
# gen_mech = automech.enumerate_reactions(
#     gen_mech,
#     enum.ReactionSmarts.abstraction,
#     rcts_=[None, "[OH]"],
#     spc_col_=Species.smiles,
#     src_mech=par_mech,
# )
# automech.display(gen_mech)

# %%
# # Expand stereochemistry
# ste_mech, *_, gen_mech = workflow.expand_stereo(
#     mech=gen_mech, tag=tag, root_path=root_path
# )

# %%
# # Prepare calculation
# workflow.prepare_calculation(
#     gen_mech=gen_mech, ste_mech=ste_mech, tag=tag, root_path=root_path
# )

# %%
# Gather statistics
workflow.gather_statistics(tag=tag, root_path=root_path)
# Out:
# New species and reactions:
#
# SPECIES
#
# END
#
#
# REACTIONS    CAL/MOL   MOL
#
# C5H8(522) + OH(4) = C5H7(1202) + H2O(5)              1.000      0.000      0.000
#
# END
#
#
#
# Statistics summary:
#
# shape: (5, 3)
# ┌────────────────────┬───────────────┬────────────────┐
# │ Mechanism          ┆ Species Count ┆ Reaction Count │
# │ ---                ┆ ---           ┆ ---            │
# │ str                ┆ i64           ┆ i64            │
# ╞════════════════════╪═══════════════╪════════════════╡
# │ Parent             ┆ 2534          ┆ 10002          │
# │ Generated          ┆ 6             ┆ 3              │
# │ Stereo             ┆ 6             ┆ 3              │
# │ Generated - Parent ┆ 0             ┆ 1              │
# │ Stereo - Parent    ┆ 0             ┆ 1              │
# └────────────────────┴───────────────┴────────────────┘

# %%
# Prepare simulation
workflow.prepare_simulation(tag=tag, root_path=root_path)
workflow.prepare_simulation_species(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/2034 [00:00<?, ?it/s]
# Writing mechanism to JSON...
#
# Writing mechanism to Chemkin...
# Control: ../data/chemkin/full_A_rh-oh_1e-1_v0_control.dat
# Calculated: ../data/chemkin/full_A_rh-oh_1e-1_v0_calc.dat
#
# Converting ChemKin mechanism to Cantera YAML...
# Wrote YAML mechanism file to '../data/cantera/full_A_rh-oh_1e-1_v0_control.yaml'.
# Mechanism contains 2534 species and 10002 reactions.
# Wrote YAML mechanism file to '../data/cantera/full_A_rh-oh_1e-1_v0_calc.yaml'.
# Mechanism contains 2534 species and 10003 reactions.
#
# Validating Cantera model...
#
# Reading in species...
#
# Writing simulation species names to CSV...
# ../data/cantera/A_rh-oh_1e-1_v0_species.csv
# shape: (20, 6)
# ┌────────────┬───────────────────────┬───────────┬────────────┬───────────────┬────────────┐
# │ orig_name  ┆ Experiment            ┆ Lokachari ┆ Hill       ┆ concentration ┆ name       │
# │ ---        ┆ ---                   ┆ ---       ┆ ---        ┆ ---           ┆ ---        │
# │ str        ┆ str                   ┆ str       ┆ str        ┆ str           ┆ str        │
# ╞════════════╪═══════════════════════╪═══════════╪════════════╪═══════════════╪════════════╡
# │ C5H8(522)  ┆ cyclopentene          ┆ CYC5H8    ┆ C5H8(522)  ┆ null          ┆ C5H8(522)  │
# │ C5H8O(825) ┆ 1,2-epoxycyclopentane ┆ CPTYO12   ┆ C5H8O(825) ┆ null          ┆ C5H8O(825) │
# │ CPT(563)   ┆ cyclopentane          ┆ CPT       ┆ CPT(563)   ┆ CPT_frac      ┆ CPT(563)   │
# │ O2(6)      ┆ O2                    ┆ O2        ┆ O2(6)      ┆ O2_frac       ┆ O2(6)      │
# │ N2         ┆ null                  ┆ N2        ┆ N2         ┆ N2_frac       ┆ N2         │
# │ …          ┆ …                     ┆ …         ┆ …          ┆ …             ┆ …          │
# │ C4H8(253)  ┆ 1-butene              ┆ C4H8-1    ┆ C4H8(253)  ┆ null          ┆ C4H8(253)  │
# │ C5H6(478)  ┆ cyclopentadiene       ┆ C5H6      ┆ C5H6(478)  ┆ null          ┆ C5H6(478)  │
# │ C6H6(970)  ┆ benzene               ┆ C6H6      ┆ C6H6(970)  ┆ null          ┆ C6H6(970)  │
# │ HO2(8)     ┆ null                  ┆ HO2       ┆ HO2(8)     ┆ null          ┆ HO2(8)     │
# │ OH(4)      ┆ null                  ┆ OH        ┆ OH(4)      ┆ null          ┆ OH(4)      │
# └────────────┴───────────────────────┴───────────┴────────────┴───────────────┴────────────┘

# %%
# Check rates
workflow.plot_rates(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Compare calculated mechanism to parent mechanism...
#
# *********
# Reaction: C5H8(522) + OH(4) = C5H7(500) + H2O(5)
# Translations:
#   smiles:
#     reactants = ['C1=CCCC1', '[OH]']
#     products = ['C1=CCC[CH]1', 'O']
# Rate parameters:
#   This work:
#     C5H8(522) + OH(4) = C5H7(500) + H2O(5)                       1.000      0.000      0.000
#         PLOG  /     0.1000    3128000      1.984      -2626/
#         PLOG  /      1.000    4384000      1.923      -2429/
#         PLOG  /      10.00   12160000      1.767      -1850/
#         PLOG  /      100.0   49070000      1.519     -631.0/
#   Hill:
#     C5H8(522) + OH(4) = C5H7(500) + H2O(5)                     4040000      2.200     -437.0
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)
# *********
# Reaction: C5H8(522) + OH(4) = C5H7(504) + H2O(5)
# Translations:
#   smiles:
#     reactants = ['C1=CCCC1', '[OH]']
#     products = ['C1=CC[CH]C1', 'O']
# Rate parameters:
#   This work:
#     C5H8(522) + OH(4) = C5H7(504) + H2O(5)                       1.000      0.000      0.000
#         PLOG  /     0.1000     230100      2.230      -2209/
#         PLOG  /      1.000     175300      2.246      -2178/
#         PLOG  /      10.00     502000      2.086      -1622/
#         PLOG  /      100.0    2394000      1.811     -406.0/
#   Hill:
#     C5H8(522) + OH(4) = C5H7(504) + H2O(5)                    16700000      1.779     -193.0
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)
# *********
# Reaction: C5H8(522) + OH(4) = C5H7(1202) + H2O(5)
# Translations:
#   smiles:
#     reactants = ['C1=CCCC1', '[OH]']
#     products = ['[C]1=CCCC1', 'O']
# Rate parameters:
#   This work:
#     C5H8(522) + OH(4) = C5H7(1202) + H2O(5)                      1.000      0.000      0.000
#         PLOG  /     0.1000       4541      2.742      955.0/
#         PLOG  /      1.000       4458      2.726      923.0/
#         PLOG  /      10.00      15980      2.537       1371/
#         PLOG  /      100.0     145500      2.181       2641/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)

# %%
# # Plot simulation
# chart_dct = workflow.plot_simulation(
#     tag=tag,
#     x_col="O2_molecules",
#     root_path=root_path,
#     line_source_=["Hill", "Lokachari"],
#     point_source="Experiment",
#     control=False,
# )
# mech = automech.io.read(
#     p_.full_calculated_mechanism(tag, "json", path=p_.data(root_path))
# )
# for name, chart in chart_dct.items():
#     automech.display_species(mech, [name])
#     chart.show()
