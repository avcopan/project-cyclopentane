# %%
from pathlib import Path

import util

from automech.subtasks import display, fs

tag = util.notebook_prefix()
root_path = Path("..")
calc_path = root_path / tag

# %%
for path in fs.task_paths("find_ts", "1: 1", path=calc_path):
    print(path)
# Out:
# /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save/RXN/C5H9O2/XWIANGFMAQPCGG/0/2/YFKPBYRVSA-N/C5H8.HO2/KLBQUVRPLRFCNS/0_0/1_2/UHFFFAOYSA-N/2/u-unGOU/TS/00

# %%
display("find_ts", "1: 1", path=calc_path)
# Out:
# Lowest frequency mode:
#   frequency: -589.8520386298709
# <div id="3dmolviewer_17371465700447462"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17371465700447462" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17371465700447462 = null;
# var warn = document.getElementById("3dmolwarning_17371465700447462");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17371465700447462 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17371465700447462"),{backgroundColor:"white"});
# viewer_17371465700447462.zoomTo();
# 	viewer_17371465700447462.addModel(" 16\n\nC    0.472970  -0.978024   0.871195   -0.001618   0.007822   0.002416\nC   -0.069430   0.278310   1.077538    0.056191   0.001696   0.029659\nH    0.239358  -1.856673   1.475107   -0.017451   0.020701  -0.003520\nC    0.569781   1.281885   0.143780    0.006394   0.001200   0.002597\nO   -1.835094   0.025231   0.348221   -0.033089  -0.006486  -0.018165\nH   -0.522451   0.581186   2.022931   -0.011837  -0.013925   0.004210\nC    1.629386   0.466392  -0.630814    0.000829   0.000132  -0.002107\nH    1.009499   2.123399   0.700295    0.026122   0.047682  -0.057576\nH   -0.193015   1.701439  -0.528643   -0.032019  -0.046455   0.035654\nC    1.257396  -1.012431  -0.403537   -0.001275   0.000752  -0.000819\nH    2.629389   0.656074  -0.210934    0.004651  -0.008236  -0.006232\nH    1.668994   0.732899  -1.696205    0.004111   0.003620  -0.006892\nH    2.129788  -1.683742  -0.364435   -0.003351   0.004379   0.004118\nH    0.614701  -1.386442  -1.226924   -0.003315  -0.009648   0.001917\nO   -1.772716  -0.038161  -1.012444   -0.005215  -0.001084  -0.001054\nH   -1.874398  -0.981494  -1.206375   -0.031676   0.003797  -0.060852","xyz",{"vibrate": {"frames": 10, "amplitude": 3}});
# 	viewer_17371465700447462.setStyle({"stick": {}, "sphere": {"radius": 0.3}});
# 	viewer_17371465700447462.setBackgroundColor("0xeeeeee");
# 	viewer_17371465700447462.animate({"loop": "backAndForth"});
# 	viewer_17371465700447462.zoomTo();
# viewer_17371465700447462.render();
# });
# </script>
