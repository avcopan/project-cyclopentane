# %%
from pathlib import Path

import util
from util import workflow

file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# Build
from automol.graph import enum

import automech
from automech.schema import Species

mech0 = automech.io.read(data_path / "full_raw.json")
mech = automech.from_smiles(spc_smis=["C1=CCCC1", "C12C(O2)CCC1"], src_mech=mech0)
#  - add HO2 addition to *ene*
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.pi2_addition,
    rcts_=[None, "O[O]"],
    spc_col_=Species.smiles,
    src_mech=mech0,
)
#  - add ring-forming scission
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.ring_forming_scission,
    src_mech=mech0,
)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path)
# Out:
# Finalizing build for...
# Mechanism(
#   reactions=DataFrame(
#     shape: (2, 8)
#     ┌────────────┬────────────┬───────────┬───────────┬────────────┬───────────┬───────────┬───────────┐
#     │ reactants  ┆ products   ┆ formula   ┆ dtqoqxscn ┆ xnomnrean  ┆ rate      ┆ colliders ┆ reabeiqom │
#     │ ---        ┆ ---        ┆ ---       ┆ ---       ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
#     │ list[str]  ┆ list[str]  ┆ struct[3] ┆ str       ┆ str        ┆ struct[7] ┆ struct[11 ┆ str       │
#     │            ┆            ┆           ┆           ┆            ┆           ┆ ]         ┆           │
#     ╞════════════╪════════════╪═══════════╪═══════════╪════════════╪═══════════╪═══════════╪═══════════╡
#     │ ["S(722)"] ┆ ["C5H8(522 ┆ {5,9,2}   ┆ null      ┆ C5H8(522)+ ┆ {{1.0,0.0 ┆ {null,nul ┆ C5H8(522) │
#     │            ┆ )",        ┆           ┆           ┆ HO2(8)=S(7 ┆ ,0.0},tru ┆ l,null,nu ┆ +HO2(8)=S │
#     │            ┆ "HO2(8)"]  ┆           ┆           ┆ 22)        ┆ e,"Plog", ┆ ll,null,n ┆ (722)     │
#     │            ┆            ┆           ┆           ┆            ┆ nul…      ┆ ull…      ┆           │
#     │ ["S(722)"] ┆ ["C5H8O(82 ┆ {5,9,2}   ┆ null      ┆ null       ┆ {{1.0,0.0 ┆ {null,nul ┆ C5H8O(825 │
#     │            ┆ 5)",       ┆           ┆           ┆            ┆ ,0.0},tru ┆ l,null,nu ┆ )+OH(4)=S │
#     │            ┆ "OH(4)"]   ┆           ┆           ┆            ┆ e,"Plog", ┆ ll,null,n ┆ (722)     │
#     │            ┆            ┆           ┆           ┆            ┆ nul…      ┆ ull…      ┆           │
#     └────────────┴────────────┴───────────┴───────────┴────────────┴───────────┴───────────┴───────────┘
#   ),
#   species=DataFrame(
#     shape: (5, 7)
#     ┌────────────┬──────────────┬──────────────────┬──────┬────────┬─────────────────┬─────────────────┐
#     │ name       ┆ smiles       ┆ amchi            ┆ spin ┆ charge ┆ formula         ┆ thermo_string   │
#     │ ---        ┆ ---          ┆ ---              ┆ ---  ┆ ---    ┆ ---             ┆ ---             │
#     │ str        ┆ str          ┆ str              ┆ i64  ┆ i64    ┆ struct[6]       ┆ str             │
#     ╞════════════╪══════════════╪══════════════════╪══════╪════════╪═════════════════╪═════════════════╡
#     │ C5H8(522)  ┆ C1CC=CC1     ┆ AMChI=1/C5H8/c1- ┆ 0    ┆ 0      ┆ {8,null,null,nu ┆ C   5H   8      │
#     │            ┆              ┆ 2-4-5-3-1/h1-2…  ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │ C5H8O(825) ┆ O1C2C1CCC2   ┆ AMChI=1/C5H8O/c1 ┆ 0    ┆ 0      ┆ {8,1,null,null, ┆ C   5H   8O   1 │
#     │            ┆              ┆ -2-4-5(6-4)3-1…  ┆      ┆        ┆ null,5}         ┆ G   300.00…     │
#     │ HO2(8)     ┆ O[O]         ┆ AMChI=1/HO2/c1-2 ┆ 1    ┆ 0      ┆ {1,2,null,null, ┆ H   1O   2      │
#     │            ┆              ┆ /h2H             ┆      ┆        ┆ null,null}      ┆ G   200.00…     │
#     │ S(722)     ┆ OOC1CCC[CH]1 ┆ AMChI=1/C5H9O2/c ┆ 1    ┆ 0      ┆ {9,2,null,null, ┆ C   5H   9O   2 │
#     │            ┆              ┆ 6-7-5-1-2-3-4-…  ┆      ┆        ┆ null,5}         ┆ G   300.00…     │
#     │ OH(4)      ┆ [OH]         ┆ AMChI=1/HO/h1H   ┆ 1    ┆ 0      ┆ {1,1,null,null, ┆ H   1O   1      │
#     │            ┆              ┆                  ┆      ┆        ┆ null,null}      ┆ G   200.00…     │
#     └────────────┴──────────────┴──────────────────┴──────┴────────┴─────────────────┴─────────────────┘
#   ),
#   rate_units=('KCAL/MOLE', 'MOLES'),
#   thermo_temps=None,
# )
#
# Expanding stereochemistry...
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/B_rh-ho2_p1v0.json
# ../data/mechanalyzer/B_rh-ho2_p1v0.dat
# ../data/mechanalyzer/B_rh-ho2_p1v0.csv
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Stereoexpansion errors:

# %%
# Read
workflow.read(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/3108 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/B_rh-ho2_p1v0_calc.json
# ../data/full_B_rh-ho2_p1v0_control.json
# ../data/full_B_rh-ho2_p1v0_calc.json
# ../data/chemkin/full_B_rh-ho2_p1v0_control.dat
# ../data/chemkin/full_B_rh-ho2_p1v0_calc.dat
#
# Compare calculated mechanism to parent mechanism...
#
# 1. Original (compare):
# S(722) = C5H8O(825) + OH(4)                        1.000E+00      0.000      0.000
#     PLOG  /                             0.0009870  9.620E+01      2.050      3.050/
#     PLOG  /                             0.0009870  4.840E+35     -7.840      19.69/
#     PLOG  /                              0.009870  1.290E+13     -1.370      5.946/
#     PLOG  /                              0.009870  2.230E+38     -8.490      20.33/
#     PLOG  /                               0.09870  3.220E+22     -4.170      8.727/
#     PLOG  /                               0.09870  2.120E+32     -6.320      18.79/
#     PLOG  /                                0.9870  1.280E+25     -4.670      10.25/
#     PLOG  /                                0.9870  4.000E+24     -3.630      17.39/
#     PLOG  /                                 9.870  9.850E+17     -2.010      9.428/
#     PLOG  /                                 9.870  1.220E+79     -19.63      47.13/
#     PLOG  /                                 98.70  1.540E+24     -3.840      12.30/
#     PLOG  /                                 98.70  1.490E+00      3.720      4.676/
# S(722) = C5H8(522) + HO2(8)                        1.000E+00      0.000      0.000
#     PLOG  /                             0.0009870  1.160E+10     0.2500      18.81/
#     PLOG  /                             0.0009870  3.200E+42     -9.300      34.89/
#     PLOG  /                              0.009870  8.010E+14     -1.060      20.21/
#     PLOG  /                              0.009870  4.070E+34     -6.510      32.93/
#     PLOG  /                               0.09870  4.260E-07      6.110      14.28/
#     PLOG  /                               0.09870  1.680E-33      13.44      2.462/
#     PLOG  /                                0.9870  1.010E+39     -9.820      19.29/
#     PLOG  /                                0.9870  1.920E+00      4.000      15.01/
#     PLOG  /                                 9.870  6.240E+30     -6.270      19.03/
#     PLOG  /                                 9.870  1.360E+22     -2.540      24.49/
#     PLOG  /                                 98.70  9.770E+19     -2.310      17.48/
#     PLOG  /                                 98.70  1.320E+90     -22.11      67.41/
# C5H8(522) + HO2(8) = C5H8O(825) + OH(4)            1.000E+00      0.000      0.000
#     PLOG  /                             0.0009870  6.250E+19     -2.220      18.57/
#     PLOG  /                             0.0009870  1.070E+08      1.050      10.30/
#     PLOG  /                              0.009870  1.120E+19     -2.010      18.02/
#     PLOG  /                              0.009870  1.500E+08     0.9900      10.30/
#     PLOG  /                               0.09870  1.580E+18     -1.770      17.45/
#     PLOG  /                               0.09870  1.520E+08     0.9800      10.27/
#     PLOG  /                                0.9870  2.960E+18     -1.860      17.72/
#     PLOG  /                                0.9870  4.970E+08     0.8500      10.60/
#     PLOG  /                                 9.870  7.480E+11    0.08000      13.43/
#     PLOG  /                                 9.870  3.630E+09     0.4100      11.18/
#     PLOG  /                                 98.70  5.530E+23     -3.500      19.62/
#     PLOG  /                                 98.70  1.470E+03      2.630      10.81/
#
# 2. Calculated (compare):
# S(722)r1 = C5H8O(825)rs + OH(4)                      2.210E+08      0.000      0.000
# S(722)r1 = C5H8(522) + HO2(8)                        1.650E+06      0.000      0.000
# C5H8(522) + HO2(8) = C5H8O(825)rs + OH(4)            8.306E+05      1.786      10.40
#     DUPLICATE
# S(722)r0 = C5H8O(825)rs + OH(4)                      2.220E+08      0.000      0.000
# S(722)r0 = C5H8(522) + HO2(8)                        1.660E+06      0.000      0.000
# C5H8(522) + HO2(8) = C5H8O(825)rs + OH(4)            8.306E+05      1.786      10.40
#     DUPLICATE

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)
