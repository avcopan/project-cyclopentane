# %%
from pathlib import Path

import util
from util import workflow

browser = True
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# Build
from automol.graph import enum

import automech
from automech.species import Species

mech0 = automech.io.read(data_path / "full_raw.json")
mech = automech.from_smiles(spc_smis=["C1=CCCC1", "C12C(O2)CCC1"], src_mech=mech0)
#  - add HO2 addition to *ene*
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.pi2_addition,
    rcts_=[None, "O[O]"],
    spc_col_=Species.smiles,
    src_mech=mech0,
)
#  - add ring-forming scission
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.ring_forming_scission,
    src_mech=mech0,
)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)
# Out:
# Finalizing build for...
# reactions=shape: (2, 5)
# ┌────────────┬─────────────────────────┬───────────┬────────────┬─────────────────────────────────┐
# │ reactants  ┆ products                ┆ formula   ┆ reversible ┆ rate_constant                   │
# │ ---        ┆ ---                     ┆ ---       ┆ ---        ┆ ---                             │
# │ list[str]  ┆ list[str]               ┆ struct[3] ┆ bool       ┆ struct[17]                      │
# ╞════════════╪═════════════════════════╪═══════════╪════════════╪═════════════════════════════════╡
# │ ["S(722)"] ┆ ["C5H8(522)", "HO2(8)"] ┆ {5,9,2}   ┆ true       ┆ {1,{null,null,null,null,null,n… │
# │ ["S(722)"] ┆ ["C5H8O(825)", "OH(4)"] ┆ {5,9,2}   ┆ true       ┆ {1,{null,null,null,null,null,n… │
# └────────────┴─────────────────────────┴───────────┴────────────┴─────────────────────────────────┘ species=shape: (5, 7)
# ┌────────────┬──────────────┬──────────────────┬──────┬────────┬─────────────────┬─────────────────┐
# │ name       ┆ smiles       ┆ amchi            ┆ spin ┆ charge ┆ formula         ┆ thermo_string   │
# │ ---        ┆ ---          ┆ ---              ┆ ---  ┆ ---    ┆ ---             ┆ ---             │
# │ str        ┆ str          ┆ str              ┆ i64  ┆ i64    ┆ struct[7]       ┆ str             │
# ╞════════════╪══════════════╪══════════════════╪══════╪════════╪═════════════════╪═════════════════╡
# │ C5H8(522)  ┆ C1CC=CC1     ┆ AMChI=1/C5H8/c1- ┆ 0    ┆ 0      ┆ {8,null,null,nu ┆ C   5H   8      │
# │            ┆              ┆ 2-4-5-3-1/h1-2…  ┆      ┆        ┆ ll,null,5,null} ┆ G   298.00…     │
# │ HO2(8)     ┆ O[O]         ┆ AMChI=1/HO2/c1-2 ┆ 1    ┆ 0      ┆ {1,2,null,null, ┆ H   1O   2      │
# │            ┆              ┆ /h2H             ┆      ┆        ┆ null,null,null} ┆ G   200.00…     │
# │ S(722)     ┆ OOC1CCC[CH]1 ┆ AMChI=1/C5H9O2/c ┆ 1    ┆ 0      ┆ {9,2,null,null, ┆ C   5H   9O   2 │
# │            ┆              ┆ 6-7-5-1-2-3-4-…  ┆      ┆        ┆ null,5,null}    ┆ G   300.00…     │
# │ C5H8O(825) ┆ O1C2C1CCC2   ┆ AMChI=1/C5H8O/c1 ┆ 0    ┆ 0      ┆ {8,1,null,null, ┆ C   5H   8O   1 │
# │            ┆              ┆ -2-4-5(6-4)3-1…  ┆      ┆        ┆ null,5,null}    ┆ G   300.00…     │
# │ OH(4)      ┆ [OH]         ┆ AMChI=1/HO/h1H   ┆ 1    ┆ 0      ┆ {1,1,null,null, ┆ H   1O   1      │
# │            ┆              ┆                  ┆      ┆        ┆ null,null,null} ┆ G   200.00…     │
# └────────────┴──────────────┴──────────────────┴──────┴────────┴─────────────────┴─────────────────┘ thermo_temps=None
#
# Expanding stereochemistry...
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/B_rh-ho2_p1v0_raw.json
# ../data/B_rh-ho2_p1v0.json
# ../data/mechanalyzer/B_rh-ho2_p1v0.dat
# ../data/mechanalyzer/B_rh-ho2_p1v0.csv
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Stereoexpansion errors:

# %%
# Read
workflow.read(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/3108 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/B_rh-ho2_p1v0_calc.json
# ../data/full_B_rh-ho2_p1v0_control.json
# ../data/full_B_rh-ho2_p1v0_calc.json
# ../data/chemkin/full_B_rh-ho2_p1v0_control.dat
# ../data/chemkin/full_B_rh-ho2_p1v0_calc.dat
#
# Compare calculated mechanism to parent mechanism...
#
# *********
# Reaction: S(722)r1 = C5H8O(825)rs + OH(4)
# Translations:
#   smiles:
#     reactants = ['OO[C@@H]1[CH]CCC1']
#     products = ['C1C[C@H]2[C@@H](C1)O2', '[OH]']
# Rate parameters:
#   This work:
#     S(722)r1 = C5H8O(825)rs + OH(4)                          221000000      0.000      0.000
#   Hill:
#     S(722) = C5H8O(825) + OH(4)                                  1.000      0.000      0.000
#         PLOG  /  0.0009870      96.20      2.050       3050/
#         PLOG  /  0.0009870  4.840E+35     -7.840      19690/
#         PLOG  /   0.009870  1.290E+13     -1.370       5946/
#         PLOG  /   0.009870  2.230E+38     -8.490      20330/
#         PLOG  /    0.09870  3.220E+22     -4.170       8727/
#         PLOG  /    0.09870  2.120E+32     -6.320      18790/
#         PLOG  /     0.9870  1.280E+25     -4.670      10250/
#         PLOG  /     0.9870  4.000E+24     -3.630      17390/
#         PLOG  /      9.870  9.850E+17     -2.010       9428/
#         PLOG  /      9.870  1.220E+79     -19.63      47130/
#         PLOG  /      98.70  1.540E+24     -3.840      12300/
#         PLOG  /      98.70      1.490      3.720       4676/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)
# *********
# Reaction: S(722)r1 = C5H8(522) + HO2(8)
# Translations:
#   smiles:
#     reactants = ['OO[C@@H]1[CH]CCC1']
#     products = ['C1=CCCC1', '[O]O']
# Rate parameters:
#   This work:
#     S(722)r1 = C5H8(522) + HO2(8)                              1650000      0.000      0.000
#   Hill:
#     S(722) = C5H8(522) + HO2(8)                                  1.000      0.000      0.000
#         PLOG  /  0.0009870  1.160E+10     0.2500      18810/
#         PLOG  /  0.0009870  3.200E+42     -9.300      34890/
#         PLOG  /   0.009870  8.010E+14     -1.060      20210/
#         PLOG  /   0.009870  4.070E+34     -6.510      32930/
#         PLOG  /    0.09870  4.260E-07      6.110      14280/
#         PLOG  /    0.09870  1.680E-33      13.44       2462/
#         PLOG  /     0.9870  1.010E+39     -9.820      19290/
#         PLOG  /     0.9870      1.920      4.000      15010/
#         PLOG  /      9.870  6.240E+30     -6.270      19030/
#         PLOG  /      9.870  1.360E+22     -2.540      24490/
#         PLOG  /      98.70  9.770E+19     -2.310      17480/
#         PLOG  /      98.70  1.320E+90     -22.11      67410/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)
# *********
# Reaction: C5H8(522) + HO2(8) = C5H8O(825)rs + OH(4)
# Translations:
#   smiles:
#     reactants = ['C1=CCCC1', '[O]O']
#     products = ['C1C[C@H]2[C@@H](C1)O2', '[OH]']
# Rate parameters:
#   This work:
#     C5H8(522) + HO2(8) = C5H8O(825)rs + OH(4)                   830600      1.786      10404
#   Hill:
#     C5H8(522) + HO2(8) = C5H8O(825) + OH(4)                      1.000      0.000      0.000
#         PLOG  /  0.0009870  6.250E+19     -2.220      18570/
#         PLOG  /  0.0009870  107000000      1.050      10300/
#         PLOG  /   0.009870  1.120E+19     -2.010      18020/
#         PLOG  /   0.009870  150000000     0.9900      10300/
#         PLOG  /    0.09870  1.580E+18     -1.770      17450/
#         PLOG  /    0.09870  152000000     0.9800      10270/
#         PLOG  /     0.9870  2.960E+18     -1.860      17720/
#         PLOG  /     0.9870  497000000     0.8500      10600/
#         PLOG  /      9.870  7.480E+11    0.08000      13430/
#         PLOG  /      9.870 3630000000     0.4100      11180/
#         PLOG  /      98.70  5.530E+23     -3.500      19620/
#         PLOG  /      98.70       1470      2.630      10810/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)
# *********
# Reaction: S(722)r0 = C5H8O(825)rs + OH(4)
# Translations:
#   smiles:
#     reactants = ['OO[C@H]1[CH]CCC1']
#     products = ['C1C[C@H]2[C@@H](C1)O2', '[OH]']
# Rate parameters:
#   This work:
#     S(722)r0 = C5H8O(825)rs + OH(4)                          222000000      0.000      0.000
#   Hill:
#     S(722) = C5H8O(825) + OH(4)                                  1.000      0.000      0.000
#         PLOG  /  0.0009870      96.20      2.050       3050/
#         PLOG  /  0.0009870  4.840E+35     -7.840      19690/
#         PLOG  /   0.009870  1.290E+13     -1.370       5946/
#         PLOG  /   0.009870  2.230E+38     -8.490      20330/
#         PLOG  /    0.09870  3.220E+22     -4.170       8727/
#         PLOG  /    0.09870  2.120E+32     -6.320      18790/
#         PLOG  /     0.9870  1.280E+25     -4.670      10250/
#         PLOG  /     0.9870  4.000E+24     -3.630      17390/
#         PLOG  /      9.870  9.850E+17     -2.010       9428/
#         PLOG  /      9.870  1.220E+79     -19.63      47130/
#         PLOG  /      98.70  1.540E+24     -3.840      12300/
#         PLOG  /      98.70      1.490      3.720       4676/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)
# *********
# Reaction: S(722)r0 = C5H8(522) + HO2(8)
# Translations:
#   smiles:
#     reactants = ['OO[C@H]1[CH]CCC1']
#     products = ['C1=CCCC1', '[O]O']
# Rate parameters:
#   This work:
#     S(722)r0 = C5H8(522) + HO2(8)                              1660000      0.000      0.000
#   Hill:
#     S(722) = C5H8(522) + HO2(8)                                  1.000      0.000      0.000
#         PLOG  /  0.0009870  1.160E+10     0.2500      18810/
#         PLOG  /  0.0009870  3.200E+42     -9.300      34890/
#         PLOG  /   0.009870  8.010E+14     -1.060      20210/
#         PLOG  /   0.009870  4.070E+34     -6.510      32930/
#         PLOG  /    0.09870  4.260E-07      6.110      14280/
#         PLOG  /    0.09870  1.680E-33      13.44       2462/
#         PLOG  /     0.9870  1.010E+39     -9.820      19290/
#         PLOG  /     0.9870      1.920      4.000      15010/
#         PLOG  /      9.870  6.240E+30     -6.270      19030/
#         PLOG  /      9.870  1.360E+22     -2.540      24490/
#         PLOG  /      98.70  9.770E+19     -2.310      17480/
#         PLOG  /      98.70  1.320E+90     -22.11      67410/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)
# *********
# Reaction: C5H8(522) + HO2(8) = C5H8O(825)rs + OH(4)
# Translations:
#   smiles:
#     reactants = ['C1=CCCC1', '[O]O']
#     products = ['C1C[C@H]2[C@@H](C1)O2', '[OH]']
# Rate parameters:
#   This work:
#     C5H8(522) + HO2(8) = C5H8O(825)rs + OH(4)                   830600      1.786      10404
#   Hill:
#     C5H8(522) + HO2(8) = C5H8O(825) + OH(4)                      1.000      0.000      0.000
#         PLOG  /  0.0009870  6.250E+19     -2.220      18570/
#         PLOG  /  0.0009870  107000000      1.050      10300/
#         PLOG  /   0.009870  1.120E+19     -2.010      18020/
#         PLOG  /   0.009870  150000000     0.9900      10300/
#         PLOG  /    0.09870  1.580E+18     -1.770      17450/
#         PLOG  /    0.09870  152000000     0.9800      10270/
#         PLOG  /     0.9870  2.960E+18     -1.860      17720/
#         PLOG  /     0.9870  497000000     0.8500      10600/
#         PLOG  /      9.870  7.480E+11    0.08000      13430/
#         PLOG  /      9.870 3630000000     0.4100      11180/
#         PLOG  /      98.70  5.530E+23     -3.500      19620/
#         PLOG  /      98.70       1470      2.630      10810/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)
