# %%
from pathlib import Path

import automech

# %%
DATA_PATH = Path("../data")

# %%
tag_dct = {
    "full_cyclopentane": "full",
    "cyclopentene": "1ene",
    "12epoxycyclopentane": "2epoxy12",
    "13epoxyCPT": "3epoxy13",
}

# %%
for tag0, tag in tag_dct.items():
    mech, err = automech.io.rmg.read.mechanism(
        rxn_inp=DATA_PATH / "rmg" / f"{tag0}_chem.inp",
        spc_inp=DATA_PATH / "rmg" / f"{tag0}_species_dictionary.txt",
    )
    automech.io.write(mech, DATA_PATH / f"{tag}_raw.json")
# Out:
#   0%|          | 0/2534 [00:00<?, ?it/s]
#   0%|          | 0/2534 [00:00<?, ?it/s]
#   0%|          | 0/2534 [00:00<?, ?it/s]
#   0%|          | 0/10002 [00:00<?, ?it/s]
#   0%|          | 0/10002 [00:00<?, ?it/s]
#   0%|          | 0/10002 [00:00<?, ?it/s]
#   0%|          | 0/10002 [00:00<?, ?it/s]
#   0%|          | 0/10002 [00:00<?, ?it/s]
#   0%|          | 0/10002 [00:00<?, ?it/s]
#   0%|          | 0/687 [00:00<?, ?it/s]
#   0%|          | 0/687 [00:00<?, ?it/s]
#   0%|          | 0/687 [00:00<?, ?it/s]
#   0%|          | 0/1639 [00:00<?, ?it/s]
#   0%|          | 0/1639 [00:00<?, ?it/s]
#   0%|          | 0/1639 [00:00<?, ?it/s]
#   0%|          | 0/1639 [00:00<?, ?it/s]
#   0%|          | 0/1639 [00:00<?, ?it/s]
#   0%|          | 0/1639 [00:00<?, ?it/s]
#   0%|          | 0/1233 [00:00<?, ?it/s]
#   0%|          | 0/1233 [00:00<?, ?it/s]
#   0%|          | 0/1233 [00:00<?, ?it/s]
#   0%|          | 0/3253 [00:00<?, ?it/s]
#   0%|          | 0/3253 [00:00<?, ?it/s]
#   0%|          | 0/3253 [00:00<?, ?it/s]
#   0%|          | 0/3253 [00:00<?, ?it/s]
#   0%|          | 0/3253 [00:00<?, ?it/s]
#   0%|          | 0/3253 [00:00<?, ?it/s]
#   0%|          | 0/345 [00:00<?, ?it/s]
#   0%|          | 0/345 [00:00<?, ?it/s]
#   0%|          | 0/345 [00:00<?, ?it/s]
#   0%|          | 0/701 [00:00<?, ?it/s]
#   0%|          | 0/701 [00:00<?, ?it/s]
#   0%|          | 0/701 [00:00<?, ?it/s]
#   0%|          | 0/701 [00:00<?, ?it/s]
#   0%|          | 0/701 [00:00<?, ?it/s]
#   0%|          | 0/701 [00:00<?, ?it/s]
