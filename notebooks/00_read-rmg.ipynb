# %%
from pathlib import Path

import util

import automech

root_path = Path("..")
data_path = util.data_path(root_path)

# %%
tag_dct = {
    "full_cyclopentane": "full",
    "cyclopentene": "1ene",
    "12epoxycyclopentane": "2epoxy12",
    "13epoxyCPT": "3epoxy13",
}

# %%
for tag0, tag in tag_dct.items():
    mech = automech.io.rmg.read.mechanism(
        rxn_inp=data_path / "rmg" / f"{tag0}_chem.inp",
        spc_inp=data_path / "rmg" / f"{tag0}_species_dictionary.txt",
    )
    automech.io.write(mech, data_path / f"{tag}_raw.json")
# Out:
#   0%|          | 0/2534 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 for tag0, tag in tag_dct.items():
# ----> 2     mech = automech.io.rmg.read.mechanism(
#       3         rxn_inp=data_path / "rmg" / f"{tag0}_chem.inp",
#       4         spc_inp=data_path / "rmg" / f"{tag0}_species_dictionary.txt",
#       5     )
#       6     automech.io.write(mech, data_path / f"{tag}_raw.json")
#
# File ~/code/amech-dev/src/automech/io/rmg/read.py:38, in mechanism(rxn_inp, spc_inp, out, spc_out)
#      27 def mechanism(
#      28     rxn_inp: str, spc_inp: str, out: str | None = None, spc_out: str | None = None
#      29 ) -> Mechanism:
#      30     """Extract the mechanism from RMG files.
#      31
#      32     :param inp: An RMG mechanism (CHEMKIN format), as a file path or string
#    (...)
#      36     :return: The mechanism dataclass
#      37     """
# ---> 38     spc_df = species(spc_inp)
#      39     spc_df = chemkin_read.thermo(rxn_inp, spc_df=spc_df, out=spc_out)
#      40     rxn_df = chemkin_read.reactions(rxn_inp, out=out, spc_df=spc_df)
#
# File ~/code/amech-dev/src/automech/io/rmg/read.py:66, in species(inp, out)
#      64     names.append(spc_par_ret["species"])
#      65     mults.append(spc_par_ret.get("mult", 1) - 1)
# ---> 66     chis.append(automol.graph.amchi(gra))
#      67     smis.append(automol.graph.smiles(gra))
#      69 data = {
#      70     Species.name: names,
#      71     Species.spin: mults,
#      72     Species.amchi: chis,
#      73     Species.smiles: smis,
#      74 }
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_09amchi.py:52, in amchi(gra, stereo)
#      42 def amchi(gra, stereo: bool = True) -> str:
#      43     """Generate an AMChI string with AMChI canonical numbers
#      44
#      45     :param gra: A graph
#    (...)
#      50     :rtype: str
#      51     """
# ---> 52     chi, _ = amchi_with_numbers(gra, stereo=stereo)
#      53     return chi
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_09amchi.py:68, in amchi_with_numbers(gra, stereo)
#      57 """Generate an AMChI string with canonical atom numbers
#      58
#      59 :param gra: A graph
#    (...)
#      65 :rtype: (str, List[Dict[int, int]])
#      66 """
#      67 gras = connected_components(gra)
# ---> 68 chis, num_dcts = zip(*(_amchi_with_numbers(g, stereo=stereo) for g in gras))
#      69 chi, srt = amchi_base.sorted_join(chis)
#      70 num_dcts = tuple(num_dcts[i] for i in srt)
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_09amchi.py:68, in <genexpr>(.0)
#      57 """Generate an AMChI string with canonical atom numbers
#      58
#      59 :param gra: A graph
#    (...)
#      65 :rtype: (str, List[Dict[int, int]])
#      66 """
#      67 gras = connected_components(gra)
# ---> 68 chis, num_dcts = zip(*(_amchi_with_numbers(g, stereo=stereo) for g in gras))
#      69 chi, srt = amchi_base.sorted_join(chis)
#      70 num_dcts = tuple(num_dcts[i] for i in srt)
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_09amchi.py:85, in _amchi_with_numbers(gra, stereo)
#      75 """single-component AMChI string from a connected graph
#      76
#      77 :param gra: molecular graph
#    (...)
#      82 :rtype: str
#      83 """
#      84 # 1. Put the graph in canonical AMChI format
# ---> 85 gra, num_dct, is_can_dir, is_can_enant = canonical_amchi_graph_with_numbers(
#      86     gra, stereo=stereo
#      87 )
#      89 # 3. Generate the appropriate layers
#      90 #   a. Formula string
#      91 fml_str = formula_string(gra)
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_08canon.py:151, in canonical_amchi_graph_with_numbers(gra, stereo)
#     148 cand_dct = stereocenter_candidates(gra)
#     150 # 1. Convert to implicit-hydrogen form
# --> 151 gra = implicit(gra)
#     153 # 2. Determine the canonical TS direction
#     154 *_, pri_dct, is_can_dir = calculate_stereo(gra, cand_dct=cand_dct)
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:2458, in implicit(gra, atm_keys)
#    2448 def implicit(gra, atm_keys=None):
#    2449     """Make explicit hydrogens in this graph implicit
#    2450
#    2451     :param gra: molecular graph
#    (...)
#    2456     :rtype: automol graph data structure
#    2457     """
# -> 2458     atm_keys = backbone_keys(gra) if atm_keys is None else atm_keys
#    2460     atm_exp_hyd_keys_dct = dict_.by_key(atom_nonbackbone_hydrogen_keys(gra), atm_keys)
#    2462     inc_imp_hyd_keys_dct = dict_.transform_values(atm_exp_hyd_keys_dct, len)
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:1671, in backbone_keys(gra, hyd)
#    1669 bbn_keys = atom_keys(gra, excl_symbs=("H",))
#    1670 if hyd:
# -> 1671     bbn_keys |= backbone_hydrogen_keys(gra)
#    1672 return bbn_keys
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:1627, in backbone_hydrogen_keys(gra)
#    1614 def backbone_hydrogen_keys(gra):
#    1615     """Get the backbone hydrogen keys of this molecular graph
#    1616
#    1617     These are hydrogen keys which cannot be made implicit, because they are
#    (...)
#    1625     :rtype: frozenset[int]
#    1626     """
# -> 1627     bbn_hkeys, _ = backbone_and_nonbackbone_hydrogen_keys(gra)
#    1628     return bbn_hkeys
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:1599, in backbone_and_nonbackbone_hydrogen_keys(gra)
#    1591 """Get the backbone and non-backbone hydrogen keys of this molecular graph
#    1592
#    1593 :param gra: molecular graph
#    (...)
#    1596 :rtype: (frozenset[int], frozenset[int])
#    1597 """
#    1598 hkeys = atom_keys(gra, symb="H")
# -> 1599 nkeys_dct = atoms_neighbor_atom_keys(gra)
#    1600 nhyd_dct = atom_implicit_hydrogens(gra)
#    1601 rxn_keys = ts_reacting_atom_keys(gra)
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:2784, in atoms_neighbor_atom_keys(gra, ts_)
#    2780 def _neighbor_keys(atm_key, atm_nbh):
#    2781     return frozenset(atom_keys(atm_nbh) - {atm_key})
#    2783 atm_ngb_keys_dct = dict_.transform_items_to_values(
# -> 2784     atom_neighborhoods(gra, ts_=ts_), _neighbor_keys
#    2785 )
#    2786 return atm_ngb_keys_dct
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:2631, in atom_neighborhoods(gra, bnd_keys, stereo, ts_)
#    2626     return atom_neighborhood(
#    2627         gra, atm_key, bnd_keys=bnd_keys, stereo=stereo, ts_=ts_
#    2628     )
#    2630 atm_keys = list(atom_keys(gra))
# -> 2631 atm_nbh_dct = dict(zip(atm_keys, map(_neighborhood, atm_keys)))
#    2632 return atm_nbh_dct
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:2626, in atom_neighborhoods.<locals>._neighborhood(atm_key)
#    2625 def _neighborhood(atm_key):
# -> 2626     return atom_neighborhood(
#    2627         gra, atm_key, bnd_keys=bnd_keys, stereo=stereo, ts_=ts_
#    2628     )
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:2604, in atom_neighborhood(gra, atm_key, bnd_keys, stereo, ts_, second_degree)
#    2601     nbh_bnd_keys = set(k for k in bnd_keys if nbh_atm_keys & k)
#    2603 if nbh_bnd_keys:
# -> 2604     nbh = bond_induced_subgraph(gra, nbh_bnd_keys, stereo=stereo)
#    2605 else:
#    2606     nbh = subgraph(gra, {atm_key}, stereo=stereo)
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:2569, in bond_induced_subgraph(gra, bnd_keys, stereo)
#    2567 sub = from_atoms_and_bonds(atm_dct, bnd_dct)
#    2568 if not stereo:
# -> 2569     sub = without_stereo(sub)
#    2570 return sub
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:2374, in without_stereo(gra, atm_keys, bnd_keys)
#    2372 bnd_ste_par_dct = dict_.by_key({}, bnd_keys, fill_val=None)
#    2373 gra = set_atom_stereo_parities(gra, atm_ste_par_dct)
# -> 2374 gra = set_bond_stereo_parities(gra, bnd_ste_par_dct)
#    2375 return gra
#
# File ~/code/amech-dev/src/autochem/automol/graph/base/_00core.py:750, in set_bond_stereo_parities(gra, bnd_par_dct)
#     740 """Set the bond stereo parities of this molecular graph with a dictionary
#     741
#     742 :param gra: molecular graph
#    (...)
#     747 :rtype: automol graph data structure
#     748 """
#     749 bnd_par_dct = dict_.transform_keys(bnd_par_dct, frozenset)
# --> 750 bnd_dct = dict_.multi.set_by_key_by_position(
#     751     bonds(gra), bnd_par_dct, BND_STE_PAR_POS
#     752 )
#     753 return from_atoms_and_bonds(atoms(gra), bnd_dct)
#
# File ~/code/amech-dev/src/autochem/automol/util/dict_/multi.py:58, in set_by_key_by_position(mdct, dct, pos)
#      56     for key, val in dct.items():
#      57         mdct[key][pos] = val
# ---> 58     mdct = _freeze(mdct)
#      59 return mdct
#
# File ~/code/amech-dev/src/autochem/automol/util/dict_/multi.py:67, in _freeze(mdct)
#      66 def _freeze(mdct):
# ---> 67     return _transform_values(mdct, func=tuple)
#
# File ~/code/amech-dev/src/autochem/automol/util/dict_/_dict_.py:162, in transform_values(dct, func)
#     156 def transform_values(dct: dict[object, object], func: Callable = lambda x: x):
#     157     """Apply a function to each value.
#     158     :param dct: Dictionary
#     159     :param func: Callable function
#     160     :return: New values in a dictionary.
#     161     """
# --> 162     return dict[object, object](zip(dct.keys(), map(func, dct.values()), strict=False))
#
# KeyboardInterrupt:
