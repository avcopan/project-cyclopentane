# %%
from pathlib import Path

import automech

# %%
DATA_PATH = Path("data")
tag = "1ene"

# %%
mech0 = automech.io.read(DATA_PATH / f"00_{tag}_orig.json")

# %%
mech = automech.neighborhood(mech0, ["C5H7(1)", "C5H7(2)", "C5H7(3)"], order=2)
automech.display(mech)
# Out:
# ...
#   0%|          | 0/109 [00:00<?, ?it/s]

# %%
mech
# Out:
# Mechanism(
#   reactions=DataFrame(
#     shape: (109, 3)
#     ┌───────────────────────────────┬─────────────────────────────────┬───────────┐
#     │ eq                            ┆ rate                            ┆ colliders │
#     │ ---                           ┆ ---                             ┆ ---       │
#     │ str                           ┆ struct[3]                       ┆ struct[1] │
#     ╞═══════════════════════════════╪═════════════════════════════════╪═══════════╡
#     │ C5H7(1) = C5H7(2)             ┆ {{1.9054e11,0.853,47.848},true… ┆ {null}    │
#     │ C5H7(1) = C5H7(3)             ┆ {{3.3200e9,0.99,33.8},true,"Co… ┆ {null}    │
#     │ C5H7(1) = C5H7(2)             ┆ {{1.1820e10,0.86,35.7},true,"C… ┆ {null}    │
#     │ C5H7(2) = C5H7(3)             ┆ {{1.124e8,1.72,44.3},true,"Con… ┆ {null}    │
#     │ C5H7(1) = C5H7(2)             ┆ {{1.9054e11,0.853,47.848},true… ┆ {null}    │
# ...
