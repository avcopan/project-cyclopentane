# %%
from pathlib import Path

import automech

# %%
mech_num = "03"
# submech_leaf = "1submech_ene"
# submech_leaf = "2submech_12epoxy"
submech_leaf = "3submech_13epoxy"
# task_leaf = "1generate"
# mech_tag = ""
task_leaf = "2stereoexpand"
mech_tag = "_full"

dir_path = Path("..") / submech_leaf / task_leaf
assert dir_path.exists()

mech_path = dir_path / f"mechanism{mech_num}.dat{mech_tag}"
spc_path = dir_path / f"species{mech_num}.csv{mech_tag}"

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (12, 2)
#     ┌─────────────────────────────────┬─────────────────────────────────┐
#     │ eq                              ┆ rate                            │
#     │ ---                             ┆ ---                             │
#     │ str                             ┆ object                          │
#     ╞═════════════════════════════════╪═════════════════════════════════╡
#     │ C5H7O-WybPs7-1 + O2 = C5H7O3-x… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O-Wybn7G-0 + O2 = C5H7O3-K… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O-Wybn7G-1 + O2 = C5H7O3-K… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O-fZyn7G-0 + O2 = C5H7O3-U… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O-fZyvJN + O2 = C5H7O3-ig6… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                               ┆ …                               │
#     │ cyC5x13r1-1 + O2 = C5H7O3-sDVv… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r2-AB + O2 = C5H7O3-aC2… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r2-AB + O2 = C5H7O3-aC2… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r4-AB0 + O2 = C5H7O3-ZU… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r4-AB1 + O2 = C5H7O3-ZU… ┆ SimpleRate(k=ArrheniusFunction… │
#     └─────────────────────────────────┴─────────────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (24, 9)
#     ┌─────────────┬─────────────┬─────────────┬──────┬───┬────────────┬────────────┬──────┬────────────┐
#     │ name        ┆ smiles      ┆ amchi       ┆ spin ┆ … ┆ inchi      ┆ inchikey   ┆ mult ┆ canon_enan │
#     │ ---         ┆ ---         ┆ ---         ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---  ┆ t_ich      │
#     │ str         ┆ str         ┆ str         ┆ i64  ┆   ┆ str        ┆ str        ┆ i64  ┆ ---        │
#     │             ┆             ┆             ┆      ┆   ┆            ┆            ┆      ┆ str        │
#     ╞═════════════╪═════════════╪═════════════╪══════╪═══╪════════════╪════════════╪══════╪════════════╡
#     │ O2          ┆ O=O         ┆ AMChI=1/O2/ ┆ 0    ┆ … ┆ InChI=1S/O ┆ MYMOFIZGZY ┆ 1    ┆ InChI=1S/O │
#     │             ┆             ┆ c1-2        ┆      ┆   ┆ 2/c1-2     ┆ HOMD-UHFFF ┆      ┆ 2/c1-2     │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ AOYSA-N    ┆      ┆            │
#     │ C5H7O-fZyn7 ┆ [CH2][C@H]1 ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ DJIAQLUOVN ┆ 2    ┆ InChI=1S/C │
#     │ G-0         ┆ CC=CO1      ┆ 7O/c1-5-4-2 ┆      ┆   ┆ 5H7O/c1-5- ┆ QIEQ-YFKPB ┆      ┆ 5H7O/c1-5- │
#     │             ┆             ┆ -3-6-5/h…   ┆      ┆   ┆ 3-2-4-6-5/ ┆ YRVSA-N    ┆      ┆ 3-2-4-6-5/ │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5x13r2-A ┆ C1C[C@@H]2[ ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ SQBNIHHRZY ┆ 2    ┆ InChI=1S/C │
#     │ B           ┆ CH][C@H]1O2 ┆ 7O/c1-4-2-3 ┆      ┆   ┆ 5H7O/c1-2- ┆ UNFP-SYDPR ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -5(1)6-4…   ┆      ┆   ┆ 5-3-4(1)6- ┆ GILSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O-WybPs ┆ [CH2]C[C@@H ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ QRLNFQNGRA ┆ 2    ┆ InChI=1S/C │
#     │ 7-1         ┆ ]1C=CO1     ┆ 7O/c1-4-5-2 ┆      ┆   ┆ 5H7O/c1-2- ┆ OPSN-RXMQY ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -3-6-5/h…   ┆      ┆   ┆ 5-3-4-6-5/ ┆ KEDSA-N    ┆      ┆ 5-3-4-6-5/ │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5x13r4-A ┆ [CH]1C[C@@H ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ FHIVWWHLNL ┆ 2    ┆ InChI=1S/C │
#     │ B0          ┆ ]2C[C@H]1O2 ┆ 7O/c1-2-5-3 ┆      ┆   ┆ 5H7O/c1-2- ┆ PBCN-CRCLS ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -4(1)6-5…   ┆      ┆   ┆ 5-3-4(1)6- ┆ JGQSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ …           ┆ …           ┆ …           ┆ …    ┆ … ┆ …          ┆ …          ┆ …    ┆ …          │
#     │ C5H7O3-aC2P ┆ [O]O[C@H]1[ ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ KKWIYEZCCN ┆ 2    ┆ InChI=1S/C │
#     │ s7-ABA      ┆ C@@H]2CC[C@ ┆ 7O3/c6-8-5- ┆      ┆   ┆ 5H7O3/c6-8 ┆ OZJS-ZXFHE ┆      ┆ 5H7O3/c6-8 │
#     │             ┆ H]1O2       ┆ 3-1-2-4(…   ┆      ┆   ┆ -5-3-1-2-4 ┆ TKHSA-N    ┆      ┆ -5-3-1-2-4 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-aC2P ┆ [O]O[C@@H]1 ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ KKWIYEZCCN ┆ 2    ┆ InChI=1S/C │
#     │ s7-ABB      ┆ [C@@H]2CC[C ┆ 7O3/c6-8-5- ┆      ┆   ┆ 5H7O3/c6-8 ┆ OZJS-SCDXW ┆      ┆ 5H7O3/c6-8 │
#     │             ┆ @H]1O2      ┆ 3-1-2-4(…   ┆      ┆   ┆ -5-3-1-2-4 ┆ VJYSA-N    ┆      ┆ -5-3-1-2-4 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-UFb4 ┆ [O]OC[C@H]1 ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ JMUQVSKSGJ ┆ 2    ┆ InChI=1S/C │
#     │ sz-1        ┆ CC=CO1      ┆ 7O3/c6-8-4- ┆      ┆   ┆ 5H7O3/c6-8 ┆ CDBV-RXMQY ┆      ┆ 5H7O3/c6-8 │
#     │             ┆             ┆ 5-3-1-2-…   ┆      ┆   ┆ -4-5-2-1-3 ┆ KEDSA-N    ┆      ┆ -4-5-2-1-3 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-JIEB ┆ C=C1C[C@H]( ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ BPMBGXLOTH ┆ 2    ┆ InChI=1S/C │
#     │ qF-1        ┆ CO[O])O1    ┆ 7O3/c1-4-2- ┆      ┆   ┆ 5H7O3/c1-4 ┆ PXLR-RXMQY ┆      ┆ 5H7O3/c1-4 │
#     │             ┆             ┆ 5(8-4)3-…   ┆      ┆   ┆ -2-5(8-4)3 ┆ KEDSA-N    ┆      ┆ -2-5(8-4)3 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-ig6B ┆ C=C1CC[C@H] ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ XRARCZBYHG ┆ 2    ┆ InChI=1S/C │
#     │ qF-1        ┆ (O1)O[O]    ┆ 7O3/c1-4-2- ┆      ┆   ┆ 5H7O3/c1-4 ┆ UYKF-RXMQY ┆      ┆ 5H7O3/c1-4 │
#     │             ┆             ┆ 3-5(7-4)…   ┆      ┆   ┆ -2-3-5(7-4 ┆ KEDSA-N    ┆      ┆ -2-3-5(7-4 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     └─────────────┴─────────────┴─────────────┴──────┴───┴────────────┴────────────┴──────┴────────────┘
#   ),
# )

# %%
automech.display(mech)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
