# %%
from pathlib import Path

import automech

# %%
mech_num = "07"
submech_leaf = "1submech_ene"
# submech_leaf = "2submech_12epoxy"
# submech_leaf = "3submech_13epoxy"
task_leaf = "1generate"
mech_tag = ""
# task_leaf = "2stereoexpand"
# mech_tag = "_full"

dir_path = Path("..") / submech_leaf / task_leaf
assert dir_path.exists()

mech_path = dir_path / f"mechanism{mech_num}.dat{mech_tag}"
spc_path = dir_path / f"species{mech_num}.csv{mech_tag}"

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    rxn_inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/82 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (121, 2)
#     ┌─────────────────────────────────┬─────────────────────────────────┐
#     │ eq                              ┆ rate                            │
#     │ ---                             ┆ ---                             │
#     │ str                             ┆ object                          │
#     ╞═════════════════════════════════╪═════════════════════════════════╡
#     │ C5H7O2-AhAyrZ = C5H7O2AhAsEZ    ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O2-E8uMRH = C5H7O2-E8uKl4   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1r3 = C5H6-FCWKI4 + H      ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O2RO2-E8ufbF = C5H7O2E8uG2… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7-kSVPs7 + O2 = C5H7O2-E8uM… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                               ┆ …                               │
#     │ C5H7O2-wONMbO = C5H6O-prCgo2 +… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O2-wONFNe = C5H6O-Wyb9m1 +… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O2-E8uNLM = C5H6O-O1A4Ts +… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O2-E8uLiq = C5H6O-fZySxf +… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O2-E8uXaz = C5H6O-8C8Sxf +… ┆ SimpleRate(k=ArrheniusFunction… │
#     └─────────────────────────────────┴─────────────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (82, 8)
#     ┌──────────────┬──────────────┬───────────────┬──────┬────────┬──────────────┬──────────────┬──────┐
#     │ name         ┆ smiles       ┆ amchi         ┆ spin ┆ charge ┆ inchi        ┆ inchikey     ┆ mult │
#     │ ---          ┆ ---          ┆ ---           ┆ ---  ┆ ---    ┆ ---          ┆ ---          ┆ ---  │
#     │ str          ┆ str          ┆ str           ┆ i64  ┆ i64    ┆ str          ┆ str          ┆ i64  │
#     ╞══════════════╪══════════════╪═══════════════╪══════╪════════╪══════════════╪══════════════╪══════╡
#     │ H            ┆ [H]          ┆ AMChI=1/H     ┆ 1    ┆ 0      ┆ InChI=1S/H   ┆ YZCKVEUIGOOR ┆ 2    │
#     │              ┆              ┆               ┆      ┆        ┆              ┆ GS-UHFFFAOYS ┆      │
#     │              ┆              ┆               ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ H2           ┆ [H][H]       ┆ AMChI=1/H2/h1 ┆ 0    ┆ 0      ┆ InChI=1S/H2/ ┆ UFHFLCQGNIYN ┆ 1    │
#     │              ┆              ┆ H             ┆      ┆        ┆ h1H          ┆ RP-UHFFFAOYS ┆      │
#     │              ┆              ┆               ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ O            ┆ [O]          ┆ AMChI=1/O     ┆ 2    ┆ 0      ┆ InChI=1S/O   ┆ QVGXLLKOCUKJ ┆ 3    │
#     │              ┆              ┆               ┆      ┆        ┆              ┆ ST-UHFFFAOYS ┆      │
#     │              ┆              ┆               ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ OH           ┆ [OH]         ┆ AMChI=1/HO/h1 ┆ 1    ┆ 0      ┆ InChI=1S/HO/ ┆ TUJKJAMUKRIR ┆ 2    │
#     │              ┆              ┆ H             ┆      ┆        ┆ h1H          ┆ HC-UHFFFAOYS ┆      │
#     │              ┆              ┆               ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ H2O          ┆ O            ┆ AMChI=1/H2O/h ┆ 0    ┆ 0      ┆ InChI=1S/H2O ┆ XLYOFNOQVPJJ ┆ 1    │
#     │              ┆              ┆ 1H2           ┆      ┆        ┆ /h1H2        ┆ NP-UHFFFAOYS ┆      │
#     │              ┆              ┆               ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ …            ┆ …            ┆ …             ┆ …    ┆ …      ┆ …            ┆ …            ┆ …    │
#     │ C5H6O-Wyb4Ts ┆ C=CC1C=CO1   ┆ AMChI=1/C5H6O ┆ 0    ┆ 0      ┆ InChI=1S/C5H ┆ KCHYFDZUSUVM ┆ 1    │
#     │              ┆              ┆ /c1-2-5-3-4-6 ┆      ┆        ┆ 6O/c1-2-5-3- ┆ AU-UHFFFAOYS ┆      │
#     │              ┆              ┆ -5/h…         ┆      ┆        ┆ 4-6-5/…      ┆ A-N          ┆      │
#     │ C5H6O-prCgo2 ┆ C=CC1C(=C)O1 ┆ AMChI=1/C5H6O ┆ 0    ┆ 0      ┆ InChI=1S/C5H ┆ IMXAKIRINGGM ┆ 1    │
#     │              ┆              ┆ /c1-3-5-4(2)6 ┆      ┆        ┆ 6O/c1-3-5-4( ┆ HR-UHFFFAOYS ┆      │
#     │              ┆              ┆ -5/h…         ┆      ┆        ┆ 2)6-5/…      ┆ A-N          ┆      │
#     │ C5H6O-O1A4Ts ┆ C1C=COC=C1   ┆ AMChI=1/C5H6O ┆ 0    ┆ 0      ┆ InChI=1S/C5H ┆ MRUWJENAYHTD ┆ 1    │
#     │              ┆              ┆ /c1-3-6-4-2-5 ┆      ┆        ┆ 6O/c1-2-4-6- ┆ QG-UHFFFAOYS ┆      │
#     │              ┆              ┆ -1/h…         ┆      ┆        ┆ 5-3-1/…      ┆ A-N          ┆      │
#     │ C5H6O-fZySxf ┆ C=C1CC=CO1   ┆ AMChI=1/C5H6O ┆ 0    ┆ 0      ┆ InChI=1S/C5H ┆ IRGVRURTPPUE ┆ 1    │
#     │              ┆              ┆ /c1-5-4-2-3-6 ┆      ┆        ┆ 6O/c1-5-3-2- ┆ DB-UHFFFAOYS ┆      │
#     │              ┆              ┆ -5/h…         ┆      ┆        ┆ 4-6-5/…      ┆ A-N          ┆      │
#     │ C5H6O-8C8Sxf ┆ C=CCC1=CO1   ┆ AMChI=1/C5H6O ┆ 0    ┆ 0      ┆ InChI=1S/C5H ┆ NWKPGNPUQQAA ┆ 1    │
#     │              ┆              ┆ /c1-2-4-5-3-6 ┆      ┆        ┆ 6O/c1-2-3-5- ┆ FB-UHFFFAOYS ┆      │
#     │              ┆              ┆ -5/h…         ┆      ┆        ┆ 4-6-5/…      ┆ A-N          ┆      │
#     └──────────────┴──────────────┴───────────────┴──────┴────────┴──────────────┴──────────────┴──────┘
#   ),
# )

# %%
automech.display(mech)
# Out:
#   0%|          | 0/82 [00:00<?, ?it/s]
#   0%|          | 0/82 [00:00<?, ?it/s]
#   0%|          | 0/82 [00:00<?, ?it/s]
#   0%|          | 0/121 [00:00<?, ?it/s]
