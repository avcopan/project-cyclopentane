# %%
from pathlib import Path

import automech

# %%
mech_num = "02"
# submech_leaf = "1submech_ene"
# submech_leaf = "2submech_12epoxy"
submech_leaf = "3submech_13epoxy"
# task_leaf = "1generate"
# mech_tag = ""
task_leaf = "2stereoexpand"
mech_tag = "_full"

dir_path = Path("..") / submech_leaf / task_leaf
assert dir_path.exists()

mech_path = dir_path / f"mechanism{mech_num}.dat{mech_tag}"
spc_path = dir_path / f"species{mech_num}.csv{mech_tag}"

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (16, 2)
#     ┌─────────────────────────────────┬─────────────────────────────────┐
#     │ eq                              ┆ rate                            │
#     │ ---                             ┆ ---                             │
#     │ str                             ┆ object                          │
#     ╞═════════════════════════════════╪═════════════════════════════════╡
#     │ cyC5x13r1-0 = C5H7OKET-kJAtue   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r1-0 = C5H7O-ihevJN-0    ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r1-0 = C5H6O-HSdVHz-0 +… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r1-0 = C5H6O-HSdNT0-0 +… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r1-1 = C5H7O-fZyvJN      ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                               ┆ …                               │
#     │ cyC5x13r4-AB0 = C5H6O-HSdNT0-1… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r4-AB0 = C5H6O-HSdI2e-A… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r4-AB1 = C5H7O-fZyn7G-1  ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r4-AB1 = C5H7O-Wybn7G-1  ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r4-AB1 = C5H6O-HSdI2e-A… ┆ SimpleRate(k=ArrheniusFunction… │
#     └─────────────────────────────────┴─────────────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (19, 9)
#     ┌─────────────┬─────────────┬─────────────┬──────┬───┬────────────┬────────────┬──────┬────────────┐
#     │ name        ┆ smiles      ┆ amchi       ┆ spin ┆ … ┆ inchi      ┆ inchikey   ┆ mult ┆ canon_enan │
#     │ ---         ┆ ---         ┆ ---         ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---  ┆ t_ich      │
#     │ str         ┆ str         ┆ str         ┆ i64  ┆   ┆ str        ┆ str        ┆ i64  ┆ ---        │
#     │             ┆             ┆             ┆      ┆   ┆            ┆            ┆      ┆ str        │
#     ╞═════════════╪═════════════╪═════════════╪══════╪═══╪════════════╪════════════╪══════╪════════════╡
#     │ H           ┆ [H]         ┆ AMChI=1/H   ┆ 1    ┆ … ┆ InChI=1S/H ┆ YZCKVEUIGO ┆ 2    ┆ InChI=1S/H │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ ORGS-UHFFF ┆      ┆            │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ AOYSA-N    ┆      ┆            │
#     │ C5H6O-HSdVH ┆ C1CC2=C[C@@ ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ VHYOFFONUA ┆ 1    ┆ InChI=1S/C │
#     │ z-1         ┆ H]1O2       ┆ 6O/c1-4-2-3 ┆      ┆   ┆ 5H6O/c1-2- ┆ CUGT-SCSAI ┆      ┆ 5H6O/c1-2- │
#     │             ┆             ┆ -5(1)6-4…   ┆      ┆   ┆ 5-3-4(1)6- ┆ BSYSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H6O-HSdVH ┆ C1CC2=C[C@H ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ VHYOFFONUA ┆ 1    ┆ InChI=1S/C │
#     │ z-0         ┆ ]1O2        ┆ 6O/c1-4-2-3 ┆      ┆   ┆ 5H6O/c1-2- ┆ CUGT-BYPYZ ┆      ┆ 5H6O/c1-2- │
#     │             ┆             ┆ -5(1)6-4…   ┆      ┆   ┆ 5-3-4(1)6- ┆ UCNSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H6O-HSdI2 ┆ C1=C[C@@H]2 ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ QIDGNVMJBD ┆ 1    ┆ InChI=1S/C │
#     │ e-AB        ┆ C[C@H]1O2   ┆ 6O/c1-2-5-3 ┆      ┆   ┆ 5H6O/c1-2- ┆ TKKV-SYDPR ┆      ┆ 5H6O/c1-2- │
#     │             ┆             ┆ -4(1)6-5…   ┆      ┆   ┆ 5-3-4(1)6- ┆ GILSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H6O-HSdNT ┆ C=1C[C@H]2C ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ CGYDMVIZLV ┆ 1    ┆ InChI=1S/C │
#     │ 0-0         ┆ C=1O2       ┆ 6O/c1-2-5-3 ┆      ┆   ┆ 5H6O/c1-2- ┆ KWMA-YFKPB ┆      ┆ 5H6O/c1-2- │
#     │             ┆             ┆ -4(1)6-5…   ┆      ┆   ┆ 5-3-4(1)6- ┆ YRVSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ …           ┆ …           ┆ …           ┆ …    ┆ … ┆ …          ┆ …          ┆ …    ┆ …          │
#     │ C5H7O-WybPs ┆ [CH2]C[C@@H ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ QRLNFQNGRA ┆ 2    ┆ InChI=1S/C │
#     │ 7-1         ┆ ]1C=CO1     ┆ 7O/c1-4-5-2 ┆      ┆   ┆ 5H7O/c1-2- ┆ OPSN-RXMQY ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -3-6-5/h…   ┆      ┆   ┆ 5-3-4-6-5/ ┆ KEDSA-N    ┆      ┆ 5-3-4-6-5/ │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5x13r2-A ┆ C1C[C@@H]2[ ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ SQBNIHHRZY ┆ 2    ┆ InChI=1S/C │
#     │ B           ┆ CH][C@H]1O2 ┆ 7O/c1-4-2-3 ┆      ┆   ┆ 5H7O/c1-2- ┆ UNFP-SYDPR ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -5(1)6-4…   ┆      ┆   ┆ 5-3-4(1)6- ┆ GILSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5x13r1-0 ┆ C1C[C]2C[C@ ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ DHICDSXZDO ┆ 2    ┆ InChI=1S/C │
#     │             ┆ H]1O2       ┆ 7O/c1-2-5-3 ┆      ┆   ┆ 5H7O/c1-2- ┆ AZNP-BYPYZ ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -4(1)6-5…   ┆      ┆   ┆ 5-3-4(1)6- ┆ UCNSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O-Wybn7 ┆ C=C[C@@H]1C ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ MSNIZPPASS ┆ 2    ┆ InChI=1S/C │
#     │ G-1         ┆ [CH]O1      ┆ 7O/c1-2-5-4 ┆      ┆   ┆ 5H7O/c1-2- ┆ XLTR-RXMQY ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -3-6-5/h…   ┆      ┆   ┆ 5-3-4-6-5/ ┆ KEDSA-N    ┆      ┆ 5-3-4-6-5/ │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7OALOX-k ┆ [O]C1CC=CC1 ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ UFPUWZJIUY ┆ 2    ┆ InChI=1S/C │
#     │ JABeL       ┆             ┆ 7O/c6-5-3-1 ┆      ┆   ┆ 5H7O/c6-5- ┆ GICA-UHFFF ┆      ┆ 5H7O/c6-5- │
#     │             ┆             ┆ -2-4-5/h…   ┆      ┆   ┆ 3-1-2-4-5/ ┆ AOYSA-N    ┆      ┆ 3-1-2-4-5/ │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     └─────────────┴─────────────┴─────────────┴──────┴───┴────────────┴────────────┴──────┴────────────┘
#   ),
# )

# %%
automech.display(mech)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
