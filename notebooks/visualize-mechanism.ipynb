# %%
from pathlib import Path

import automech

# %%
mech_num = "01"
submech_leaf = "3submech_13epoxy"
# mech_tag = ""
# task_leaf = "1generate"
mech_tag = "_full"
task_leaf = "2stereoexpand"

dir_path = Path("..") / submech_leaf / task_leaf
assert dir_path.exists()

mech_path = dir_path / f"mechanism{mech_num}.dat{mech_tag}"
spc_path = dir_path / f"species{mech_num}.csv{mech_tag}"

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (24, 2)
#     ┌─────────────────────────────────┬─────────────────────────────────┐
#     │ eq                              ┆ rate                            │
#     │ ---                             ┆ ---                             │
#     │ str                             ┆ object                          │
#     ╞═════════════════════════════════╪═════════════════════════════════╡
#     │ cyC5x13-AB + H = cyC5x13r1-1 +… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13-AB + H = cyC5x13r2-AB … ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13-AB + H = cyC5x13r4-AB0… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13-AB + H = cyC5x13r4-AB1… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13-AB + O = cyC5x13r1-1 +… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                               ┆ …                               │
#     │ cyC5x13-AB + HO2 = cyC5x13r4-A… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13-AB + CH3 = cyC5x13r1-1… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13-AB + CH3 = cyC5x13r2-A… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13-AB + CH3 = cyC5x13r4-A… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13-AB + CH3 = cyC5x13r4-A… ┆ SimpleRate(k=ArrheniusFunction… │
#     └─────────────────────────────────┴─────────────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (15, 9)
#     ┌─────────────┬─────────────┬─────────────┬──────┬───┬────────────┬────────────┬──────┬────────────┐
#     │ name        ┆ smiles      ┆ amchi       ┆ spin ┆ … ┆ inchi      ┆ inchikey   ┆ mult ┆ canon_enan │
#     │ ---         ┆ ---         ┆ ---         ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---  ┆ t_ich      │
#     │ str         ┆ str         ┆ str         ┆ i64  ┆   ┆ str        ┆ str        ┆ i64  ┆ ---        │
#     │             ┆             ┆             ┆      ┆   ┆            ┆            ┆      ┆ str        │
#     ╞═════════════╪═════════════╪═════════════╪══════╪═══╪════════════╪════════════╪══════╪════════════╡
#     │ H           ┆ [H]         ┆ AMChI=1/H   ┆ 1    ┆ … ┆ InChI=1S/H ┆ YZCKVEUIGO ┆ 2    ┆ InChI=1S/H │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ ORGS-UHFFF ┆      ┆            │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ AOYSA-N    ┆      ┆            │
#     │ O           ┆ [O]         ┆ AMChI=1/O   ┆ 0    ┆ … ┆ InChI=1S/O ┆ QVGXLLKOCU ┆ 1    ┆ InChI=1S/O │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ KJST-UHFFF ┆      ┆            │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ AOYSA-N    ┆      ┆            │
#     │ H2          ┆ [H][H]      ┆ AMChI=1/H2/ ┆ 0    ┆ … ┆ InChI=1S/H ┆ UFHFLCQGNI ┆ 1    ┆ InChI=1S/H │
#     │             ┆             ┆ h1H         ┆      ┆   ┆ 2/h1H      ┆ YNRP-UHFFF ┆      ┆ 2/h1H      │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ AOYSA-N    ┆      ┆            │
#     │ O2          ┆ O=O         ┆ AMChI=1/O2/ ┆ 0    ┆ … ┆ InChI=1S/O ┆ MYMOFIZGZY ┆ 1    ┆ InChI=1S/O │
#     │             ┆             ┆ c1-2        ┆      ┆   ┆ 2/c1-2     ┆ HOMD-UHFFF ┆      ┆ 2/c1-2     │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ AOYSA-N    ┆      ┆            │
#     │ OH          ┆ [OH]        ┆ AMChI=1/HO/ ┆ 1    ┆ … ┆ InChI=1S/H ┆ TUJKJAMUKR ┆ 2    ┆ InChI=1S/H │
#     │             ┆             ┆ h1H         ┆      ┆   ┆ O/h1H      ┆ IRHC-UHFFF ┆      ┆ O/h1H      │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ AOYSA-N    ┆      ┆            │
#     │ …           ┆ …           ┆ …           ┆ …    ┆ … ┆ …          ┆ …          ┆ …    ┆ …          │
#     │ cyC5x13r2-A ┆ C1C[C@@H]2[ ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ SQBNIHHRZY ┆ 2    ┆ InChI=1S/C │
#     │ B           ┆ CH][C@H]1O2 ┆ 7O/c1-4-2-3 ┆      ┆   ┆ 5H7O/c1-2- ┆ UNFP-SYDPR ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -5(1)6-4…   ┆      ┆   ┆ 5-3-4(1)6- ┆ GILSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5x13r1-1 ┆ C1C[C]2C[C@ ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ DHICDSXZDO ┆ 2    ┆ InChI=1S/C │
#     │             ┆ @H]1O2      ┆ 7O/c1-2-5-3 ┆      ┆   ┆ 5H7O/c1-2- ┆ AZNP-SCSAI ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -4(1)6-5…   ┆      ┆   ┆ 5-3-4(1)6- ┆ BSYSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5x13r4-A ┆ [CH]1C[C@@H ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ FHIVWWHLNL ┆ 2    ┆ InChI=1S/C │
#     │ B0          ┆ ]2C[C@H]1O2 ┆ 7O/c1-2-5-3 ┆      ┆   ┆ 5H7O/c1-2- ┆ PBCN-CRCLS ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -4(1)6-5…   ┆      ┆   ┆ 5-3-4(1)6- ┆ JGQSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5x13r4-A ┆ [CH]1C[C@H] ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ FHIVWWHLNL ┆ 2    ┆ InChI=1S/C │
#     │ B1          ┆ 2C[C@@H]1O2 ┆ 7O/c1-2-5-3 ┆      ┆   ┆ 5H7O/c1-2- ┆ PBCN-UHNVW ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -4(1)6-5…   ┆      ┆   ┆ 5-3-4(1)6- ┆ ZDZSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5x13-AB  ┆ C1C[C@@H]2C ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ ZQCZKNJMUN ┆ 1    ┆ InChI=1S/C │
#     │             ┆ [C@H]1O2    ┆ 8O/c1-2-5-3 ┆      ┆   ┆ 5H8O/c1-2- ┆ AGGK-SYDPR ┆      ┆ 5H8O/c1-2- │
#     │             ┆             ┆ -4(1)6-5…   ┆      ┆   ┆ 5-3-4(1)6- ┆ GILSA-N    ┆      ┆ 5-3-4(1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     └─────────────┴─────────────┴─────────────┴──────┴───┴────────────┴────────────┴──────┴────────────┘
#   ),
# )

# %%
automech.display(mech)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
