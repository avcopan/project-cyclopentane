# %%
from pathlib import Path

import automech

# %%
mech_num = "04"
# submech_leaf = "1submech_ene"
# submech_leaf = "2submech_12epoxy"
submech_leaf = "3submech_13epoxy"
# task_leaf = "1generate"
# mech_tag = ""
task_leaf = "2stereoexpand"
mech_tag = "_full"

dir_path = Path("..") / submech_leaf / task_leaf
assert dir_path.exists()

mech_path = dir_path / f"mechanism{mech_num}.dat{mech_tag}"
spc_path = dir_path / f"species{mech_num}.csv{mech_tag}"

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/74 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (52, 2)
#     ┌─────────────────────────────────┬─────────────────────────────────┐
#     │ eq                              ┆ rate                            │
#     │ ---                             ┆ ---                             │
#     │ str                             ┆ object                          │
#     ╞═════════════════════════════════╪═════════════════════════════════╡
#     │ C5H7O3-JIEBqF-0 = C5H7O3-JIEsE… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-JIEBqF-0 = C5H7O3-JIEMb… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-JIEBqF-0 = C5H7O3-JIEJh… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-JIEBqF-0 = C5H7O3-JIEJh… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-JIEBqF-1 = C5H7O3-JIEXa… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                               ┆ …                               │
#     │ C5H7O3-xh24sz-0 = C5H7O3-xh2Yg… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-xh24sz-0 = C5H7O3-xh2Yd… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-xh24sz-0 = C5H7O3-xh2Vc… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-xh24sz-1 = C5H7O3-xh2Zc… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-xh24sz-1 = C5H7O3-xh2Yd… ┆ SimpleRate(k=ArrheniusFunction… │
#     └─────────────────────────────────┴─────────────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (74, 9)
#     ┌─────────────┬─────────────┬─────────────┬──────┬───┬────────────┬────────────┬──────┬────────────┐
#     │ name        ┆ smiles      ┆ amchi       ┆ spin ┆ … ┆ inchi      ┆ inchikey   ┆ mult ┆ canon_enan │
#     │ ---         ┆ ---         ┆ ---         ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---  ┆ t_ich      │
#     │ str         ┆ str         ┆ str         ┆ i64  ┆   ┆ str        ┆ str        ┆ i64  ┆ ---        │
#     │             ┆             ┆             ┆      ┆   ┆            ┆            ┆      ┆ str        │
#     ╞═════════════╪═════════════╪═════════════╪══════╪═══╪════════════╪════════════╪══════╪════════════╡
#     │ C5H7O3-UFb4 ┆ [O]OC[C@@H] ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ JMUQVSKSGJ ┆ 2    ┆ InChI=1S/C │
#     │ sz-0        ┆ 1CC=CO1     ┆ 7O3/c6-8-4- ┆      ┆   ┆ 5H7O3/c6-8 ┆ CDBV-YFKPB ┆      ┆ 5H7O3/c6-8 │
#     │             ┆             ┆ 5-3-1-2-…   ┆      ┆   ┆ -4-5-2-1-3 ┆ YRVSA-N    ┆      ┆ -4-5-2-1-3 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-JIEB ┆ C=C1C[C@H]( ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ BPMBGXLOTH ┆ 2    ┆ InChI=1S/C │
#     │ qF-1        ┆ CO[O])O1    ┆ 7O3/c1-4-2- ┆      ┆   ┆ 5H7O3/c1-4 ┆ PXLR-RXMQY ┆      ┆ 5H7O3/c1-4 │
#     │             ┆             ┆ 5(8-4)3-…   ┆      ┆   ┆ -2-5(8-4)3 ┆ KEDSA-N    ┆      ┆ -2-5(8-4)3 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-ZUdH ┆ OO[C@@H]1C[ ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ MKIHIMNTGO ┆ 2    ┆ InChI=1S/C │
#     │ 7Z-AA1      ┆ C]2C[C@H]1O ┆ 7O3/c6-8-5- ┆      ┆   ┆ 5H7O3/c6-8 ┆ NXDT-RFZPG ┆      ┆ 5H7O3/c6-8 │
#     │             ┆ 2           ┆ 2-3-1-4(…   ┆      ┆   ┆ -5-2-3-1-4 ┆ FLSSA-N    ┆      ┆ -5-2-3-1-4 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-ZUdP ┆ [O]O[C@@H]1 ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ UXKGYIBGCV ┆ 2    ┆ InChI=1S/C │
#     │ s7-ABB0     ┆ C[C@@H]2C[C ┆ 7O3/c6-8-5- ┆      ┆   ┆ 5H7O3/c6-8 ┆ CTHH-VPENI ┆      ┆ 5H7O3/c6-8 │
#     │             ┆ @H]1O2      ┆ 2-3-1-4(…   ┆      ┆   ┆ -5-2-3-1-4 ┆ NKCSA-N    ┆      ┆ -5-2-3-1-4 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-ZUdH ┆ OO[C@H]1C[C ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ MKIHIMNTGO ┆ 2    ┆ InChI=1S/C │
#     │ 7Z-AB1      ┆ ]2C[C@H]1O2 ┆ 7O3/c6-8-5- ┆      ┆   ┆ 5H7O3/c6-8 ┆ NXDT-UHNVW ┆      ┆ 5H7O3/c6-8 │
#     │             ┆             ┆ 2-3-1-4(…   ┆      ┆   ┆ -5-2-3-1-4 ┆ ZDZSA-N    ┆      ┆ -5-2-3-1-4 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ …           ┆ …           ┆ …           ┆ …    ┆ … ┆ …          ┆ …          ┆ …    ┆ …          │
#     │ C5H7O3-xh2V ┆ OOCC[C@@H]1 ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ VUURPFZOMD ┆ 2    ┆ InChI=1S/C │
#     │ cc-0        ┆ C=[C]O1     ┆ 7O3/c6-8-4- ┆      ┆   ┆ 5H7O3/c6-8 ┆ AAIA-YFKPB ┆      ┆ 5H7O3/c6-8 │
#     │             ┆             ┆ 3-5-2-1-…   ┆      ┆   ┆ -4-2-5-1-3 ┆ YRVSA-N    ┆      ┆ -4-2-5-1-3 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-xh2e ┆ OOCC[C]1C=C ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ OFPWRMJKNU ┆ 2    ┆ InChI=1S/C │
#     │ HU          ┆ O1          ┆ 7O3/c6-8-4- ┆      ┆   ┆ 5H7O3/c6-8 ┆ SLSR-UHFFF ┆      ┆ 5H7O3/c6-8 │
#     │             ┆             ┆ 3-5-1-2-…   ┆      ┆   ┆ -4-2-5-1-3 ┆ AOYSA-N    ┆      ┆ -4-2-5-1-3 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-xh24 ┆ [O]OCC[C@@H ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ NDTAGFSBRG ┆ 2    ┆ InChI=1S/C │
#     │ sz-0        ┆ ]1C=CO1     ┆ 7O3/c6-8-4- ┆      ┆   ┆ 5H7O3/c6-8 ┆ NQBN-YFKPB ┆      ┆ 5H7O3/c6-8 │
#     │             ┆             ┆ 3-5-1-2-…   ┆      ┆   ┆ -4-2-5-1-3 ┆ YRVSA-N    ┆      ┆ -4-2-5-1-3 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3-KcFX ┆ [CH2]/C=C1\ ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ AMChI=1/C5 ┆ GFYQHTQBUV ┆ 2    ┆ AMChI=1/C5 │
#     │ az-E0       ┆ C[C@@H](O1) ┆ 7O3/c1-2-4- ┆      ┆   ┆ H7O3/c1-2- ┆ AOID-FYTLM ┆      ┆ H7O3/c1-2- │
#     │             ┆ OO          ┆ 3-5(7-4)…   ┆      ┆   ┆ 4-3-5(7-4) ┆ ZHYNA-N    ┆      ┆ 4-3-5(7-4) │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O3KHP-T ┆ O=C1C[CH][C ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ YOCSUSGCCQ ┆ 2    ┆ InChI=1S/C │
#     │ 5Audv-0     ┆ @@H](C1)OO  ┆ 7O3/c6-4-2- ┆      ┆   ┆ 5H7O3/c6-4 ┆ AKLK-YFKPB ┆      ┆ 5H7O3/c6-4 │
#     │             ┆             ┆ 1-5(3-4)…   ┆      ┆   ┆ -1-2-5(3-4 ┆ YRVSA-N    ┆      ┆ -1-2-5(3-4 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     └─────────────┴─────────────┴─────────────┴──────┴───┴────────────┴────────────┴──────┴────────────┘
#   ),
# )

# %%
automech.display(mech)
# Out:
#   0%|          | 0/74 [00:00<?, ?it/s]
#   0%|          | 0/74 [00:00<?, ?it/s]
#   0%|          | 0/74 [00:00<?, ?it/s]
#   0%|          | 0/52 [00:00<?, ?it/s]
