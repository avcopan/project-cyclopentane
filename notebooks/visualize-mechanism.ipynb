# %%
from pathlib import Path

import automech

# %%
mech_num = "02"
submech_leaf = "1submech_ene"
# task_leaf = "1generate"
# mech_tag = ""
task_leaf = "2stereoexpand"
mech_tag = "_full"

dir_path = Path("..") / submech_leaf / task_leaf
assert dir_path.exists()

mech_path = dir_path / f"mechanism{mech_num}.dat{mech_tag}"
spc_path = dir_path / f"species{mech_num}.csv{mech_tag}"

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (12, 2)
#     ┌────────────────────────────┬─────────────────────────────────┐
#     │ eq                         ┆ rate                            │
#     │ ---                        ┆ ---                             │
#     │ str                        ┆ object                          │
#     ╞════════════════════════════╪═════════════════════════════════╡
#     │ cyC5e1r4 = C5H7-kSV85M-E   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1r4 = C5H6-FCWeGu + H ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1r3 = cyC5e1r4        ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1r3 = C5H7-kSVPs7-ZZ  ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1r3 = C5H6-FCWeGu + H ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                          ┆ …                               │
#     │ cyC5e1r1 = cyC5e1r3        ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1r1 = C5H7-kSVha0     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1r1 = C5H7-kSVBqF     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1r1 = C5H6-FCWkuc + H ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1r1 = C5H6-FCWKI4 + H ┆ SimpleRate(k=ArrheniusFunction… │
#     └────────────────────────────┴─────────────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (11, 9)
#     ┌─────────────┬─────────────┬─────────────┬──────┬───┬────────────┬────────────┬──────┬────────────┐
#     │ name        ┆ smiles      ┆ amchi       ┆ spin ┆ … ┆ inchi      ┆ inchikey   ┆ mult ┆ canon_enan │
#     │ ---         ┆ ---         ┆ ---         ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---  ┆ t_ich      │
#     │ str         ┆ str         ┆ str         ┆ i64  ┆   ┆ str        ┆ str        ┆ i64  ┆ ---        │
#     │             ┆             ┆             ┆      ┆   ┆            ┆            ┆      ┆ str        │
#     ╞═════════════╪═════════════╪═════════════╪══════╪═══╪════════════╪════════════╪══════╪════════════╡
#     │ H           ┆ [H]         ┆ AMChI=1/H   ┆ 1    ┆ … ┆ InChI=1S/H ┆ YZCKVEUIGO ┆ 2    ┆ InChI=1S/H │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ ORGS-UHFFF ┆      ┆            │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ AOYSA-N    ┆      ┆            │
#     │ C5H6-FCWeGu ┆ C=1C=CCC=1  ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ ZSWFCLXCOI ┆ 1    ┆ InChI=1S/C │
#     │             ┆             ┆ 6/c1-2-4-5- ┆      ┆   ┆ 5H6/c1-2-4 ┆ ISFI-UHFFF ┆      ┆ 5H6/c1-2-4 │
#     │             ┆             ┆ 3-1/h1-4…   ┆      ┆   ┆ -5-3-1/h1- ┆ AOYSA-N    ┆      ┆ -5-3-1/h1- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H6-FCWKI4 ┆ C=1CCC=C=1  ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ VRNCRGHDRG ┆ 1    ┆ InChI=1S/C │
#     │             ┆             ┆ 6/c1-2-4-5- ┆      ┆   ┆ 5H6/c1-2-4 ┆ GBLW-UHFFF ┆      ┆ 5H6/c1-2-4 │
#     │             ┆             ┆ 3-1/h2-3…   ┆      ┆   ┆ -5-3-1/h1, ┆ AOYSA-N    ┆      ┆ -5-3-1/h1, │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H6-FCWkuc ┆ C1CC#CC1    ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ CPGPQFYAGK ┆ 1    ┆ InChI=1S/C │
#     │             ┆             ┆ 6/c1-2-4-5- ┆      ┆   ┆ 5H6/c1-2-4 ┆ HQTB-UHFFF ┆      ┆ 5H6/c1-2-4 │
#     │             ┆             ┆ 3-1/h3-5…   ┆      ┆   ┆ -5-3-1/h1- ┆ AOYSA-N    ┆      ┆ -5-3-1/h1- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5e1r3    ┆ C1=CCC[CH]1 ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ MNLVCBKWEV ┆ 2    ┆ InChI=1S/C │
#     │             ┆             ┆ 7/c1-2-4-5- ┆      ┆   ┆ 5H7/c1-2-4 ┆ XHGE-UHFFF ┆      ┆ 5H7/c1-2-4 │
#     │             ┆             ┆ 3-1/h1-3…   ┆      ┆   ┆ -5-3-1/h1- ┆ AOYSA-N    ┆      ┆ -5-3-1/h1- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ …           ┆ …           ┆ …           ┆ …    ┆ … ┆ …          ┆ …          ┆ …    ┆ …          │
#     │ cyC5e1r4    ┆ C1=CC[CH]C1 ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ DABYZUWMLU ┆ 2    ┆ InChI=1S/C │
#     │             ┆             ┆ 7/c1-2-5-3- ┆      ┆   ┆ 5H7/c1-2-4 ┆ GAGP-UHFFF ┆      ┆ 5H7/c1-2-4 │
#     │             ┆             ┆ 4-1/h1-3…   ┆      ┆   ┆ -5-3-1/h1- ┆ AOYSA-N    ┆      ┆ -5-3-1/h1- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5e1r1    ┆ C=1CCC[C]=1 ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ NRADQUVNXZ ┆ 2    ┆ InChI=1S/C │
#     │             ┆             ┆ 7/c1-2-4-5- ┆      ┆   ┆ 5H7/c1-2-4 ┆ VPHN-UHFFF ┆      ┆ 5H7/c1-2-4 │
#     │             ┆             ┆ 3-1/h2H,…   ┆      ┆   ┆ -5-3-1/h1H ┆ AOYSA-N    ┆      ┆ -5-3-1/h1H │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7-kSVha0 ┆ C#CCC[CH2]  ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ LMYNWNXMBY ┆ 2    ┆ InChI=1S/C │
#     │             ┆             ┆ 7/c1-3-5-4- ┆      ┆   ┆ 5H7/c1-3-5 ┆ VPED-UHFFF ┆      ┆ 5H7/c1-3-5 │
#     │             ┆             ┆ 2/h1H,2,…   ┆      ┆   ┆ -4-2/h1H,2 ┆ AOYSA-N    ┆      ┆ -4-2/h1H,2 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7-kSV85M ┆ [H]/[C]=C/C ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ AMChI=1/C5 ┆ OOLQZHXELH ┆ 2    ┆ AMChI=1/C5 │
#     │ -E          ┆ C=C         ┆ 7/c1-3-5-4- ┆      ┆   ┆ H7/c1-3-5- ┆ HHFX-HNQUO ┆      ┆ H7/c1-3-5- │
#     │             ┆             ┆ 2/h1,3-4…   ┆      ┆   ┆ 4-2/h1,3-4 ┆ IGGNA-N    ┆      ┆ 4-2/h1,3-4 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7-kSVBqF ┆ [CH2]CC=C=C ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ UFKWMZADYV ┆ 2    ┆ InChI=1S/C │
#     │             ┆             ┆ 7/c1-3-4-5- ┆      ┆   ┆ 5H7/c1-3-5 ┆ JUNL-UHFFF ┆      ┆ 5H7/c1-3-5 │
#     │             ┆             ┆ 2/h4H,1-…   ┆      ┆   ┆ -4-2/h5H,1 ┆ AOYSA-N    ┆      ┆ -4-2/h5H,1 │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     └─────────────┴─────────────┴─────────────┴──────┴───┴────────────┴────────────┴──────┴────────────┘
#   ),
# )

# %%
automech.display(mech)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
