# %%
from pathlib import Path

import automech

# %%
mech_num = "04"
# submech_leaf = "1submech_ene"
# submech_leaf = "2submech_12epoxy"
submech_leaf = "3submech_13epoxy"
task_leaf = "1generate"
mech_tag = ""
# task_leaf = "2stereoexpand"
# mech_tag = "_full"

dir_path = Path("..") / submech_leaf / task_leaf
assert dir_path.exists()

mech_path = dir_path / f"mechanism{mech_num}.dat{mech_tag}"
spc_path = dir_path / f"species{mech_num}.csv{mech_tag}"

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/73 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (82, 2)
#     ┌─────────────────────────────────┬─────────────────────────────────┐
#     │ eq                              ┆ rate                            │
#     │ ---                             ┆ ---                             │
#     │ str                             ┆ object                          │
#     ╞═════════════════════════════════╪═════════════════════════════════╡
#     │ cyC5x13r1 = cyC5x13r4           ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O-Wybn7G + O2 = C5H7O3-KcF… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O-WybPs7 + O2 = C5H7O3-xh2… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13 + O2 = cyC5x13r2 + HO2  ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x13r4 = C5H7OALOX-kJABeL    ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                               ┆ …                               │
#     │ C5H7O3-UFb4sz = C5H7O3-UFbYgo   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-UFb4sz = C5H7O3-UFbYdY   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-UFb4sz = C5H7O3-UFbVcc   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-UFb4sz = C5H7O3-UFbZcg   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-UFb4sz = C5H7O3-UFbeHU   ┆ SimpleRate(k=ArrheniusFunction… │
#     └─────────────────────────────────┴─────────────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (73, 8)
#     ┌───────────────┬──────────────┬──────────────┬──────┬────────┬──────────────┬──────────────┬──────┐
#     │ name          ┆ smiles       ┆ amchi        ┆ spin ┆ charge ┆ inchi        ┆ inchikey     ┆ mult │
#     │ ---           ┆ ---          ┆ ---          ┆ ---  ┆ ---    ┆ ---          ┆ ---          ┆ ---  │
#     │ str           ┆ str          ┆ str          ┆ i64  ┆ i64    ┆ str          ┆ str          ┆ i64  │
#     ╞═══════════════╪══════════════╪══════════════╪══════╪════════╪══════════════╪══════════════╪══════╡
#     │ H             ┆ [H]          ┆ AMChI=1/H    ┆ 1    ┆ 0      ┆ InChI=1S/H   ┆ YZCKVEUIGOOR ┆ 2    │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ GS-UHFFFAOYS ┆      │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ H2            ┆ [H][H]       ┆ AMChI=1/H2/h ┆ 0    ┆ 0      ┆ InChI=1S/H2/ ┆ UFHFLCQGNIYN ┆ 1    │
#     │               ┆              ┆ 1H           ┆      ┆        ┆ h1H          ┆ RP-UHFFFAOYS ┆      │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ O             ┆ [O]          ┆ AMChI=1/O    ┆ 2    ┆ 0      ┆ InChI=1S/O   ┆ QVGXLLKOCUKJ ┆ 3    │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ ST-UHFFFAOYS ┆      │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ OH            ┆ [OH]         ┆ AMChI=1/HO/h ┆ 1    ┆ 0      ┆ InChI=1S/HO/ ┆ TUJKJAMUKRIR ┆ 2    │
#     │               ┆              ┆ 1H           ┆      ┆        ┆ h1H          ┆ HC-UHFFFAOYS ┆      │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ H2O           ┆ O            ┆ AMChI=1/H2O/ ┆ 0    ┆ 0      ┆ InChI=1S/H2O ┆ XLYOFNOQVPJJ ┆ 1    │
#     │               ┆              ┆ h1H2         ┆      ┆        ┆ /h1H2        ┆ NP-UHFFFAOYS ┆      │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ …             ┆ …            ┆ …            ┆ …    ┆ …      ┆ …            ┆ …            ┆ …    │
#     │ C5H7O3-UFbYgo ┆ OOCC1C[C]=CO ┆ AMChI=1/C5H7 ┆ 1    ┆ 0      ┆ InChI=1S/C5H ┆ XCERRFHWLQIG ┆ 2    │
#     │               ┆ 1            ┆ O3/c6-8-4-5- ┆      ┆        ┆ 7O3/c6-8-4-5 ┆ CC-UHFFFAOYS ┆      │
#     │               ┆              ┆ 3-1-2-…      ┆      ┆        ┆ -2-1-3…      ┆ A-N          ┆      │
#     │ C5H7O3-UFbYdY ┆ OOCC1C=C[CH] ┆ AMChI=1/C5H7 ┆ 1    ┆ 0      ┆ InChI=1S/C5H ┆ FSPRTUZXJXPB ┆ 2    │
#     │               ┆ O1           ┆ O3/c6-8-4-5- ┆      ┆        ┆ 7O3/c6-8-4-5 ┆ BX-UHFFFAOYS ┆      │
#     │               ┆              ┆ 2-1-3-…      ┆      ┆        ┆ -2-1-3…      ┆ A-N          ┆      │
#     │ C5H7O3-UFbVcc ┆ OOCC1CC=[C]O ┆ AMChI=1/C5H7 ┆ 1    ┆ 0      ┆ InChI=1S/C5H ┆ LHXCABWODLFU ┆ 2    │
#     │               ┆ 1            ┆ O3/c6-8-4-5- ┆      ┆        ┆ 7O3/c6-8-4-5 ┆ PG-UHFFFAOYS ┆      │
#     │               ┆              ┆ 3-2-1-…      ┆      ┆        ┆ -2-1-3…      ┆ A-N          ┆      │
#     │ C5H7O3-UFbZcg ┆ OO[CH]C1CC=C ┆ AMChI=1/C5H7 ┆ 1    ┆ 0      ┆ InChI=1S/C5H ┆ UCJBUZMQJAGU ┆ 2    │
#     │               ┆ O1           ┆ O3/c6-8-3-5- ┆      ┆        ┆ 7O3/c6-8-4-5 ┆ JN-UHFFFAOYS ┆      │
#     │               ┆              ┆ 4-1-2-…      ┆      ┆        ┆ -2-1-3…      ┆ A-N          ┆      │
#     │ C5H7O3-UFbeHU ┆ OOC[C]1CC=CO ┆ AMChI=1/C5H7 ┆ 1    ┆ 0      ┆ InChI=1S/C5H ┆ XMFXKOBYHMWB ┆ 2    │
#     │               ┆ 1            ┆ O3/c6-8-4-5- ┆      ┆        ┆ 7O3/c6-8-4-5 ┆ DU-UHFFFAOYS ┆      │
#     │               ┆              ┆ 3-1-2-…      ┆      ┆        ┆ -2-1-3…      ┆ A-N          ┆      │
#     └───────────────┴──────────────┴──────────────┴──────┴────────┴──────────────┴──────────────┴──────┘
#   ),
# )

# %%
automech.display(mech)
# Out:
#   0%|          | 0/73 [00:00<?, ?it/s]
#   0%|          | 0/73 [00:00<?, ?it/s]
#   0%|          | 0/73 [00:00<?, ?it/s]
#   0%|          | 0/82 [00:00<?, ?it/s]
