# %%
from pathlib import Path

import automech

# %%
mech_num = "02"
# submech_leaf = "1submech_ene"
submech_leaf = "2submech_12epoxy"
# task_leaf = "1generate"
# mech_tag = ""
task_leaf = "2stereoexpand"
mech_tag = "_full"

dir_path = Path("..") / submech_leaf / task_leaf
assert dir_path.exists()

mech_path = dir_path / f"mechanism{mech_num}.dat{mech_tag}"
spc_path = dir_path / f"species{mech_num}.csv{mech_tag}"

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (15, 2)
#     ┌─────────────────────────────────┬─────────────────────────────────┐
#     │ eq                              ┆ rate                            │
#     │ ---                             ┆ ---                             │
#     │ str                             ┆ object                          │
#     ╞═════════════════════════════════╪═════════════════════════════════╡
#     │ cyC5x12r1-0 = C5H7OKET-kJAyrZ   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12r1-0 = C5H7O-prCBqF-0    ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12r1-0 = C5H7O-8C8vJN      ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12r1-0 = C5H6O-d50kuc + H  ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12r1-0 = C5H6O-d50G4j-0 +… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                               ┆ …                               │
#     │ cyC5x12r3-AB1 = C5H6O-d50I2e-A… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12r4-AB = C5H7O-8C8n7G-1   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12r4-AB = C5H6O-d50I2e-AB… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12r4-AB = C5H6O-d50I2e-AB… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12r1-1 = C5H6O-d50G4j-1 +… ┆ SimpleRate(k=ArrheniusFunction… │
#     └─────────────────────────────────┴─────────────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (18, 9)
#     ┌─────────────┬─────────────┬─────────────┬──────┬───┬────────────┬────────────┬──────┬────────────┐
#     │ name        ┆ smiles      ┆ amchi       ┆ spin ┆ … ┆ inchi      ┆ inchikey   ┆ mult ┆ canon_enan │
#     │ ---         ┆ ---         ┆ ---         ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---  ┆ t_ich      │
#     │ str         ┆ str         ┆ str         ┆ i64  ┆   ┆ str        ┆ str        ┆ i64  ┆ ---        │
#     │             ┆             ┆             ┆      ┆   ┆            ┆            ┆      ┆ str        │
#     ╞═════════════╪═════════════╪═════════════╪══════╪═══╪════════════╪════════════╪══════╪════════════╡
#     │ H           ┆ [H]         ┆ AMChI=1/H   ┆ 1    ┆ … ┆ InChI=1S/H ┆ YZCKVEUIGO ┆ 2    ┆ InChI=1S/H │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ ORGS-UHFFF ┆      ┆            │
#     │             ┆             ┆             ┆      ┆   ┆            ┆ AOYSA-N    ┆      ┆            │
#     │ C5H6O-d50I2 ┆ C1=C[C@H]2[ ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ ASZFCDOTGI ┆ 1    ┆ InChI=1S/C │
#     │ e-AB0       ┆ C@@H](C1)O2 ┆ 6O/c1-2-4-5 ┆      ┆   ┆ 5H6O/c1-2- ┆ TCJI-CRCLS ┆      ┆ 5H6O/c1-2- │
#     │             ┆             ┆ (6-4)3-1…   ┆      ┆   ┆ 4-5(3-1)6- ┆ JGQSA-N    ┆      ┆ 4-5(3-1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H6O-d50I2 ┆ C1=C[C@@H]2 ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ ASZFCDOTGI ┆ 1    ┆ InChI=1S/C │
#     │ e-AB1       ┆ [C@H](C1)O2 ┆ 6O/c1-2-4-5 ┆      ┆   ┆ 5H6O/c1-2- ┆ TCJI-UHNVW ┆      ┆ 5H6O/c1-2- │
#     │             ┆             ┆ (6-4)3-1…   ┆      ┆   ┆ 4-5(3-1)6- ┆ ZDZSA-N    ┆      ┆ 4-5(3-1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H6O-d50G4 ┆ C1C=C2[C@H] ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ PWKZHHLFGB ┆ 1    ┆ InChI=1S/C │
#     │ j-0         ┆ (C1)O2      ┆ 6O/c1-2-3-5 ┆      ┆   ┆ 5H6O/c1-2- ┆ EELG-YFKPB ┆      ┆ 5H6O/c1-2- │
#     │             ┆             ┆ -4(1)6-5…   ┆      ┆   ┆ 4-5(3-1)6- ┆ YRVSA-N    ┆      ┆ 4-5(3-1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H6O-d50ku ┆ C1CC2=C(C1) ┆ AMChI=1/C5H ┆ 0    ┆ … ┆ InChI=1S/C ┆ DJQGARJHMZ ┆ 1    ┆ InChI=1S/C │
#     │ c           ┆ O2          ┆ 6O/c1-2-4-5 ┆      ┆   ┆ 5H6O/c1-2- ┆ LWPJ-UHFFF ┆      ┆ 5H6O/c1-2- │
#     │             ┆             ┆ (6-4)3-1…   ┆      ┆   ┆ 4-5(3-1)6- ┆ AOYSA-N    ┆      ┆ 4-5(3-1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ …           ┆ …           ┆ …           ┆ …    ┆ … ┆ …          ┆ …          ┆ …    ┆ …          │
#     │ cyC5x12r3-A ┆ C1[CH][C@@H ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ HMGKAGDNMR ┆ 2    ┆ InChI=1S/C │
#     │ B1          ┆ ]2[C@H](C1) ┆ 7O/c1-2-3-5 ┆      ┆   ┆ 5H7O/c1-2- ┆ SUEK-UHNVW ┆      ┆ 5H7O/c1-2- │
#     │             ┆ O2          ┆ -4(1)6-5…   ┆      ┆   ┆ 4-5(3-1)6- ┆ ZDZSA-N    ┆      ┆ 4-5(3-1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ cyC5x12r3-A ┆ C1[CH][C@H] ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ HMGKAGDNMR ┆ 2    ┆ InChI=1S/C │
#     │ B0          ┆ 2[C@@H](C1) ┆ 7O/c1-2-3-5 ┆      ┆   ┆ 5H7O/c1-2- ┆ SUEK-CRCLS ┆      ┆ 5H7O/c1-2- │
#     │             ┆ O2          ┆ -4(1)6-5…   ┆      ┆   ┆ 4-5(3-1)6- ┆ JGQSA-N    ┆      ┆ 4-5(3-1)6- │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O-8C8vJ ┆ [CH2]CCC1=C ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ GMIZXUDQUV ┆ 2    ┆ InChI=1S/C │
#     │ N           ┆ O1          ┆ 7O/c1-3-4-5 ┆      ┆   ┆ 5H7O/c1-2- ┆ LSBQ-UHFFF ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -2-6-5/h…   ┆      ┆   ┆ 3-5-4-6-5/ ┆ AOYSA-N    ┆      ┆ 3-5-4-6-5/ │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O-8C8n7 ┆ C=CC[C@@H]1 ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ SISRIUZRNJ ┆ 2    ┆ InChI=1S/C │
#     │ G-1         ┆ [CH]O1      ┆ 7O/c1-2-4-5 ┆      ┆   ┆ 5H7O/c1-2- ┆ BXBS-RXMQY ┆      ┆ 5H7O/c1-2- │
#     │             ┆             ┆ -3-6-5/h…   ┆      ┆   ┆ 3-5-4-6-5/ ┆ KEDSA-N    ┆      ┆ 3-5-4-6-5/ │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     │ C5H7O-prCPs ┆ C=C[C@@H]1[ ┆ AMChI=1/C5H ┆ 1    ┆ … ┆ InChI=1S/C ┆ CRYRPHILLG ┆ 2    ┆ InChI=1S/C │
#     │ 7-AB0       ┆ C@H]([CH2]) ┆ 7O/c1-3-5-4 ┆      ┆   ┆ 5H7O/c1-3- ┆ DPLH-CRCLS ┆      ┆ 5H7O/c1-3- │
#     │             ┆ O1          ┆ (2)6-5/h…   ┆      ┆   ┆ 5-4(2)6-5/ ┆ JGQSA-N    ┆      ┆ 5-4(2)6-5/ │
#     │             ┆             ┆             ┆      ┆   ┆ …          ┆            ┆      ┆ …          │
#     └─────────────┴─────────────┴─────────────┴──────┴───┴────────────┴────────────┴──────┴────────────┘
#   ),
# )

# %%
automech.display(mech)
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
