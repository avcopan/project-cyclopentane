# %%
from importlib import reload

from automech import _mech

reload(_mech)

o = _mech.Mechanism(
    reactions={"A": [1, 2, 3], "B": [4, 5, 6]}, species={"C": [1, 2], "D": [3, 4]}
)
o.model_dump_json()
# Out:
# '{"reactions":{"A":[1,2,3],"B":[4,5,6]},"species":{"C":[1,2],"D":[3,4]},"thermo_temps":null}'
