# %%
from pathlib import Path

import util
from util import workflow

browser = False
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# # Build
# import automech

# sub_tags = ["A_rh-oh_p1v0", "A_rh-oh_p2v2", "B_rh-ho2_p1v1"]
# sub_mechs = [automech.io.read(data_path / f"{t}_raw.json") for t in sub_tags]
# mech = automech.combine_all(sub_mechs)
# print(mech)

# %%
# # Write
# workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)

# %%
# Read
workflow.read(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/3246 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/S_all_v1_calc.json
# ../data/full_S_all_v1_control.json
# ../data/full_S_all_v1_calc.json
# ../data/chemkin/full_S_all_v1_control.dat
# ../data/chemkin/full_S_all_v1_calc.dat
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Read
# ----> 2 workflow.read(tag=tag, root_path=root_path)
#
# File /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/notebooks/util/workflow.py:110, in read(tag, root_path)
#     108 automech.io.chemkin.write.mechanism(mech0, data_path / "chemkin" / f"{full0}.dat")
#     109 print(data_path / "chemkin" / f"{full}.dat")
# --> 110 automech.io.chemkin.write.mechanism(mech, data_path / "chemkin" / f"{full}.dat")
#     112 # Compare calculated to parent mechanism
#     113 print("\nCompare calculated mechanism to parent mechanism...")
#
# File /lcrc/project/PACC/copan/amech-dev/src/automech/io/chemkin/write.py:38, in mechanism(mech, out, fill_rates)
#      24 def mechanism(
#      25     mech: Mechanism, out: str | Path | None = None, fill_rates: bool = False
#      26 ) -> str:
#      27     """Write a mechanism to CHEMKIN format.
#      28
#      29     :param mech: A mechanism
#    (...)
#      32     :return: The CHEMKIN mechanism as a string
#      33     """
#      34     blocks = [
#      35         elements_block(mech),
#      36         species_block(mech),
#      37         thermo_block(mech),
# ---> 38         reactions_block(mech, fill_rates=fill_rates),
#      39     ]
#      40     mech_str = "\n\n\n".join(b for b in blocks if b is not None)
#      41     if out is not None:
#
# File /lcrc/project/PACC/copan/amech-dev/src/automech/io/chemkin/write.py:130, in reactions_block(mech, frame, fill_rates)
#     128 # Add reaction objects
#     129 obj_col = c_.temp()
# --> 130 rxn_df = reaction.with_rate_objects(rxn_df, obj_col, fill=fill_rates)
#     132 # Add reaction equations to determine apppropriate width
#     133 eq_col = c_.temp()
#
# File /lcrc/project/PACC/copan/amech-dev/src/automech/reaction.py:318, in with_rate_objects(rxn_df, col, fill)
#     310     rxn_df = with_rates(rxn_df)
#     312 cols = [
#     313     Reaction.reactants,
#     314     Reaction.products,
#     315     ReactionRate.reversible,
#     316     ReactionRate.rate_constant,
#     317 ]
# --> 318 return rxn_df.with_columns(
#     319     polars.struct(cols)
#     320     .map_elements(autochem.rate.Rate.model_validate, return_dtype=polars.Object)
#     321     .alias(col)
#     322 )
#
# File /lcrc/project/PACC/copan/amech-dev/.pixi/envs/proto/lib/python3.11/site-packages/polars/dataframe/frame.py:9589, in DataFrame.with_columns(self, *exprs, **named_exprs)
#    9443 def with_columns(
#    9444     self,
#    9445     *exprs: IntoExpr | Iterable[IntoExpr],
#    9446     **named_exprs: IntoExpr,
#    9447 ) -> DataFrame:
#    9448     """
#    9449     Add columns to this DataFrame.
#    9450
#    (...)
#    9587     └─────┴──────┴─────────────┘
#    9588     """
# -> 9589     return self.lazy().with_columns(*exprs, **named_exprs).collect(_eager=True)
#
# File /lcrc/project/PACC/copan/amech-dev/.pixi/envs/proto/lib/python3.11/site-packages/polars/lazyframe/frame.py:2066, in LazyFrame.collect(self, type_coercion, _type_check, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, streaming, engine, background, _check_order, _eager, **_kwargs)
#    2064 # Only for testing purposes
#    2065 callback = _kwargs.get("post_opt_callback", callback)
# -> 2066 return wrap_df(ldf.collect(callback))
#
# ComputeError: ValidationError: 2 validation errors for Rate
# reversible
#   Input should be a valid boolean [type=bool_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/bool_type
# rate_constant
#   Input should be a valid dictionary or instance of RateConstant [type=model_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/model_type

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)

# %%
# # Plot
# charts = workflow.plot(
#     full_tag=f"full_{tag}_calc",
#     x_col="O2_molecules",
#     y_col_=["C5H8(522)", "C5H8O(825)rs"],
#     root_path=root_path,
#     line_source_=["hill", "lokachari"],
#     point_source="experiment",
# )
# for chart in charts:
#     chart.show()
