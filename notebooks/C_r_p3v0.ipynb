# %%
from pathlib import Path

import util
from util import workflow

browser = False
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")

# %%
# # Build
# from automol.graph import enum

# import automech

# par_mech = workflow.read_parent_mechanism(root_path=root_path)
# mech = automech.from_smiles(
#     spc_smis=["C1(O)[CH]CCC1"],
#     src_mech=par_mech,
# )
# #  - add ring beta scissions
# mech = automech.enumerate_reactions(
#     mech,
#     enum.ReactionSmarts.ring_beta_scission,
#     src_mech=par_mech,
# )
# automech.display(mech)

# %%
# # Write
# workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)

# %%
# Read
workflow.prepare_simulation(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/31 [00:00<?, ?it/s]
# Writing mechanism to JSON...
#
# Writing mechanism to Chemkin...
# Control: ../data/chemkin/full_C_r_p3v0_control.dat
# Calculated: ../data/chemkin/full_C_r_p3v0_calc.dat
#
# Converting ChemKin mechanism to Cantera YAML...
# Wrote YAML mechanism file to '../data/cantera/full_C_r_p3v0_control.yaml'.
# Mechanism contains 2537 species and 10037 reactions.
# Wrote YAML mechanism file to '../data/cantera/full_C_r_p3v0_calc.yaml'.
# Mechanism contains 2537 species and 10045 reactions.
#
# Validating Cantera model...
# ---------------------------------------------------------------------------
# CanteraError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Read
# ----> 2 workflow.prepare_simulation(tag=tag, root_path=root_path)
#
# File /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/notebooks/util/workflow.py:151, in prepare_simulation(tag, root_path)
#     145 Parser.convert_mech(
#     146     cal_path,
#     147     out_name=p_.full_calculated_mechanism(tag, "yaml", path=p_.cantera(root_path)),
#     148 )
#     150 print("\nValidating Cantera model...")
# --> 151 cantera.Solution(
#     152     p_.full_calculated_mechanism(tag, "yaml", path=p_.cantera(root_path))
#     153 )
#
# File build/python/cantera/solutionbase.pyx:37, in cantera.solutionbase._SolutionBase.__cinit__()
#
# File build/python/cantera/solutionbase.pyx:75, in cantera.solutionbase._SolutionBase._cinit()
#
# File build/python/cantera/solutionbase.pyx:160, in cantera.solutionbase._SolutionBase._init_yaml()
#
# CanteraError:
# *******************************************************************************
# CanteraError thrown by addReactions:
#
# *******************************************************************************
# InputFileError thrown by PlogRate::validate:
# Error on line 59012 of ./../data/cantera/full_C_r_p3v0_calc.yaml:
#
# Invalid rate coefficient for reaction 'C5H9O(852)r1 <=> C5H9O(852)r0'
# at P = 1.0132e+05, T = 300.0
# at P = 1.0132e+05, T = 500.0
# at P = 1.0132e+05, T = 1000.0
# at P = 1.0132e+05, T = 2000.0
# at P = 1.0132e+05, T = 5000.0
# at P = 1.0132e+05, T = 10000.0
#
# To fix this error, remove this reaction or contact the author of the
# reaction/mechanism in question, because the rate expression is
# mathematically unsound at the temperatures and pressures noted above.
#
# |  Line |
# |  59007 |   - {P: 1.0 atm, A: 8.286e+18, b: -2.126, Ea: 2.8248e+04}
# |  59008 |   - {P: 10.0 atm, A: 6.084e+20, b: -2.848, Ea: 3.0347e+04}
# |  59009 |   - {P: 10.0 atm, A: 3.905e+127, b: -33.1, Ea: 1.0259e+05}
# |  59010 |   - {P: 100.0 atm, A: 8.992e+30, b: -5.334, Ea: 4.4667e+04}
# |  59011 |   - {P: 100.0 atm, A: 6.339e+17, b: -2.46, Ea: 2.8164e+04}
# >  59012 > - equation: C5H9O(852)r1 <=> C5H9O(852)r0  # Reaction 10043
#             ^
# |  59013 |   type: pressure-dependent-Arrhenius
# |  59014 |   rate-constants:
# |  59015 |   - {P: 0.1 atm, A: 5.303e-28, b: 12.75, Ea: 2.3674e+04}
# *******************************************************************************
# *******************************************************************************

# %%
# # Plot
# charts = workflow.plot(
#     full_tag=f"full_{tag}_calc",
#     x_col="O2_molecules",
#     y_col_=["C5H8(522)", "C5H8O(825)rs"],
#     root_path=root_path,
#     line_source_=["hill", "lokachari"],
#     point_source="experiment",
# )
# for chart in charts:
#     chart.show()

# %%
# import automech
# from mechdriver.subtasks import display

# chan = "1: 6"

# # TRANSITION STATE
# #   - Read in expanded mechanism
# mech_path = util.p_.mechanism(tag, ext="json", path=util.p_.data(root_path))
# mech = automech.io.read(mech_path)

# #   - Display the reaction
# automech.display_reactions(mech, chans=[chan])

# %%
# #   - Display the TS mode
# calc_path = util.p_.calc(root_path, tag)
# display("conf_opt", chan, path=calc_path)

# %%
# #   - Display the TS mode
# calc_path = util.p_.calc(root_path, tag)
# display("find_ts", chan, path=calc_path)

# %%
# # REACTION RATE
# #   - Read in calculated mechanism
# cal_mech = automech.io.read(data_path / f"{tag}_calc.json")

# #   - Read in other mechanisms for comparison
# par_mech = automech.io.read(data_path / "full_raw.json")
# tags0 = util.previous_tags(tag)
# trues = [True] * len(tags0)
# names0 = list(map(util.calculated_mechanism_name, tags0))
# mechs0 = [automech.io.read(data_path / f"{name}.json") for name in names0]

# #   - Display the reaction and calculated rate
# automech.display_reactions(
#     cal_mech,
#     chans=[chan],
#     comp_mechs=[par_mech, *mechs0],
#     comp_labels=["Hill", *tags0],
#     comp_stereo=[False, *trues],
# )
