# %%
from pathlib import Path

import automech

# %%
DATA_PATH = Path("../data")

# %%
mech = automech.io.read(DATA_PATH / "full_raw.json")

# %%
automech.display_species(mech, ["N#N"], "smiles")
# Out:
# smiles: N#N
# name: N2
