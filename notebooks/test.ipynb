# %%
import autochem

# %%
chem_str = """
S(1100) (+ M) = C8H8(1050) + H2O(5) (+ M)                               3.530E+13      0.000      67260
    LOW   /                                                             1.990E+81     -18.59      78190/
    TROE  /                                                     0.1300      1.000 8940000000 9330000000/
"""

rate = autochem.rate.from_chemkin_string(chem_str)
print(autochem.rate.chemkin_string(rate))
# Out:
# rate.is_pressure_dependent = True
# S(1100) (+ M) = C8H8(1050) + H2O(5) (+ M)                3.530E+13      0.000      67260
#     LOW   /                                              1.990E+81     -18.59      78190/
#     TROE  /                                      0.1300      1.000 8940000000 9330000000/
