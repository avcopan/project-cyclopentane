# %%
import automol
from automol.graph import enum

# %%
gra = ({0: ('C', 0, None), 1: ('C', 0, None), 2: ('C', 0, None), 3: ('C', 0, None), 4: ('C', 0, None), 5: ('O', 0, None), 6: ('H', 0, None), 7: ('H', 0, None), 8: ('H', 0, None), 9: ('H', 0, None), 10: ('H', 0, None), 11: ('H', 0, None), 12: ('H', 0, None), 13: ('H', 0, None), 14: ('H', 0, None)}, {frozenset({3, 4}): (1, None), frozenset({0, 6}): (1, None), frozenset({1, 7}): (1, None), frozenset({2, 3}): (1, None), frozenset({1, 2}): (1, None), frozenset({4, 5}): (1, None), frozenset({0, 1}): (1, None), frozenset({2, 10}): (1, None), frozenset({4, 13}): (1, None), frozenset({5, 14}): (1, None), frozenset({0, 4}): (1, None), frozenset({8, 1}): (1, None), frozenset({3, 12}): (1, None), frozenset({3, 11}): (1, None), frozenset({9, 2}): (1, None)})
automol.graph.display(gra)

# %%
from importlib import reload

reload(enum)
enum.products(enum.ReactionSmarts.beta_scission, gra)
# Out:
# [({0: ('C', 0, None),
#    1: ('C', 0, None),
#    2: ('C', 0, None),
#    3: ('C', 0, None),
#    4: ('C', 0, None),
#    5: ('O', 0, None),
#    6: ('H', 0, None),
#    7: ('H', 0, None),
#    8: ('H', 0, None),
#    9: ('H', 0, None),
#    10: ('H', 0, None),
#    11: ('H', 0, None),
#    12: ('H', 0, None),
#    13: ('H', 0, None),
#    14: ('H', 0, None)},
#   {frozenset({5, 14}): (1, None),
#    frozenset({0, 4}): (1, None),
#    frozenset({4, 13}): (1, None),
#    frozenset({0, 1}): (1, None),
#    frozenset({0, 6}): (1, None),
#    frozenset({3, 4}): (1, None),
#    frozenset({3, 12}): (1, None),
#    frozenset({2, 3}): (1, None),
#    frozenset({2, 10}): (1, None),
#    frozenset({3, 11}): (1, None),
#    frozenset({1, 2}): (1, None),
#    frozenset({1, 7}): (1, None),
#    frozenset({2, 9}): (1, None),
#    frozenset({1, 8}): (1, None)})]
