# %%
from pathlib import Path

import automech

# %%
DATA_PATH = Path("../data")

# %%
mech = automech.io.read(DATA_PATH / "full_raw.json")

# %%
automech.display_species(mech, ["CC=O"], "smiles")
# Out:
# smiles: O=CC
# name: CH3CHO(41)
