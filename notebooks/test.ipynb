# %%
from importlib import reload

from automech.data import rate

# %%
reload(rate)

k = rate.ArrheniusFunction(A=1.0, b=2.0, E=3.0)
print(dict(k))
# Out:
# {'A': 1.0, 'b': 2.0, 'E': 3.0, 'B': None, 'C': None}

# %%
reload(rate)

# f = rate.BlendingFunction(type_="LIND")
f = rate.BlendingFunction()
print(dict(f))
# Out:
# {'type_': 'Lind', 'coeffs': None}

# %%
reload(rate)

# r = rate.SimpleRate(type_="constant")
r = rate.SimpleRate()
# print(dict(r))
print(r.model_dump())
# Out:
# {'is_rev': True, 'type_': 'Constant', 'k': {'A': 1.0, 'b': 0.0, 'E': 0.0, 'B': None, 'C': None}, 'k0': None, 'f': None}
