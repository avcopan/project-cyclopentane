# %%
from pathlib import Path

import automech

# %%
DATA_PATH = Path("../data")

# %%
mech = automech.io.read(DATA_PATH / "full_raw.json")

# %%
automech.display_species(mech, ["S(1431)", "C5H9O(852)"])
# Out:
# name: C5H9O(852)
# smiles: OC1CCC[CH]1
# name: S(1431)
# smiles: OC(CC=C)[CH2]
