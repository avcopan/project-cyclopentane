# %%
from pathlib import Path

import automech

# %%
DATA_PATH = Path("../data")

# %%
mech = automech.io.read(DATA_PATH / "full_raw.json")

# %%
automech.display_species(mech, ["O1C2CCC[C]12", "[CH]1CCCC1=O"], spc_key_="smiles")
# Out:
# smiles: [O]C=1CCCC=1
# name: C5H7O(690)
# smiles: O1C2CCC[C]12
# name: S(1314)
