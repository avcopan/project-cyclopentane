# %%
from pathlib import Path

import util
from util import workflow

browser = False
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")

# %%
# # Build
# from automol.graph import enum

# import automech
# from automech.species import Species

# par_mech = workflow.read_parent_mechanism(root_path=root_path)
# mech = automech.from_smiles(
#     spc_smis=["C1(O)[CH]CCC1"],
#     src_mech=par_mech,
# )
# #  - O2 additions
# mech = automech.enumerate_reactions(
#     mech,
#     enum.ReactionSmarts.o2_addition,
#     rcts_=[None, "[O][O]"],
#     spc_col_=Species.smiles,
#     src_mech=par_mech,
# )
# #  - HO2 elimination
# mech = automech.enumerate_reactions(
#     mech,
#     enum.ReactionSmarts.ho2_elimination,
#     spc_col_=Species.smiles,
#     src_mech=par_mech,
# )
# automech.display(mech)

# %%
# # Write
# workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)

# %%
# # Read
# workflow.read(tag=tag, root_path=root_path)

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)

# %%
# # Plot
# charts = workflow.plot(
#     full_tag=f"full_{tag}_calc",
#     x_col="O2_molecules",
#     y_col_=["C5H8(522)", "C5H8O(825)rs"],
#     root_path=root_path,
#     line_source_=["hill", "lokachari"],
#     point_source="experiment",
# )
# for chart in charts:
#     chart.show()

# %%
import automech
from mechdriver.subtasks import display

chan = "1: 10"

# TRANSITION STATE
#   - Read in expanded mechanism
mech_path = util.p_.mechanism(tag, ext="json", path=util.p_.data(root_path))
mech = automech.io.read(mech_path)

#   - Display the reaction
# automech.display_reactions(mech, chans=[chan])
automech.display_species(mech, ["S(594)rr1"])
# Out:
# name: S(594)rr1
# smiles: [O]O[C@@H]1CCC[C@H]1O

# %%
#   - Display the TS mode
calc_path = util.p_.calc(root_path, tag)
display("conf_opt", "11", path=calc_path)
# Out:
# ----
# /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save/SPC/C5H9O3/ZUNHHSMBPLJENU/0/2/WHFBIAKZSA-N/hJUhMUU/CONFS/r22iDVJ7LAmFq/cPz5nWADgL4W0
# Lowest frequency mode:
#   frequency: 36.114483093569824
#
# ----
# /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save/SPC/C5H9O3/ZUNHHSMBPLJENU/0/2/WHFBIAKZSA-N/hJUhMUU/CONFS/r4eoZjezNZx5h/cGBeJBJFelWqi
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 #   - Display the TS mode
#       2 calc_path = util.p_.calc(root_path, tag)
# ----> 3 display("conf_opt", "11", path=calc_path)
#
# File /lcrc/project/PACC/copan/amech-dev/src/mechdriver/mechdriver/subtasks/_3view.py:36, in display(task_key, subtask_key, path, runlvl, animate)
#      33 disp_ = task_display_function(task_key)
#      35 for task_path in fs.task_paths(task_key, subtask_key, path=path, runlvl=runlvl):
# ---> 36     disp_(task_path)
#
# File /lcrc/project/PACC/copan/amech-dev/src/mechdriver/mechdriver/subtasks/_3view.py:54, in _display_conf_hess(task_path)
#      52 print(path)
#      53 geo = cnf_fs[-1].file.geometry.read(cnf_loc)
# ---> 54 hess = cnf_fs[-1].file.hessian.read(cnf_loc)
#      55 freqs, norm_coos = automol.geom.vibrational_analysis(geo, hess)
#      56 norm_coo = norm_coos[:, 0]
#
# File /lcrc/project/PACC/copan/amech-dev/src/autofile/autofile/model.py:417, in DataSeriesFile.read(self, locs)
#     413 def read(self, locs=()):
#     414     """ read data from this file
#     415
#     416     """
# --> 417     return self.file.read(self.dir.path(locs))
#
# File /lcrc/project/PACC/copan/amech-dev/src/autofile/autofile/model.py:74, in DataFile.read(self, dir_pth)
#      66 def read(self, dir_pth):
#      67     """ read data from this file
#      68
#      69     :param dir_pth: directory path
#    (...)
#      72     :return type: int/float/str/tuple
#      73     """
# ---> 74     assert self.exists(dir_pth), (
#      75         f'Either requested file {self}',
#      76         f'or requested path does not exist {dir_pth}'
#      77     )
#      79     pth = self.path(dir_pth)
#      80     val_str = autofile.io_.read_file(pth)
#
# AssertionError: ("Either requested file DataFile('hess.hess')", 'or requested path does not exist /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save/SPC/C5H9O3/ZUNHHSMBPLJENU/0/2/WHFBIAKZSA-N/hJUhMUU/CONFS/r4eoZjezNZx5h/cGBeJBJFelWqi')

# %%
#   - Display the TS mode
calc_path = util.p_.calc(root_path, tag)
display("conf_opt", chan, path=calc_path)

# %%
#   - Display the TS mode
calc_path = util.p_.calc(root_path, tag)
display("find_ts", chan, path=calc_path)

# %%
# # REACTION RATE
# #   - Read in calculated mechanism
# cal_mech = automech.io.read(data_path / f"{tag}_calc.json")

# #   - Read in other mechanisms for comparison
# par_mech = automech.io.read(data_path / "full_raw.json")
# tags0 = util.previous_tags(tag)
# trues = [True] * len(tags0)
# names0 = list(map(util.calculated_mechanism_name, tags0))
# mechs0 = [automech.io.read(data_path / f"{name}.json") for name in names0]

# #   - Display the reaction and calculated rate
# automech.display_reactions(
#     cal_mech,
#     chans=[chan],
#     comp_mechs=[par_mech, *mechs0],
#     comp_labels=["Hill", *tags0],
#     comp_stereo=[False, *trues],
# )
