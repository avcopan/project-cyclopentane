# %%
from pathlib import Path

import util
from util import workflow

browser = True
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# Build
from automol.graph import enum

import automech
from automech.species import Species

mech0 = automech.io.read(data_path / "full_raw.json")
mech = automech.from_smiles(spc_smis=["C1=CCCC1"], src_mech=mech0)
#  - add OH addition to *ene*
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.pi2_addition,
    rcts_=[None, "[OH]"],
    spc_col_=Species.smiles,
    src_mech=mech0,
)
#  - add H-migrations
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.h_migration,
    spc_col_=Species.smiles,
    src_mech=mech0,
    repeat=2
)
#  - add ring beta scissions
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.ring_beta_scission,
    src_mech=mech0,
)
#  - add H-migrations
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.h_migration,
    spc_col_=Species.smiles,
    src_mech=mech0,
    repeat=2
)
#  - add ring beta scissions
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.ring_beta_scission,
    src_mech=mech0,
)
#  - add beta scissions
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.beta_scission,
    src_mech=mech0,
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(automech.reaction_count(mech))
print(automech.species_count(mech))
# Out:
# 147
# 94

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)
# Out:
# Finalizing build for...
# reactions=shape: (147, 5)
# ┌────────────────┬────────────────────────────┬───────────┬────────────┬───────────────────────────┐
# │ reactants      ┆ products                   ┆ formula   ┆ reversible ┆ rate_constant             │
# │ ---            ┆ ---                        ┆ ---       ┆ ---        ┆ ---                       │
# │ list[str]      ┆ list[str]                  ┆ struct[3] ┆ bool       ┆ struct[17]                │
# ╞════════════════╪════════════════════════════╪═══════════╪════════════╪═══════════════════════════╡
# │ ["C5H9O(852)"] ┆ ["S(1248)"]                ┆ {5,9,1}   ┆ true       ┆ {1,{null,null,null,null,n │
# │                ┆                            ┆           ┆            ┆ ull,n…                    │
# │ ["C5H9O(852)"] ┆ ["S(1247)"]                ┆ {5,9,1}   ┆ true       ┆ {1,{null,null,null,null,n │
# │                ┆                            ┆           ┆            ┆ ull,n…                    │
# │ ["CPTOJ(880)"] ┆ ["C5H9O(852)"]             ┆ {5,9,1}   ┆ true       ┆ {1,{null,null,null,null,n │
# │                ┆                            ┆           ┆            ┆ ull,n…                    │
# │ ["S(1248)"]    ┆ ["S(1247)"]                ┆ {5,9,1}   ┆ true       ┆ {1,{null,null,null,null,n │
# │                ┆                            ┆           ┆            ┆ ull,n…                    │
# │ ["S(1248)"]    ┆ ["CPTOJ(880)"]             ┆ {5,9,1}   ┆ true       ┆ {1,{null,null,null,null,n │
# │                ┆                            ┆           ┆            ┆ ull,n…                    │
# │ …              ┆ …                          ┆ …         ┆ …          ┆ …                         │
# │ ["C5H9O(894)"] ┆ ["C4H6O(360)", "CH3(29)"]  ┆ {5,9,1}   ┆ null       ┆ null                      │
# │ ["C2H4(52)",   ┆ ["S(1528)"]                ┆ {5,9,1}   ┆ true       ┆ {2,{null,null,null,null,n │
# │ "C3H5O(186)"]  ┆                            ┆           ┆            ┆ ull,n…                    │
# │ ["OH(4)",      ┆ ["S(1396)"]                ┆ {5,9,1}   ┆ true       ┆ {2,{null,null,null,null,n │
# │ "C5H8(1365)"]  ┆                            ┆           ┆            ┆ ull,n…                    │
# │ ["C5Ofatwfw"]  ┆ ["C4H6O(331)", "CH3(29)"]  ┆ {5,9,1}   ┆ null       ┆ null                      │
# │ ["C2H4(52)",   ┆ ["C5H9O(896)"]             ┆ {5,9,1}   ┆ true       ┆ {2,{null,null,null,null,n │
# │ "C3H5O(105)"]  ┆                            ┆           ┆            ┆ ull,n…                    │
# └────────────────┴────────────────────────────┴───────────┴────────────┴───────────────────────────┘ species=shape: (94, 7)
# ┌────────────┬───────────────┬─────────────────┬──────┬────────┬─────────────────┬─────────────────┐
# │ name       ┆ smiles        ┆ amchi           ┆ spin ┆ charge ┆ formula         ┆ thermo_string   │
# │ ---        ┆ ---           ┆ ---             ┆ ---  ┆ ---    ┆ ---             ┆ ---             │
# │ str        ┆ str           ┆ str             ┆ i64  ┆ i64    ┆ struct[7]       ┆ str             │
# ╞════════════╪═══════════════╪═════════════════╪══════╪════════╪═════════════════╪═════════════════╡
# │ C5H9O(852) ┆ OC1CCC[CH]1   ┆ AMChI=1/C5H9O/c ┆ 1    ┆ 0      ┆ {9,1,null,null, ┆ C   5H   9O   1 │
# │            ┆               ┆ 6-5-1-2-3-4-5/h ┆      ┆        ┆ null,5,null}    ┆ G   298.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ C5H8(522)  ┆ C1CC=CC1      ┆ AMChI=1/C5H8/c1 ┆ 0    ┆ 0      ┆ {8,null,null,nu ┆ C   5H   8      │
# │            ┆               ┆ -2-4-5-3-1/h1-2 ┆      ┆        ┆ ll,null,5,null} ┆ G   298.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ OH(4)      ┆ [OH]          ┆ AMChI=1/HO/h1H  ┆ 1    ┆ 0      ┆ {1,1,null,null, ┆ H   1O   1      │
# │            ┆               ┆                 ┆      ┆        ┆ null,null,null} ┆ G   200.00…     │
# │ C5H9O(878) ┆ OC(C[CH2])C=C ┆ AMChI=1/C5H9O/c ┆ 1    ┆ 0      ┆ {9,1,null,null, ┆ C   5H   9O   1 │
# │            ┆               ┆ 1-3-5(6)4-2/h3, ┆      ┆        ┆ null,5,null}    ┆ G   300.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ C3H5O(168) ┆ O[CH]C=C      ┆ AMChI=1/C3H5O/c ┆ 1    ┆ 0      ┆ {5,1,null,null, ┆ C   3H   5O   1 │
# │            ┆               ┆ 1-2-3-4/h2-4H,1 ┆      ┆        ┆ null,3,null}    ┆ G   100.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ …          ┆ …             ┆ …               ┆ …    ┆ …      ┆ …               ┆ …               │
# │ C5Opzlxqn  ┆ [CH2]C=C(CC)O ┆ AMChI=1/C5H9O/c ┆ 1    ┆ 0      ┆ {9,1,null,null, ┆ null            │
# │            ┆               ┆ 1-3-5(6)4-2/h3, ┆      ┆        ┆ null,5,null}    ┆                 │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ C5Olylssu  ┆ [CH]=CCC(C)O  ┆ AMChI=1/C5H9O/c ┆ 1    ┆ 0      ┆ {9,1,null,null, ┆ null            │
# │            ┆               ┆ 1-3-4-5(2)6/h1, ┆      ┆        ┆ null,5,null}    ┆                 │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ S(1247)    ┆ O[C]1CCCC1    ┆ AMChI=1/C5H9O/c ┆ 1    ┆ 0      ┆ {9,1,null,null, ┆ C   5H   9O   1 │
# │            ┆               ┆ 6-5-3-1-2-4-5/h ┆      ┆        ┆ null,5,null}    ┆ G   100.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ S(1521)    ┆ O[C]=CCCC     ┆ AMChI=1/C5H9O/c ┆ 1    ┆ 0      ┆ {9,1,null,null, ┆ C   5H   9O   1 │
# │            ┆               ┆ 1-4-5-3-2-6/h3, ┆      ┆        ┆ null,5,null}    ┆ G   100.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ C5Ogbioie  ┆ [CH]=CC(CC)O  ┆ AMChI=1/C5H9O/c ┆ 1    ┆ 0      ┆ {9,1,null,null, ┆ null            │
# │            ┆               ┆ 1-3-5(6)4-2/h1, ┆      ┆        ┆ null,5,null}    ┆                 │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# └────────────┴───────────────┴─────────────────┴──────┴────────┴─────────────────┴─────────────────┘ thermo_temps=None
#
# Expanding stereochemistry...
#   0%|          | 0/94 [00:00<?, ?it/s]
#   0%|          | 0/143 [00:00<?, ?it/s]
#   0%|          | 0/147 [00:00<?, ?it/s]

# %%
# # Read
# workflow.read(tag=tag, root_path=root_path)

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)
