# %%
from pathlib import Path

import util
from util import workflow

browser = True
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# Build
from automol.graph import enum

import automech
from automech.species import Species

mech0 = automech.io.read(data_path / "full_raw.json")
mech = automech.from_smiles(spc_smis=["C1=CCCC1", "C12C(O2)CCC1"], src_mech=mech0)
#  - enumerate OH abstractions from *ene* and *1-2epoxy*
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.abstraction,
    rcts_=[None, "[OH]"],
    spc_col_=Species.smiles,
    src_mech=mech0,
)
#  - add H-migrations
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.h_migration,
    spc_col_=Species.smiles,
    src_mech=mech0,
    repeat=2
)
#  - add ring beta scissions
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.ring_beta_scission,
    src_mech=mech0,
)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)
# Out:
# Finalizing build for...
# reactions=shape: (22, 5)
# ┌────────────────┬────────────────┬────────────┬────────────┬─────────────────────────────────┐
# │ reactants      ┆ products       ┆ formula    ┆ reversible ┆ rate_constant                   │
# │ ---            ┆ ---            ┆ ---        ┆ ---        ┆ ---                             │
# │ list[str]      ┆ list[str]      ┆ struct[3]  ┆ bool       ┆ struct[17]                      │
# ╞════════════════╪════════════════╪════════════╪════════════╪═════════════════════════════════╡
# │ ["C5H7(1202)"] ┆ ["C5H7(500)"]  ┆ {5,7,null} ┆ true       ┆ {1,{null,null,null,null,null,n… │
# │ ["C5H7(1202)"] ┆ ["C5H7(504)"]  ┆ {5,7,null} ┆ true       ┆ {1,{null,null,null,null,null,n… │
# │ ["C5H7(504)"]  ┆ ["C5H7(500)"]  ┆ {5,7,null} ┆ true       ┆ {1,{null,null,null,null,null,n… │
# │ ["C5H7O(758)"] ┆ ["S(1289)"]    ┆ {5,7,1}    ┆ true       ┆ {1,{null,null,null,null,null,n… │
# │ ["S(1289)"]    ┆ ["S(1314)"]    ┆ {5,7,1}    ┆ true       ┆ {1,{null,null,null,null,null,n… │
# │ …              ┆ …              ┆ …          ┆ …          ┆ …                               │
# │ ["C5H7O(690)"] ┆ ["S(1314)"]    ┆ {5,7,1}    ┆ true       ┆ {1,{null,null,null,null,null,n… │
# │ ["C5H7(507)"]  ┆ ["C5H7(500)"]  ┆ {5,7,null} ┆ true       ┆ {1,{null,null,null,null,null,n… │
# │ ["C5H7O(758)"] ┆ ["C5H7O(746)"] ┆ {5,7,1}    ┆ true       ┆ {1,{null,null,null,null,null,n… │
# │ ["S(1512)"]    ┆ ["S(1289)"]    ┆ {5,7,1}    ┆ true       ┆ {1,{null,null,null,null,null,n… │
# │ ["C5H7O(758)"] ┆ ["C5H7O(762)"] ┆ {5,7,1}    ┆ true       ┆ {1,{null,null,null,null,null,n… │
# └────────────────┴────────────────┴────────────┴────────────┴─────────────────────────────────┘ species=shape: (20, 7)
# ┌────────────┬──────────────┬──────────────────┬──────┬────────┬─────────────────┬─────────────────┐
# │ name       ┆ smiles       ┆ amchi            ┆ spin ┆ charge ┆ formula         ┆ thermo_string   │
# │ ---        ┆ ---          ┆ ---              ┆ ---  ┆ ---    ┆ ---             ┆ ---             │
# │ str        ┆ str          ┆ str              ┆ i64  ┆ i64    ┆ struct[7]       ┆ str             │
# ╞════════════╪══════════════╪══════════════════╪══════╪════════╪═════════════════╪═════════════════╡
# │ C5H7(1202) ┆ C1CC=[C]C1   ┆ AMChI=1/C5H7/c1- ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
# │            ┆              ┆ 2-4-5-3-1/h2H,…  ┆      ┆        ┆ ll,null,5,null} ┆ G   100.00…     │
# │ C5H7ozvusw ┆ C=C=CC[CH2]  ┆ AMChI=1/C5H7/c1- ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ null            │
# │            ┆              ┆ 3-4-5-2/h4H,1-…  ┆      ┆        ┆ ll,null,5,null} ┆                 │
# │ C5H7(500)  ┆ C1C[CH]C=C1  ┆ AMChI=1/C5H7/c1- ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
# │            ┆              ┆ 2-4-5-3-1/h1-3…  ┆      ┆        ┆ ll,null,5,null} ┆ G   298.00…     │
# │ C5H7(507)  ┆ C=C[CH]C=C   ┆ AMChI=1/C5H7/c1- ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
# │            ┆              ┆ 3-5-4-2/h3-5H,…  ┆      ┆        ┆ ll,null,5,null} ┆ G   298.00…     │
# │ C5H7(504)  ┆ C1[CH]CC=C1  ┆ AMChI=1/C5H7/c1- ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
# │            ┆              ┆ 2-5-3-4-1/h1-3…  ┆      ┆        ┆ ll,null,5,null} ┆ G   298.00…     │
# │ …          ┆ …            ┆ …                ┆ …    ┆ …      ┆ …               ┆ …               │
# │ C5H7O(690) ┆ [O]C=1CCCC=1 ┆ AMChI=1/C5H7O/c6 ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
# │            ┆              ┆ -5-1-2-3-4-5/h…  ┆      ┆        ┆ null,5,null}    ┆ G   300.00…     │
# │ C5H8(522)  ┆ C1CC=CC1     ┆ AMChI=1/C5H8/c1- ┆ 0    ┆ 0      ┆ {8,null,null,nu ┆ C   5H   8      │
# │            ┆              ┆ 2-4-5-3-1/h1-2…  ┆      ┆        ┆ ll,null,5,null} ┆ G   298.00…     │
# │ H2O(5)     ┆ O            ┆ AMChI=1/H2O/h1H2 ┆ 0    ┆ 0      ┆ {2,1,null,null, ┆ H   2O   1      │
# │            ┆              ┆                  ┆      ┆        ┆ null,null,null} ┆ G   200.00…     │
# │ OH(4)      ┆ [OH]         ┆ AMChI=1/HO/h1H   ┆ 1    ┆ 0      ┆ {1,1,null,null, ┆ H   1O   1      │
# │            ┆              ┆                  ┆      ┆        ┆ null,null,null} ┆ G   200.00…     │
# │ C5H8O(825) ┆ O1C2C1CCC2   ┆ AMChI=1/C5H8O/c1 ┆ 0    ┆ 0      ┆ {8,1,null,null, ┆ C   5H   8O   1 │
# │            ┆              ┆ -2-4-5(6-4)3-1…  ┆      ┆        ┆ null,5,null}    ┆ G   300.00…     │
# └────────────┴──────────────┴──────────────────┴──────┴────────┴─────────────────┴─────────────────┘ thermo_temps=None
#
# Expanding stereochemistry...
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/C_r_p1v0_raw.json
# ../data/C_r_p1v0.json
# ../data/mechanalyzer/C_r_p1v0.dat
# ../data/mechanalyzer/C_r_p1v0.csv
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
# Stereoexpansion errors:
#
# *********
# Reaction: C5H7O(758) = S(1314)
# Translations:
#   smiles:
#     reactants = ['O1C2C1[CH]CC2']
#     products = ['O1C2CCC[C]12']
# Rate parameters:
#   This work:
#     C5H7O(758) = S(1314)                                     7.250E+10     0.6000      36900
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)

# %%
# # Read
# workflow.read(tag=tag, root_path=root_path)

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)

# %%
# # Plot
# charts = workflow.plot(
#     full_tag=f"full_{tag}_calc",
#     x_col="O2_molecules",
#     y_col_=["C5H8(522)", "C5H8O(825)rs"],
#     root_path=root_path,
#     line_source_=["hill", "lokachari"],
#     point_source="experiment",
# )
# for chart in charts:
#     chart.show()
