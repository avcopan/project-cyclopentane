# %%
from pathlib import Path

import util
from util import workflow

browser = False
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# Build
import automech

sub_tags = ["A_rh-oh_p1v0", "B_rh-ho2_p1v1"]
sub_mechs = [automech.io.read(data_path / f"{t}_raw.json") for t in sub_tags]
mech = automech.combine_all(sub_mechs)
print(mech)
# Out:
# Mechanism(
#   reactions=DataFrame(
#     shape: (14, 5)
#     ┌────────────────┬────────────────┬───────────┬──────────────────────────┬─────────────────────────┐
#     │ reactants      ┆ products       ┆ formula   ┆ rate                     ┆ colliders               │
#     │ ---            ┆ ---            ┆ ---       ┆ ---                      ┆ ---                     │
#     │ list[str]      ┆ list[str]      ┆ struct[3] ┆ struct[7]                ┆ struct[11]              │
#     ╞════════════════╪════════════════╪═══════════╪══════════════════════════╪═════════════════════════╡
#     │ ["C5H7(1202)", ┆ ["C5H8(522)",  ┆ {5,9,1}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "H2O(5)"]      ┆ "OH(4)"]       ┆           ┆                          ┆ ll,null…                │
#     │ ["C5H8(522)",  ┆ ["C5H7(500)",  ┆ {5,9,1}   ┆ {{4.04e6,2.2,-0.437},tru ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "H2O(5)"]      ┆           ┆ e,"Con…                  ┆ ll,null…                │
#     │ ["C5H8(522)",  ┆ ["C5H7(504)",  ┆ {5,9,1}   ┆ {{1.67e7,1.779,-0.193},t ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "H2O(5)"]      ┆           ┆ rue,"C…                  ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["H2O(5)",     ┆ {5,9,2}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "S(1289)"]     ┆           ┆                          ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["C5H7O(758)", ┆ {5,9,2}   ┆ {{3.35e7,1.779,-0.193},t ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "H2O(5)"]      ┆           ┆ rue,"C…                  ┆ ll,null…                │
#     │ …              ┆ …              ┆ …         ┆ …                        ┆ …                       │
#     │ ["C5H8(522)",  ┆ ["C5H7(500)",  ┆ {5,9,2}   ┆ {{0.782,3.968,11.702},tr ┆ {null,null,null,null,nu │
#     │ "HO2(8)"]      ┆ "H2O2(10)"]    ┆           ┆ ue,"Co…                  ┆ ll,null…                │
#     │ ["C5H8(522)",  ┆ ["C5H7(504)",  ┆ {5,9,2}   ┆ {{94.8,3.37,13.719},true ┆ {null,null,null,null,nu │
#     │ "HO2(8)"]      ┆ "H2O2(10)"]    ┆           ┆ ,"Cons…                  ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["H2O2(10)",   ┆ {5,9,3}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "HO2(8)"]      ┆ "S(1289)"]     ┆           ┆                          ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["C5H7O(758)", ┆ {5,9,3}   ┆ {{126.0,3.37,13.719},tru ┆ {null,null,null,null,nu │
#     │ "HO2(8)"]      ┆ "H2O2(10)"]    ┆           ┆ e,"Con…                  ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["H2O2(10)",   ┆ {5,9,3}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "HO2(8)"]      ┆ "S(1314)"]     ┆           ┆                          ┆ ll,null…                │
#     └────────────────┴────────────────┴───────────┴──────────────────────────┴─────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (13, 7)
#     ┌────────────┬───────────────┬─────────────────┬──────┬────────┬─────────────────┬─────────────────┐
#     │ name       ┆ smiles        ┆ amchi           ┆ spin ┆ charge ┆ formula         ┆ thermo_string   │
#     │ ---        ┆ ---           ┆ ---             ┆ ---  ┆ ---    ┆ ---             ┆ ---             │
#     │ str        ┆ str           ┆ str             ┆ i64  ┆ i64    ┆ struct[6]       ┆ str             │
#     ╞════════════╪═══════════════╪═════════════════╪══════╪════════╪═════════════════╪═════════════════╡
#     │ H2O(5)     ┆ O             ┆ AMChI=1/H2O/h1H ┆ 0    ┆ 0      ┆ {2,1,null,null, ┆ H   2O   1      │
#     │            ┆               ┆ 2               ┆      ┆        ┆ null,null}      ┆ G   200.00…     │
#     │ C5H8(522)  ┆ C1CC=CC1      ┆ AMChI=1/C5H8/c1 ┆ 0    ┆ 0      ┆ {8,null,null,nu ┆ C   5H   8      │
#     │            ┆               ┆ -2-4-5-3-1/h1-2 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H8O(825) ┆ O1C2C1CCC2    ┆ AMChI=1/C5H8O/c ┆ 0    ┆ 0      ┆ {8,1,null,null, ┆ C   5H   8O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   300.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ HO2(8)     ┆ O[O]          ┆ AMChI=1/HO2/c1- ┆ 1    ┆ 0      ┆ {1,2,null,null, ┆ H   1O   2      │
#     │            ┆               ┆ 2/h2H           ┆      ┆        ┆ null,null}      ┆ G   200.00…     │
#     │ S(722)     ┆ OOC1CCC[CH]1  ┆ AMChI=1/C5H9O2/ ┆ 1    ┆ 0      ┆ {9,2,null,null, ┆ C   5H   9O   2 │
#     │            ┆               ┆ c6-7-5-1-2-3-4- ┆      ┆        ┆ null,5}         ┆ G   300.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ …          ┆ …             ┆ …               ┆ …    ┆ …      ┆ …               ┆ …               │
#     │ C5H7(500)  ┆ C1C[CH]C=C1   ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
#     │            ┆               ┆ -2-4-5-3-1/h1-3 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H7(504)  ┆ C1[CH]CC=C1   ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
#     │            ┆               ┆ -2-5-3-4-1/h1-3 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ S(1289)    ┆ O1C2C1C[CH]C2 ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   100.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H7O(758) ┆ O1C2C1[CH]CC2 ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-3-5-4(1)6-5 ┆      ┆        ┆ null,5}         ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ S(1314)    ┆ O1C2CCC[C]12  ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   100.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     └────────────┴───────────────┴─────────────────┴──────┴────────┴─────────────────┴─────────────────┘
#   ),
#   rate_units=('KCAL/MOLE', 'MOLES'),
#   thermo_temps=None,
# )

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)
# Out:
# Finalizing build for...
# Mechanism(
#   reactions=DataFrame(
#     shape: (14, 5)
#     ┌────────────────┬────────────────┬───────────┬──────────────────────────┬─────────────────────────┐
#     │ reactants      ┆ products       ┆ formula   ┆ rate                     ┆ colliders               │
#     │ ---            ┆ ---            ┆ ---       ┆ ---                      ┆ ---                     │
#     │ list[str]      ┆ list[str]      ┆ struct[3] ┆ struct[7]                ┆ struct[11]              │
#     ╞════════════════╪════════════════╪═══════════╪══════════════════════════╪═════════════════════════╡
#     │ ["C5H7(1202)", ┆ ["C5H8(522)",  ┆ {5,9,1}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "H2O(5)"]      ┆ "OH(4)"]       ┆           ┆                          ┆ ll,null…                │
#     │ ["C5H8(522)",  ┆ ["C5H7(500)",  ┆ {5,9,1}   ┆ {{4.04e6,2.2,-0.437},tru ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "H2O(5)"]      ┆           ┆ e,"Con…                  ┆ ll,null…                │
#     │ ["C5H8(522)",  ┆ ["C5H7(504)",  ┆ {5,9,1}   ┆ {{1.67e7,1.779,-0.193},t ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "H2O(5)"]      ┆           ┆ rue,"C…                  ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["H2O(5)",     ┆ {5,9,2}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "S(1289)"]     ┆           ┆                          ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["C5H7O(758)", ┆ {5,9,2}   ┆ {{3.35e7,1.779,-0.193},t ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "H2O(5)"]      ┆           ┆ rue,"C…                  ┆ ll,null…                │
#     │ …              ┆ …              ┆ …         ┆ …                        ┆ …                       │
#     │ ["C5H8(522)",  ┆ ["C5H7(500)",  ┆ {5,9,2}   ┆ {{0.782,3.968,11.702},tr ┆ {null,null,null,null,nu │
#     │ "HO2(8)"]      ┆ "H2O2(10)"]    ┆           ┆ ue,"Co…                  ┆ ll,null…                │
#     │ ["C5H8(522)",  ┆ ["C5H7(504)",  ┆ {5,9,2}   ┆ {{94.8,3.37,13.719},true ┆ {null,null,null,null,nu │
#     │ "HO2(8)"]      ┆ "H2O2(10)"]    ┆           ┆ ,"Cons…                  ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["H2O2(10)",   ┆ {5,9,3}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "HO2(8)"]      ┆ "S(1289)"]     ┆           ┆                          ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["C5H7O(758)", ┆ {5,9,3}   ┆ {{126.0,3.37,13.719},tru ┆ {null,null,null,null,nu │
#     │ "HO2(8)"]      ┆ "H2O2(10)"]    ┆           ┆ e,"Con…                  ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["H2O2(10)",   ┆ {5,9,3}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "HO2(8)"]      ┆ "S(1314)"]     ┆           ┆                          ┆ ll,null…                │
#     └────────────────┴────────────────┴───────────┴──────────────────────────┴─────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (13, 7)
#     ┌────────────┬───────────────┬─────────────────┬──────┬────────┬─────────────────┬─────────────────┐
#     │ name       ┆ smiles        ┆ amchi           ┆ spin ┆ charge ┆ formula         ┆ thermo_string   │
#     │ ---        ┆ ---           ┆ ---             ┆ ---  ┆ ---    ┆ ---             ┆ ---             │
#     │ str        ┆ str           ┆ str             ┆ i64  ┆ i64    ┆ struct[6]       ┆ str             │
#     ╞════════════╪═══════════════╪═════════════════╪══════╪════════╪═════════════════╪═════════════════╡
#     │ H2O(5)     ┆ O             ┆ AMChI=1/H2O/h1H ┆ 0    ┆ 0      ┆ {2,1,null,null, ┆ H   2O   1      │
#     │            ┆               ┆ 2               ┆      ┆        ┆ null,null}      ┆ G   200.00…     │
#     │ C5H8(522)  ┆ C1CC=CC1      ┆ AMChI=1/C5H8/c1 ┆ 0    ┆ 0      ┆ {8,null,null,nu ┆ C   5H   8      │
#     │            ┆               ┆ -2-4-5-3-1/h1-2 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H8O(825) ┆ O1C2C1CCC2    ┆ AMChI=1/C5H8O/c ┆ 0    ┆ 0      ┆ {8,1,null,null, ┆ C   5H   8O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   300.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ HO2(8)     ┆ O[O]          ┆ AMChI=1/HO2/c1- ┆ 1    ┆ 0      ┆ {1,2,null,null, ┆ H   1O   2      │
#     │            ┆               ┆ 2/h2H           ┆      ┆        ┆ null,null}      ┆ G   200.00…     │
#     │ S(722)     ┆ OOC1CCC[CH]1  ┆ AMChI=1/C5H9O2/ ┆ 1    ┆ 0      ┆ {9,2,null,null, ┆ C   5H   9O   2 │
#     │            ┆               ┆ c6-7-5-1-2-3-4- ┆      ┆        ┆ null,5}         ┆ G   300.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ …          ┆ …             ┆ …               ┆ …    ┆ …      ┆ …               ┆ …               │
#     │ C5H7(500)  ┆ C1C[CH]C=C1   ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
#     │            ┆               ┆ -2-4-5-3-1/h1-3 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H7(504)  ┆ C1[CH]CC=C1   ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
#     │            ┆               ┆ -2-5-3-4-1/h1-3 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ S(1289)    ┆ O1C2C1C[CH]C2 ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   100.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H7O(758) ┆ O1C2C1[CH]CC2 ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-3-5-4(1)6-5 ┆      ┆        ┆ null,5}         ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ S(1314)    ┆ O1C2CCC[C]12  ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   100.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     └────────────┴───────────────┴─────────────────┴──────┴────────┴─────────────────┴─────────────────┘
#   ),
#   rate_units=('KCAL/MOLE', 'MOLES'),
#   thermo_temps=None,
# )
#
# Expanding stereochemistry...
#   0%|          | 0/13 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/14 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/S_all_v0_raw.json
# ../data/S_all_v0.json
# ../data/mechanalyzer/S_all_v0.dat
# ../data/mechanalyzer/S_all_v0.csv
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
# Stereoexpansion errors:

# %%
# Read
workflow.read(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/3173 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/S_all_v0_calc.json
# ../data/full_S_all_v0_control.json
# ../data/full_S_all_v0_calc.json
# ../data/chemkin/full_S_all_v0_control.dat
# ../data/chemkin/full_S_all_v0_calc.dat
#
# Compare calculated mechanism to parent mechanism...
#
# 1. Original (compare):
# S(722) = C5H8O(825) + OH(4)                            1.000E+00      0.000      0.000
#     PLOG  /                                 0.0009870  9.620E+01      2.050      3.050/
#     PLOG  /                                 0.0009870  4.840E+35     -7.840      19.69/
#     PLOG  /                                  0.009870  1.290E+13     -1.370      5.946/
#     PLOG  /                                  0.009870  2.230E+38     -8.490      20.33/
#     PLOG  /                                   0.09870  3.220E+22     -4.170      8.727/
#     PLOG  /                                   0.09870  2.120E+32     -6.320      18.79/
#     PLOG  /                                    0.9870  1.280E+25     -4.670      10.25/
#     PLOG  /                                    0.9870  4.000E+24     -3.630      17.39/
#     PLOG  /                                     9.870  9.850E+17     -2.010      9.428/
#     PLOG  /                                     9.870  1.220E+79     -19.63      47.13/
#     PLOG  /                                     98.70  1.540E+24     -3.840      12.30/
#     PLOG  /                                     98.70  1.490E+00      3.720      4.676/
# S(722) = C5H8(522) + HO2(8)                            1.000E+00      0.000      0.000
#     PLOG  /                                 0.0009870  1.160E+10     0.2500      18.81/
#     PLOG  /                                 0.0009870  3.200E+42     -9.300      34.89/
#     PLOG  /                                  0.009870  8.010E+14     -1.060      20.21/
#     PLOG  /                                  0.009870  4.070E+34     -6.510      32.93/
#     PLOG  /                                   0.09870  4.260E-07      6.110      14.28/
#     PLOG  /                                   0.09870  1.680E-33      13.44      2.462/
#     PLOG  /                                    0.9870  1.010E+39     -9.820      19.29/
#     PLOG  /                                    0.9870  1.920E+00      4.000      15.01/
#     PLOG  /                                     9.870  6.240E+30     -6.270      19.03/
#     PLOG  /                                     9.870  1.360E+22     -2.540      24.49/
#     PLOG  /                                     98.70  9.770E+19     -2.310      17.48/
#     PLOG  /                                     98.70  1.320E+90     -22.11      67.41/
# C5H8O(825) + OH(4) = C5H7O(758) + H2O(5)               3.350E+07      1.779    -0.1930
# C5H8O(825) + HO2(8) = C5H7O(758) + H2O2(10)            1.260E+02      3.370      13.72
# C5H8(522) + OH(4) = C5H7(504) + H2O(5)                 1.670E+07      1.779    -0.1930
# C5H8(522) + HO2(8) = C5H7(504) + H2O2(10)              9.480E+01      3.370      13.72
# C5H8(522) + OH(4) = C5H7(500) + H2O(5)                 4.040E+06      2.200    -0.4370
# C5H8(522) + HO2(8) = C5H7(500) + H2O2(10)              7.820E-01      3.968      11.70
# C5H8(522) + HO2(8) = C5H8O(825) + OH(4)                1.000E+00      0.000      0.000
#     PLOG  /                                 0.0009870  6.250E+19     -2.220      18.57/
#     PLOG  /                                 0.0009870  1.070E+08      1.050      10.30/
#     PLOG  /                                  0.009870  1.120E+19     -2.010      18.02/
#     PLOG  /                                  0.009870  1.500E+08     0.9900      10.30/
#     PLOG  /                                   0.09870  1.580E+18     -1.770      17.45/
#     PLOG  /                                   0.09870  1.520E+08     0.9800      10.27/
#     PLOG  /                                    0.9870  2.960E+18     -1.860      17.72/
#     PLOG  /                                    0.9870  4.970E+08     0.8500      10.60/
#     PLOG  /                                     9.870  7.480E+11    0.08000      13.43/
#     PLOG  /                                     9.870  3.630E+09     0.4100      11.18/
#     PLOG  /                                     98.70  5.530E+23     -3.500      19.62/
#     PLOG  /                                     98.70  1.470E+03      2.630      10.81/
#
# 2. Calculated (compare):
# C5H8(522) + HO2(8) = C5H7(500) + H2O2(10)                   7.820E-01      3.968      11.70   ! pes.subpes.channel  2.4.6
# C5H8(522) + HO2(8) = C5H7(504) + H2O2(10)                   9.480E+01      3.370      13.72   ! pes.subpes.channel  2.5.7
# C5H8O(825)rs + OH(4) = C5H7O(758)rs0 + H2O(5)               3.350E+07      1.779    -0.1930   ! pes.subpes.channel  2.6.8
# C5H8O(825)rs + OH(4) = C5H7O(758)rs1 + H2O(5)               3.350E+07      1.779    -0.1930   ! pes.subpes.channel  2.7.9
# C5H8O(825)rs + HO2(8) = C5H7O(758)rs0 + H2O2(10)            1.260E+02      3.370      13.72   ! pes.subpes.channel  3.1.1
# C5H8O(825)rs + HO2(8) = C5H7O(758)rs1 + H2O2(10)            1.260E+02      3.370      13.72   ! pes.subpes.channel  3.2.2
# C5H8(522) + OH(4) = C5H7(504) + H2O(5)                      7.220E+05      2.138     -1.342
# S(722)r1 = C5H8O(825)rs + OH(4)                             2.210E+08      0.000      0.000
# S(722)r1 = C5H8(522) + HO2(8)                               1.650E+06      0.000      0.000
# C5H8(522) + HO2(8) = C5H8O(825)rs + OH(4)                   8.306E+05      1.786      10.40
#     DUPLICATE
# C5H8(522) + OH(4) = C5H7(500) + H2O(5)                      7.388E+04      2.456     -2.610
# S(722)r0 = C5H8O(825)rs + OH(4)                             2.220E+08      0.000      0.000
# S(722)r0 = C5H8(522) + HO2(8)                               1.660E+06      0.000      0.000
# C5H8(522) + HO2(8) = C5H8O(825)rs + OH(4)                   8.306E+05      1.786      10.40
#     DUPLICATE
#
# 3. Calculated (new):
# C5H8O(825)rs + OH(4) = H2O(5) + S(1289)rs               1.000E+00      0.000      0.000   ! pes.subpes.channel  2.8.10
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r0               1.000E+00      0.000      0.000   ! pes.subpes.channel  2.9.11
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r1               1.000E+00      0.000      0.000   ! pes.subpes.channel  2.10.12
# C5H8O(825)rs + HO2(8) = H2O2(10) + S(1289)rs            1.000E+00      0.000      0.000   ! pes.subpes.channel  3.3.3
# C5H8O(825)rs + HO2(8) = H2O2(10) + S(1314)r0            1.000E+00      0.000      0.000   ! pes.subpes.channel  3.4.4
# C5H8O(825)rs + HO2(8) = H2O2(10) + S(1314)r1            1.000E+00      0.000      0.000   ! pes.subpes.channel  3.5.5
# C5H7(1202) + H2O2(10) = C5H8(522) + HO2(8)              1.856E-01      3.835     -3.890
# C5H8(522) + OH(4) = C5H7(1202) + H2O(5)                 4.697E+03      2.787      1.081
#
#
# 4. Calculated (all together):
# C5H8(522) + HO2(8) = C5H7(500) + H2O2(10)                   7.820E-01      3.968      11.70   ! pes.subpes.channel  2.4.6
# C5H8(522) + HO2(8) = C5H7(504) + H2O2(10)                   9.480E+01      3.370      13.72   ! pes.subpes.channel  2.5.7
# C5H8O(825)rs + OH(4) = C5H7O(758)rs0 + H2O(5)               3.350E+07      1.779    -0.1930   ! pes.subpes.channel  2.6.8
# C5H8O(825)rs + OH(4) = C5H7O(758)rs1 + H2O(5)               3.350E+07      1.779    -0.1930   ! pes.subpes.channel  2.7.9
# C5H8O(825)rs + OH(4) = H2O(5) + S(1289)rs                   1.000E+00      0.000      0.000   ! pes.subpes.channel  2.8.10
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r0                   1.000E+00      0.000      0.000   ! pes.subpes.channel  2.9.11
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r1                   1.000E+00      0.000      0.000   ! pes.subpes.channel  2.10.12
# C5H8O(825)rs + HO2(8) = C5H7O(758)rs0 + H2O2(10)            1.260E+02      3.370      13.72   ! pes.subpes.channel  3.1.1
# C5H8O(825)rs + HO2(8) = C5H7O(758)rs1 + H2O2(10)            1.260E+02      3.370      13.72   ! pes.subpes.channel  3.2.2
# C5H8O(825)rs + HO2(8) = H2O2(10) + S(1289)rs                1.000E+00      0.000      0.000   ! pes.subpes.channel  3.3.3
# C5H8O(825)rs + HO2(8) = H2O2(10) + S(1314)r0                1.000E+00      0.000      0.000   ! pes.subpes.channel  3.4.4
# C5H8O(825)rs + HO2(8) = H2O2(10) + S(1314)r1                1.000E+00      0.000      0.000   ! pes.subpes.channel  3.5.5
# C5H7(1202) + H2O2(10) = C5H8(522) + HO2(8)                  1.856E-01      3.835     -3.890
# C5H8(522) + OH(4) = C5H7(1202) + H2O(5)                     4.697E+03      2.787      1.081
# C5H8(522) + OH(4) = C5H7(504) + H2O(5)                      7.220E+05      2.138     -1.342
# S(722)r1 = C5H8O(825)rs + OH(4)                             2.210E+08      0.000      0.000
# S(722)r1 = C5H8(522) + HO2(8)                               1.650E+06      0.000      0.000
# C5H8(522) + HO2(8) = C5H8O(825)rs + OH(4)                   8.306E+05      1.786      10.40
#     DUPLICATE
# C5H8(522) + OH(4) = C5H7(500) + H2O(5)                      7.388E+04      2.456     -2.610
# S(722)r0 = C5H8O(825)rs + OH(4)                             2.220E+08      0.000      0.000
# S(722)r0 = C5H8(522) + HO2(8)                               1.660E+06      0.000      0.000
# C5H8(522) + HO2(8) = C5H8O(825)rs + OH(4)                   8.306E+05      1.786      10.40
#     DUPLICATE

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)

# %%
# # Plot
# charts = workflow.plot(
#     full_tag=f"full_{tag}_calc",
#     x_col="O2_molecules",
#     y_col_=["C5H8(522)", "C5H8O(825)rs"],
#     root_path=root_path,
#     line_source_=["hill", "lokachari"],
#     point_source="experiment",
# )
# for chart in charts:
#     chart.show()
