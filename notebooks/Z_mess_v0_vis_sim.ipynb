# %%
from pathlib import Path

from project_utilities import workflow

tag = "Z_mess_v0"
root_path = Path("..")

# %%
chart_dct = workflow.plot_o2_simulation(
    tag,
    x_col="O2_molecules",
    line_source_=["Hill", "Lokachari"],
    point_source="Experiment",
    root_path=root_path,
    control=True,
)
for name, chart in chart_dct.items():
    print(name)
    display(chart)
# Out:
# C5H8(522)
# alt.LayerChart(...)
# C5H8O(825)rs
# alt.LayerChart(...)
# CPT(563)
# alt.LayerChart(...)
# O2(6)
# alt.LayerChart(...)
# H2(2)
# alt.LayerChart(...)
# H2O(5)
# alt.LayerChart(...)
# CO(12)
# alt.LayerChart(...)
# CO2(13)
# alt.LayerChart(...)
# CH4(33)
# alt.LayerChart(...)
# CH3CHO(41)
# alt.LayerChart(...)
# C2H4(52)
# alt.LayerChart(...)
# C3H6(131)
# alt.LayerChart(...)
# C3H4O(165)
# alt.LayerChart(...)
# C4H6(227)
# alt.LayerChart(...)
# C4H8(253)
# alt.LayerChart(...)
# C5H6(478)
# alt.LayerChart(...)
# C6H6(970)
# alt.LayerChart(...)
