# %%
from pathlib import Path

import util
from util import workflow

browser = False
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")

# %%
# # Build
# from automol.graph import enum

# import automech
# from automech.species import Species

# par_mech = workflow.read_parent_mechanism(root_path=root_path)
# mech = automech.from_smiles(spc_smis=["C1=CCCC1", "C12C(O2)CCC1"], src_mech=par_mech)
# #  - enumerate OH abstractions from *ene* and *1-2epoxy*
# mech = automech.enumerate_reactions(
#     mech,
#     enum.ReactionSmarts.abstraction,
#     rcts_=[None, "[OH]"],
#     spc_col_=Species.smiles,
#     src_mech=par_mech,
# )
# automech.display(mech)

# %%
# # Write
# workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)

# %%
# Read
# workflow.prepare_simulation(tag=tag, root_path=root_path)
workflow.prepare_simulation_species(tag=tag, root_path=root_path)
# Out:
# Reading in species...
# shape: (20, 5)
# ┌────────────┬───────────────────────┬───────────┬────────────┬───────────────┐
# │ orig_name  ┆ experiment            ┆ lokachari ┆ hill       ┆ concentration │
# │ ---        ┆ ---                   ┆ ---       ┆ ---        ┆ ---           │
# │ str        ┆ str                   ┆ str       ┆ str        ┆ str           │
# ╞════════════╪═══════════════════════╪═══════════╪════════════╪═══════════════╡
# │ CPT(563)   ┆ cyclopentane          ┆ CPT       ┆ CPT(563)   ┆ CPT_frac      │
# │ O2(6)      ┆ O2                    ┆ O2        ┆ O2(6)      ┆ O2_frac       │
# │ N2         ┆ N2                    ┆ N2        ┆ N2         ┆ N2_frac       │
# │ H2(2)      ┆ H2                    ┆ H2        ┆ H2(2)      ┆ null          │
# │ H2O(5)     ┆ water                 ┆ H2O       ┆ H2O(5)     ┆ null          │
# │ …          ┆ …                     ┆ …         ┆ …          ┆ …             │
# │ C5H8(522)  ┆ cyclopentene          ┆ CYC5H8    ┆ C5H8(522)  ┆ null          │
# │ C5H8O(825) ┆ 1,2-epoxycyclopentane ┆ CPTYO12   ┆ C5H8O(825) ┆ null          │
# │ C6H6(970)  ┆ benzene               ┆ C6H6      ┆ C6H6(970)  ┆ null          │
# │ HO2(8)     ┆ null                  ┆ HO2       ┆ HO2(8)     ┆ null          │
# │ OH(4)      ┆ null                  ┆ OH        ┆ OH(4)      ┆ null          │
# └────────────┴───────────────────────┴───────────┴────────────┴───────────────┘
# shape: (2_536, 10)
# ┌─────────┬─────────────┬────────────┬──────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ name    ┆ smiles      ┆ amchi      ┆ spin ┆ … ┆ orig_smile ┆ orig_amchi ┆ thermo_str ┆ orig_name │
# │ ---     ┆ ---         ┆ ---        ┆ ---  ┆   ┆ s          ┆ ---        ┆ ing        ┆ ---       │
# │ str     ┆ str         ┆ str        ┆ i64  ┆   ┆ ---        ┆ str        ┆ ---        ┆ str       │
# │         ┆             ┆            ┆      ┆   ┆ str        ┆            ┆ str        ┆           │
# ╞═════════╪═════════════╪════════════╪══════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ H(1)    ┆ [H]         ┆ AMChI=1/H  ┆ 1    ┆ … ┆ [H]        ┆ AMChI=1/H  ┆ H   1      ┆ null      │
# │         ┆             ┆            ┆      ┆   ┆            ┆            ┆ G          ┆           │
# │         ┆             ┆            ┆      ┆   ┆            ┆            ┆ 200.00…    ┆           │
# │ H2(2)   ┆ [H][H]      ┆ AMChI=1/H2 ┆ 0    ┆ … ┆ [H][H]     ┆ AMChI=1/H2 ┆ H   2      ┆ null      │
# │         ┆             ┆ /h1H       ┆      ┆   ┆            ┆ /h1H       ┆ G          ┆           │
# │         ┆             ┆            ┆      ┆   ┆            ┆            ┆ 200.00…    ┆           │
# │ O(3)    ┆ [O]         ┆ AMChI=1/O  ┆ 2    ┆ … ┆ [O]        ┆ AMChI=1/O  ┆ O   1      ┆ null      │
# │         ┆             ┆            ┆      ┆   ┆            ┆            ┆ G          ┆           │
# │         ┆             ┆            ┆      ┆   ┆            ┆            ┆ 200.00…    ┆           │
# │ OH(4)   ┆ [OH]        ┆ AMChI=1/HO ┆ 1    ┆ … ┆ [OH]       ┆ AMChI=1/HO ┆ H   1O   1 ┆ OH(4)     │
# │         ┆             ┆ /h1H       ┆      ┆   ┆            ┆ /h1H       ┆ G          ┆           │
# │         ┆             ┆            ┆      ┆   ┆            ┆            ┆ 200.…      ┆           │
# │ H2O(5)  ┆ O           ┆ AMChI=1/H2 ┆ 0    ┆ … ┆ O          ┆ AMChI=1/H2 ┆ H   2O   1 ┆ H2O(5)    │
# │         ┆             ┆ O/h1H2     ┆      ┆   ┆            ┆ O/h1H2     ┆ G          ┆           │
# │         ┆             ┆            ┆      ┆   ┆            ┆            ┆ 200.…      ┆           │
# │ …       ┆ …           ┆ …          ┆ …    ┆ … ┆ …          ┆ …          ┆ …          ┆ …         │
# │ S(2528) ┆ OCCC1CO[CH] ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ OCCC1CO[CH ┆ AMChI=1/C5 ┆ C   5H     ┆ null      │
# │         ┆ 1           ┆ H9O2/c6-3- ┆      ┆   ┆ ]1         ┆ H9O2/c6-3- ┆ 9O   2     ┆           │
# │         ┆             ┆ 2-5-1-7-4- ┆      ┆   ┆            ┆ 2-5-1-7-4- ┆ G          ┆           │
# │         ┆             ┆ …          ┆      ┆   ┆            ┆ …          ┆ 100.00…    ┆           │
# │ S(2529) ┆ O1C(C2CO[CH ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ O1C(C2CO[C ┆ AMChI=1/C5 ┆ C   5H     ┆ null      │
# │         ┆ ]2)C1       ┆ H7O2/c1-4( ┆      ┆   ┆ H]2)C1     ┆ H7O2/c1-4( ┆ 7O   2     ┆           │
# │         ┆             ┆ 5-3-7-5)2- ┆      ┆   ┆            ┆ 5-3-7-5)2- ┆ G          ┆           │
# │         ┆             ┆ …          ┆      ┆   ┆            ┆ …          ┆ 100.00…    ┆           │
# │ S(2530) ┆ OC(=O)C1C(C ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ OC(=O)C1C( ┆ AMChI=1/C5 ┆ C   5H     ┆ null      │
# │         ┆ 1)[CH2]     ┆ H7O2/c1-4- ┆      ┆   ┆ C1)[CH2]   ┆ H7O2/c1-4- ┆ 7O   2     ┆           │
# │         ┆             ┆ 2-5(4)3(6) ┆      ┆   ┆            ┆ 2-5(4)3(6) ┆ G          ┆           │
# │         ┆             ┆ …          ┆      ┆   ┆            ┆ …          ┆ 100.00…    ┆           │
# │ S(2531) ┆ OC(=O)C(C=C ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ OC(=O)C(C= ┆ AMChI=1/C5 ┆ C   5H     ┆ null      │
# │         ┆ )[CH2]      ┆ H7O2/c1-3- ┆      ┆   ┆ C)[CH2]    ┆ H7O2/c1-3- ┆ 7O   2     ┆           │
# │         ┆             ┆ 5(2)4(6)7/ ┆      ┆   ┆            ┆ 5(2)4(6)7/ ┆ G          ┆           │
# │         ┆             ┆ …          ┆      ┆   ┆            ┆ …          ┆ 100.00…    ┆           │
# │ S(2532) ┆ OC(C=CCOO)[ ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ OC(C=CCOO) ┆ AMChI=1/C5 ┆ C   5H     ┆ null      │
# │         ┆ CH2]        ┆ H9O3/c1-5( ┆      ┆   ┆ [CH2]      ┆ H9O3/c1-5( ┆ 9O   3     ┆           │
# │         ┆             ┆ 6)3-2-4-8- ┆      ┆   ┆            ┆ 6)3-2-4-8- ┆ G          ┆           │
# │         ┆             ┆ …          ┆      ┆   ┆            ┆ …          ┆ 100.00…    ┆           │
# └─────────┴─────────────┴────────────┴──────┴───┴────────────┴────────────┴────────────┴───────────┘
# shape: (4, 6)
# ┌──────────────┬────────────┬───────────────────────┬───────────┬────────────┬───────────────┐
# │ name         ┆ orig_name  ┆ experiment            ┆ lokachari ┆ hill       ┆ concentration │
# │ ---          ┆ ---        ┆ ---                   ┆ ---       ┆ ---        ┆ ---           │
# │ str          ┆ str        ┆ str                   ┆ str       ┆ str        ┆ str           │
# ╞══════════════╪════════════╪═══════════════════════╪═══════════╪════════════╪═══════════════╡
# │ OH(4)        ┆ OH(4)      ┆ null                  ┆ OH        ┆ OH(4)      ┆ null          │
# │ H2O(5)       ┆ H2O(5)     ┆ water                 ┆ H2O       ┆ H2O(5)     ┆ null          │
# │ C5H8(522)    ┆ C5H8(522)  ┆ cyclopentene          ┆ CYC5H8    ┆ C5H8(522)  ┆ null          │
# │ C5H8O(825)rs ┆ C5H8O(825) ┆ 1,2-epoxycyclopentane ┆ CPTYO12   ┆ C5H8O(825) ┆ null          │
# └──────────────┴────────────┴───────────────────────┴───────────┴────────────┴───────────────┘

# %%
# # Plot
# charts = workflow.plot_simulation(
#     tag=tag,
#     x_col="O2_molecules",
#     y_col_=["C5H8(522)", "C5H8O(825)rs"],
#     root_path=root_path,
#     line_source_=["hill", "lokachari"],
#     point_source="experiment",
# )
# for chart in charts:
#     chart.show()

# %%
# import automech
# from mechdriver.subtasks import display

# chan = "2: 5"

# # TRANSITION STATE
# #   - Read in expanded mechanism
# mech_path = util.p_.mechanism(tag, ext="json", path=util.p_.data(root_path))
# mech = automech.io.read(mech_path)

# #   - Display the reaction
# automech.display_reactions(mech, chans=[chan])

# %%
# #   - Display the TS mode
# calc_path = util.p_.calc(root_path, tag)
# display("conf_opt", chan, path=calc_path)

# %%
# #   - Display the TS mode
# calc_path = util.p_.calc(root_path, tag)
# display("find_ts", chan, path=calc_path)

# %%
# # REACTION RATE
# #   - Read in calculated mechanism
# cal_mech = automech.io.read(data_path / f"{tag}_calc.json")

# #   - Read in other mechanisms for comparison
# par_mech = automech.io.read(data_path / "full_raw.json")
# tags0 = util.previous_tags(tag)
# trues = [True] * len(tags0)
# names0 = list(map(util.calculated_mechanism_name, tags0))
# mechs0 = [automech.io.read(data_path / f"{name}.json") for name in names0]

# #   - Display the reaction and calculated rate
# automech.display_reactions(
#     cal_mech,
#     chans=[chan],
#     comp_mechs=[par_mech, *mechs0],
#     comp_labels=["Hill", *tags0],
#     comp_stereo=[False, *trues],
# )
