# %%
from pathlib import Path

import util
from util import workflow

tag = util.notebook_prefix()
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# Build
from automol.graph import enum

import automech
from automech.schema import Species

mech0 = automech.io.read(data_path / "full_raw.json")
mech = automech.from_smiles(spc_smis=["C1=CCCC1", "C12C(O2)CCC1"], src_mech=mech0)
#  - enumerate OH abstractions from *ene* and *1-2epoxy*
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.abstraction,
    rcts_=[None, "[OH]"],
    spc_col_=Species.smiles,
    src_mech=mech0,
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path)
# Out:
# Finalizing build for...
# Mechanism(
#   reactions=DataFrame(
#     shape: (6, 5)
#     ┌────────────────┬────────────────┬───────────┬──────────────────────────┬─────────────────────────┐
#     │ reactants      ┆ products       ┆ formula   ┆ rate                     ┆ colliders               │
#     │ ---            ┆ ---            ┆ ---       ┆ ---                      ┆ ---                     │
#     │ list[str]      ┆ list[str]      ┆ struct[3] ┆ struct[7]                ┆ struct[11]              │
#     ╞════════════════╪════════════════╪═══════════╪══════════════════════════╪═════════════════════════╡
#     │ ["C5H7(1202)", ┆ ["C5H8(522)",  ┆ {5,9,1}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "H2O(5)"]      ┆ "OH(4)"]       ┆           ┆                          ┆ ll,null…                │
#     │ ["C5H8(522)",  ┆ ["C5H7(500)",  ┆ {5,9,1}   ┆ {{4.04e6,2.2,-0.437},tru ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "H2O(5)"]      ┆           ┆ e,"Con…                  ┆ ll,null…                │
#     │ ["C5H8(522)",  ┆ ["C5H7(504)",  ┆ {5,9,1}   ┆ {{1.67e7,1.779,-0.193},t ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "H2O(5)"]      ┆           ┆ rue,"C…                  ┆ ll,null…                │
#     │ ["H2O(5)",     ┆ ["C5H8O(825)", ┆ {5,9,2}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "S(1289)"]     ┆ "OH(4)"]       ┆           ┆                          ┆ ll,null…                │
#     │ ["C5H8O(825)", ┆ ["C5H7O(758)", ┆ {5,9,2}   ┆ {{3.35e7,1.779,-0.193},t ┆ {null,null,null,null,nu │
#     │ "OH(4)"]       ┆ "H2O(5)"]      ┆           ┆ rue,"C…                  ┆ ll,null…                │
#     │ ["H2O(5)",     ┆ ["C5H8O(825)", ┆ {5,9,2}   ┆ null                     ┆ {null,null,null,null,nu │
#     │ "S(1314)"]     ┆ "OH(4)"]       ┆           ┆                          ┆ ll,null…                │
#     └────────────────┴────────────────┴───────────┴──────────────────────────┴─────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (10, 7)
#     ┌────────────┬───────────────┬─────────────────┬──────┬────────┬─────────────────┬─────────────────┐
#     │ name       ┆ smiles        ┆ amchi           ┆ spin ┆ charge ┆ formula         ┆ thermo_string   │
#     │ ---        ┆ ---           ┆ ---             ┆ ---  ┆ ---    ┆ ---             ┆ ---             │
#     │ str        ┆ str           ┆ str             ┆ i64  ┆ i64    ┆ struct[6]       ┆ str             │
#     ╞════════════╪═══════════════╪═════════════════╪══════╪════════╪═════════════════╪═════════════════╡
#     │ C5H8(522)  ┆ C1CC=CC1      ┆ AMChI=1/C5H8/c1 ┆ 0    ┆ 0      ┆ {8,null,null,nu ┆ C   5H   8      │
#     │            ┆               ┆ -2-4-5-3-1/h1-2 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H8O(825) ┆ O1C2C1CCC2    ┆ AMChI=1/C5H8O/c ┆ 0    ┆ 0      ┆ {8,1,null,null, ┆ C   5H   8O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   300.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ OH(4)      ┆ [OH]          ┆ AMChI=1/HO/h1H  ┆ 1    ┆ 0      ┆ {1,1,null,null, ┆ H   1O   1      │
#     │            ┆               ┆                 ┆      ┆        ┆ null,null}      ┆ G   200.00…     │
#     │ C5H7(1202) ┆ C1CC=[C]C1    ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
#     │            ┆               ┆ -2-4-5-3-1/h2H, ┆      ┆        ┆ ll,null,5}      ┆ G   100.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ H2O(5)     ┆ O             ┆ AMChI=1/H2O/h1H ┆ 0    ┆ 0      ┆ {2,1,null,null, ┆ H   2O   1      │
#     │            ┆               ┆ 2               ┆      ┆        ┆ null,null}      ┆ G   200.00…     │
#     │ C5H7(500)  ┆ C1C[CH]C=C1   ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
#     │            ┆               ┆ -2-4-5-3-1/h1-3 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H7(504)  ┆ C1[CH]CC=C1   ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
#     │            ┆               ┆ -2-5-3-4-1/h1-3 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ S(1289)    ┆ O1C2C1C[CH]C2 ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   100.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H7O(758) ┆ O1C2C1[CH]CC2 ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-3-5-4(1)6-5 ┆      ┆        ┆ null,5}         ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ S(1314)    ┆ O1C2CCC[C]12  ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   100.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     └────────────┴───────────────┴─────────────────┴──────┴────────┴─────────────────┴─────────────────┘
#   ),
#   rate_units=('KCAL/MOLE', 'MOLES'),
#   thermo_temps=None,
# )
#
# Expanding stereochemistry...
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/A_rh-oh_p1v0.json
# ../data/mechanalyzer/A_rh-oh_p1v0.dat
# ../data/mechanalyzer/A_rh-oh_p1v0.csv
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Stereoexpansion errors:

# %%
# Read
workflow.read(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/2068 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/A_rh-oh_p1v0_calc.json
# ../data/full_A_rh-oh_p1v0_control.json
# ../data/full_A_rh-oh_p1v0_calc.json
# ../data/chemkin/full_A_rh-oh_p1v0_control.dat
# ../data/chemkin/full_A_rh-oh_p1v0_calc.dat
#
# Compare calculated mechanism to parent mechanism...
#
# 1. Original (compare):
#
#
# 2. Calculated (compare):
#
#
# 3. Calculated (new):
# C5H7(1202) + H2O(5) = C5H8(522) + OH(4)                  1.000E+00      0.000      0.000   ! pes.subpes.channel  1.1.1
# C5H8(522) + OH(4) = C5H7(500) + H2O(5)                   7.388E+04      2.456     -2.610   ! pes.subpes.channel  1.2.2
# C5H8(522) + OH(4) = C5H7(504) + H2O(5)                   7.220E+05      2.138     -1.342   ! pes.subpes.channel  1.3.3
# C5H8O(825)rs + OH(4) = C5H7O(758)rs0 + H2O(5)            1.531E+06      2.169     -1.510   ! pes.subpes.channel  2.1.1
# C5H8O(825)rs + OH(4) = C5H7O(758)rs1 + H2O(5)            1.531E+06      2.169     -1.510   ! pes.subpes.channel  2.2.2
# H2O(5) + S(1289)rs = C5H8O(825)rs + OH(4)                1.000E+00      0.000      0.000   ! pes.subpes.channel  2.3.3
# H2O(5) + S(1314)r0 = C5H8O(825)rs + OH(4)                1.000E+00      0.000      0.000   ! pes.subpes.channel  2.4.4
# H2O(5) + S(1314)r1 = C5H8O(825)rs + OH(4)                1.000E+00      0.000      0.000   ! pes.subpes.channel  2.5.5
#
#
# 4. Calculated (all together):

# %%
# Simulate
workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)
# Out:
# Converting ChemKin mechanism to Cantera YAML...
# Wrote YAML mechanism file to '../data/cantera/full_A_rh-oh_p1v0_control.yaml'.
# Mechanism contains 2536 species and 10038 reactions.
#
# Reading in species and concentrations...
# {'CPT_frac': 'CPT(563)', 'O2_frac': 'O2(6)', 'N2_frac': 'N2'}
# shape: (27, 5)
# ┌──────┬──────────────┬──────────┬──────────┬──────────┐
# │ phi  ┆ O2_molecules ┆ CPT(563) ┆ N2       ┆ O2(6)    │
# │ ---  ┆ ---          ┆ ---      ┆ ---      ┆ ---      │
# │ f64  ┆ f64          ┆ f64      ┆ f64      ┆ f64      │
# ╞══════╪══════════════╪══════════╪══════════╪══════════╡
# │ 3.0  ┆ 0.12233      ┆ 0.005    ┆ 0.9825   ┆ 0.0125   │
# │ 2.0  ┆ 0.1835       ┆ 0.005    ┆ 0.97625  ┆ 0.01875  │
# │ 1.75 ┆ 0.20962      ┆ 0.005    ┆ 0.973571 ┆ 0.021429 │
# │ 1.5  ┆ 0.24456      ┆ 0.005    ┆ 0.97     ┆ 0.025    │
# │ 1.25 ┆ 0.29347      ┆ 0.005    ┆ 0.965    ┆ 0.03     │
# │ …    ┆ …            ┆ …        ┆ …        ┆ …        │
# │ 0.17 ┆ 2.15785      ┆ 0.005    ┆ 0.774412 ┆ 0.220588 │
# │ 0.15 ┆ 2.44557      ┆ 0.005    ┆ 0.745    ┆ 0.25     │
# │ 0.13 ┆ 2.75147      ┆ 0.005    ┆ 0.706538 ┆ 0.288462 │
# │ 0.11 ┆ 3.33486      ┆ 0.005    ┆ 0.654091 ┆ 0.340909 │
# │ 0.1  ┆ 3.66835      ┆ 0.005    ┆ 0.62     ┆ 0.375    │
# └──────┴──────────────┴──────────┴──────────┴──────────┘
#
# Defining model and conditions...
#
# Running simulations...
# Starting simulation for {'CPT(563)': 0.005, 'N2': 0.9825, 'O2(6)': 0.0125}
# Starting simulation for {'CPT(563)': 0.005, 'N2': 0.97625, 'O2(6)': 0.01875}
# Starting simulation for {'CPT(563)': 0.005, 'N2': 0.973571429, 'O2(6)': 0.021428571}
