# %%
from pathlib import Path

import util
from util import workflow

tag = util.notebook_prefix()
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# # Build
# from automol.graph import enum

# import automech
# from automech.schema import Species

# mech0 = automech.io.read(data_path / "full_raw.json")
# mech = automech.from_smiles(spc_smis=["C1=CCCC1", "C12C(O2)CCC1"], src_mech=mech0)
# #  - enumerate OH abstractions from *ene* and *1-2epoxy*
# mech = automech.enumerate_reactions(
#     mech,
#     enum.ReactionSmarts.abstraction,
#     rcts_=[None, "[OH]"],
#     spc_col_=Species.smiles,
#     src_mech=mech0,
# )

# %%
# # Write
# workflow.write(mech=mech, tag=tag, root_path=root_path)

# %%
# # Read
# workflow.read(tag=tag, root_path=root_path)

# %%
# Simulate
workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)
# Out:
# Reading in species and concentrations...
# {'CPT_frac': 'CPT(563)', 'O2_frac': 'O2(6)', 'N2_frac': 'N2'}
# shape: (27, 5)
# ┌──────┬──────────────┬──────────┬──────────┬──────────┐
# │ phi  ┆ O2_molecules ┆ CPT(563) ┆ N2       ┆ O2(6)    │
# │ ---  ┆ ---          ┆ ---      ┆ ---      ┆ ---      │
# │ f64  ┆ f64          ┆ f64      ┆ f64      ┆ f64      │
# ╞══════╪══════════════╪══════════╪══════════╪══════════╡
# │ 3.0  ┆ 0.12233      ┆ 0.005    ┆ 0.9825   ┆ 0.0125   │
# │ 2.0  ┆ 0.1835       ┆ 0.005    ┆ 0.97625  ┆ 0.01875  │
# │ 1.75 ┆ 0.20962      ┆ 0.005    ┆ 0.973571 ┆ 0.021429 │
# │ 1.5  ┆ 0.24456      ┆ 0.005    ┆ 0.97     ┆ 0.025    │
# │ 1.25 ┆ 0.29347      ┆ 0.005    ┆ 0.965    ┆ 0.03     │
# │ …    ┆ …            ┆ …        ┆ …        ┆ …        │
# │ 0.17 ┆ 2.15785      ┆ 0.005    ┆ 0.774412 ┆ 0.220588 │
# │ 0.15 ┆ 2.44557      ┆ 0.005    ┆ 0.745    ┆ 0.25     │
# │ 0.13 ┆ 2.75147      ┆ 0.005    ┆ 0.706538 ┆ 0.288462 │
# │ 0.11 ┆ 3.33486      ┆ 0.005    ┆ 0.654091 ┆ 0.340909 │
# │ 0.1  ┆ 3.66835      ┆ 0.005    ┆ 0.62     ┆ 0.375    │
# └──────┴──────────────┴──────────┴──────────┴──────────┘
#
# Defining model and conditions...
#
# Running simulations...
# Starting simulation for {'CPT(563)': 0.005, 'N2': 0.9825, 'O2(6)': 0.0125}
# Starting simulation for {'CPT(563)': 0.005, 'N2': 0.937307692, 'O2(6)': 0.057692308}
# Starting simulation for {'CPT(563)': 0.005, 'N2': 0.845, 'O2(6)': 0.15}
#
# Extracting results...
# ---------------------------------------------------------------------------
# ShapeError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Simulate
# ----> 2 workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)
#
# File ~/code/amech-proto/work/project-cyclopentane/notebooks/util/workflow.py:166, in simulate(full_tag, root_path, temp_k, pres_atm, tau_s, vol_cm3)
#     163     solns.append(reactor.thermo.state)
#     165 print("\nExtracting results...")
# --> 166 sim_df = conc_df.with_columns(
#     167     polars.Series(s, solns(s).X.flatten() * 10**6) for s in species_df["name"]
#     168 )
#     170 print("\nWriting results to CSV...")
#     171 print(data_path / "cantera" / f"{full_tag}.csv")
#
# File ~/code/amech-proto/.pixi/envs/dev/lib/python3.12/site-packages/polars/dataframe/frame.py:9194, in DataFrame.with_columns(self, *exprs, **named_exprs)
#    9048 def with_columns(
#    9049     self,
#    9050     *exprs: IntoExpr | Iterable[IntoExpr],
#    9051     **named_exprs: IntoExpr,
#    9052 ) -> DataFrame:
#    9053     """
#    9054     Add columns to this DataFrame.
#    9055
#    (...)
#    9192     └─────┴──────┴─────────────┘
#    9193     """
# -> 9194     return self.lazy().with_columns(*exprs, **named_exprs).collect(_eager=True)
#
# File ~/code/amech-proto/.pixi/envs/dev/lib/python3.12/site-packages/polars/lazyframe/frame.py:2055, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, streaming, engine, background, _eager, **_kwargs)
#    2053 # Only for testing purposes
#    2054 callback = _kwargs.get("post_opt_callback", callback)
# -> 2055 return wrap_df(ldf.collect(callback))
#
# ShapeError: unable to add a column of length 3 to a DataFrame of height 27
