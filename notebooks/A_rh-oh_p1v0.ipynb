# %%
from pathlib import Path

import util
from util import workflow

browser = True
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# Build
from automol.graph import enum

import automech
from automech.schema import Species

mech0 = automech.io.read(data_path / "full_raw.json")
mech = automech.from_smiles(spc_smis=["C1=CCCC1", "C12C(O2)CCC1"], src_mech=mech0)
#  - enumerate OH abstractions from *ene* and *1-2epoxy*
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.abstraction,
    rcts_=[None, "[OH]"],
    spc_col_=Species.smiles,
    src_mech=mech0,
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)
# Out:
# Finalizing build for...
# Mechanism(
#   reactions=DataFrame(
#     shape: (6, 7)
#     ┌──────────────┬──────────────┬───────────┬───────────┬──────────────┬──────────────┬──────────────┐
#     │ reactants    ┆ products     ┆ formula   ┆ zgqcetdhu ┆ rate         ┆ colliders    ┆ vlxdzccts    │
#     │ ---          ┆ ---          ┆ ---       ┆ ---       ┆ ---          ┆ ---          ┆ ---          │
#     │ list[str]    ┆ list[str]    ┆ struct[3] ┆ str       ┆ struct[7]    ┆ struct[11]   ┆ str          │
#     ╞══════════════╪══════════════╪═══════════╪═══════════╪══════════════╪══════════════╪══════════════╡
#     │ ["C5H7(1202) ┆ ["C5H8(522)" ┆ {5,9,1}   ┆ null      ┆ null         ┆ {null,null,n ┆ C5H7(1202)+H │
#     │ ", "H2O(5)"] ┆ , "OH(4)"]   ┆           ┆           ┆              ┆ ull,null,nul ┆ 2O(5)=C5H8(5 │
#     │              ┆              ┆           ┆           ┆              ┆ l,null…      ┆ 22)+OH…      │
#     │ ["C5H8(522)" ┆ ["C5H7(500)" ┆ {5,9,1}   ┆ null      ┆ {{4.04e6,2.2 ┆ {null,null,n ┆ C5H7(500)+H2 │
#     │ , "OH(4)"]   ┆ , "H2O(5)"]  ┆           ┆           ┆ ,-0.437},tru ┆ ull,null,nul ┆ O(5)=C5H8(52 │
#     │              ┆              ┆           ┆           ┆ e,"Con…      ┆ l,null…      ┆ 2)+OH(…      │
#     │ ["C5H8(522)" ┆ ["C5H7(504)" ┆ {5,9,1}   ┆ null      ┆ {{1.67e7,1.7 ┆ {null,null,n ┆ C5H7(504)+H2 │
#     │ , "OH(4)"]   ┆ , "H2O(5)"]  ┆           ┆           ┆ 79,-0.193},t ┆ ull,null,nul ┆ O(5)=C5H8(52 │
#     │              ┆              ┆           ┆           ┆ rue,"C…      ┆ l,null…      ┆ 2)+OH(…      │
#     │ ["C5H8O(825) ┆ ["H2O(5)",   ┆ {5,9,2}   ┆ null      ┆ null         ┆ {null,null,n ┆ C5H8O(825)+O │
#     │ ", "OH(4)"]  ┆ "S(1289)"]   ┆           ┆           ┆              ┆ ull,null,nul ┆ H(4)=H2O(5)+ │
#     │              ┆              ┆           ┆           ┆              ┆ l,null…      ┆ S(1289…      │
#     │ ["C5H8O(825) ┆ ["C5H7O(758) ┆ {5,9,2}   ┆ null      ┆ {{3.35e7,1.7 ┆ {null,null,n ┆ C5H7O(758)+H │
#     │ ", "OH(4)"]  ┆ ", "H2O(5)"] ┆           ┆           ┆ 79,-0.193},t ┆ ull,null,nul ┆ 2O(5)=C5H8O( │
#     │              ┆              ┆           ┆           ┆ rue,"C…      ┆ l,null…      ┆ 825)+O…      │
#     │ ["C5H8O(825) ┆ ["H2O(5)",   ┆ {5,9,2}   ┆ null      ┆ null         ┆ {null,null,n ┆ C5H8O(825)+O │
#     │ ", "OH(4)"]  ┆ "S(1314)"]   ┆           ┆           ┆              ┆ ull,null,nul ┆ H(4)=H2O(5)+ │
#     │              ┆              ┆           ┆           ┆              ┆ l,null…      ┆ S(1314…      │
#     └──────────────┴──────────────┴───────────┴───────────┴──────────────┴──────────────┴──────────────┘
#   ),
#   species=DataFrame(
#     shape: (10, 7)
#     ┌────────────┬───────────────┬─────────────────┬──────┬────────┬─────────────────┬─────────────────┐
#     │ name       ┆ smiles        ┆ amchi           ┆ spin ┆ charge ┆ formula         ┆ thermo_string   │
#     │ ---        ┆ ---           ┆ ---             ┆ ---  ┆ ---    ┆ ---             ┆ ---             │
#     │ str        ┆ str           ┆ str             ┆ i64  ┆ i64    ┆ struct[6]       ┆ str             │
#     ╞════════════╪═══════════════╪═════════════════╪══════╪════════╪═════════════════╪═════════════════╡
#     │ C5H8(522)  ┆ C1CC=CC1      ┆ AMChI=1/C5H8/c1 ┆ 0    ┆ 0      ┆ {8,null,null,nu ┆ C   5H   8      │
#     │            ┆               ┆ -2-4-5-3-1/h1-2 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H8O(825) ┆ O1C2C1CCC2    ┆ AMChI=1/C5H8O/c ┆ 0    ┆ 0      ┆ {8,1,null,null, ┆ C   5H   8O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   300.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ OH(4)      ┆ [OH]          ┆ AMChI=1/HO/h1H  ┆ 1    ┆ 0      ┆ {1,1,null,null, ┆ H   1O   1      │
#     │            ┆               ┆                 ┆      ┆        ┆ null,null}      ┆ G   200.00…     │
#     │ C5H7(1202) ┆ C1CC=[C]C1    ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
#     │            ┆               ┆ -2-4-5-3-1/h2H, ┆      ┆        ┆ ll,null,5}      ┆ G   100.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ H2O(5)     ┆ O             ┆ AMChI=1/H2O/h1H ┆ 0    ┆ 0      ┆ {2,1,null,null, ┆ H   2O   1      │
#     │            ┆               ┆ 2               ┆      ┆        ┆ null,null}      ┆ G   200.00…     │
#     │ C5H7(500)  ┆ C1C[CH]C=C1   ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
#     │            ┆               ┆ -2-4-5-3-1/h1-3 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H7(504)  ┆ C1[CH]CC=C1   ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
#     │            ┆               ┆ -2-5-3-4-1/h1-3 ┆      ┆        ┆ ll,null,5}      ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ S(1289)    ┆ O1C2C1C[CH]C2 ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   100.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ C5H7O(758) ┆ O1C2C1[CH]CC2 ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-3-5-4(1)6-5 ┆      ┆        ┆ null,5}         ┆ G   298.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     │ S(1314)    ┆ O1C2CCC[C]12  ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
#     │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5}         ┆ G   100.00…     │
#     │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
#     └────────────┴───────────────┴─────────────────┴──────┴────────┴─────────────────┴─────────────────┘
#   ),
#   rate_units=('KCAL/MOLE', 'MOLES'),
#   thermo_temps=None,
# )
#
# Expanding stereochemistry...
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/A_rh-oh_p1v0_raw.json
# ../data/A_rh-oh_p1v0.json
# ../data/mechanalyzer/A_rh-oh_p1v0.dat
# ../data/mechanalyzer/A_rh-oh_p1v0.csv
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Stereoexpansion errors:

# %%
# Read
workflow.read(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/2068 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/A_rh-oh_p1v0_calc.json
# ../data/full_A_rh-oh_p1v0_control.json
# ../data/full_A_rh-oh_p1v0_calc.json
# ../data/chemkin/full_A_rh-oh_p1v0_control.dat
# ../data/chemkin/full_A_rh-oh_p1v0_calc.dat
#
# Compare calculated mechanism to parent mechanism...
#
# 1. Original (compare):
# C5H8O(825) + OH(4) = C5H7O(758) + H2O(5)            3.350E+07      1.779    -0.1930
# C5H8(522) + OH(4) = C5H7(504) + H2O(5)              1.670E+07      1.779    -0.1930
# C5H8(522) + OH(4) = C5H7(500) + H2O(5)              4.040E+06      2.200    -0.4370
#
# 2. Calculated (compare):
# C5H8(522) + OH(4) = C5H7(500) + H2O(5)                   7.388E+04      2.456     -2.610
# C5H8O(825)rs + OH(4) = C5H7O(758)rs0 + H2O(5)            1.531E+06      2.169     -1.510
# C5H8O(825)rs + OH(4) = C5H7O(758)rs1 + H2O(5)            1.531E+06      2.169     -1.510
# C5H8(522) + OH(4) = C5H7(504) + H2O(5)                   7.220E+05      2.138     -1.342
#
# 3. Calculated (new):
# C5H8O(825)rs + OH(4) = H2O(5) + S(1289)rs            5.495E+04      2.580     -1.162
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r0            1.698E+05      2.388     -1.007
# C5H8(522) + OH(4) = C5H7(1202) + H2O(5)              4.649E+03      2.788      1.079
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r1            1.698E+05      2.388     -1.007
#
#
# 4. Calculated (all together):
# C5H8O(825)rs + OH(4) = H2O(5) + S(1289)rs                5.495E+04      2.580     -1.162
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r0                1.698E+05      2.388     -1.007
# C5H8(522) + OH(4) = C5H7(500) + H2O(5)                   7.388E+04      2.456     -2.610
# C5H8O(825)rs + OH(4) = C5H7O(758)rs0 + H2O(5)            1.531E+06      2.169     -1.510
# C5H8O(825)rs + OH(4) = C5H7O(758)rs1 + H2O(5)            1.531E+06      2.169     -1.510
# C5H8(522) + OH(4) = C5H7(1202) + H2O(5)                  4.649E+03      2.788      1.079
# C5H8(522) + OH(4) = C5H7(504) + H2O(5)                   7.220E+05      2.138     -1.342
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r1                1.698E+05      2.388     -1.007

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)
