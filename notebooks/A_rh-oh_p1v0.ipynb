# %%
from pathlib import Path

import util
from util import workflow

browser = True
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# Build
from automol.graph import enum

import automech
from automech.species import Species

mech0 = automech.io.read(data_path / "full_raw.json")
mech = automech.from_smiles(spc_smis=["C1=CCCC1", "C12C(O2)CCC1"], src_mech=mech0)
#  - enumerate OH abstractions from *ene* and *1-2epoxy*
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.abstraction,
    rcts_=[None, "[OH]"],
    spc_col_=Species.smiles,
    src_mech=mech0,
)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)
# Out:
# Finalizing build for...
# reactions=shape: (6, 5)
# ┌────────────────┬────────────────────────────┬───────────┬────────────┬───────────────────────────┐
# │ reactants      ┆ products                   ┆ formula   ┆ reversible ┆ rate_constant             │
# │ ---            ┆ ---                        ┆ ---       ┆ ---        ┆ ---                       │
# │ list[str]      ┆ list[str]                  ┆ struct[3] ┆ bool       ┆ struct[17]                │
# ╞════════════════╪════════════════════════════╪═══════════╪════════════╪═══════════════════════════╡
# │ ["C5H7(1202)", ┆ ["C5H8(522)", "OH(4)"]     ┆ {9,1,5}   ┆ null       ┆ null                      │
# │ "H2O(5)"]      ┆                            ┆           ┆            ┆                           │
# │ ["C5H8(522)",  ┆ ["C5H7(500)", "H2O(5)"]    ┆ {9,1,5}   ┆ true       ┆ {2,{null,null,null,null,n │
# │ "OH(4)"]       ┆                            ┆           ┆            ┆ ull,n…                    │
# │ ["C5H8(522)",  ┆ ["C5H7(504)", "H2O(5)"]    ┆ {9,1,5}   ┆ true       ┆ {2,{null,null,null,null,n │
# │ "OH(4)"]       ┆                            ┆           ┆            ┆ ull,n…                    │
# │ ["C5H8O(825)", ┆ ["H2O(5)", "S(1289)"]      ┆ {9,2,5}   ┆ null       ┆ null                      │
# │ "OH(4)"]       ┆                            ┆           ┆            ┆                           │
# │ ["C5H8O(825)", ┆ ["C5H7O(758)", "H2O(5)"]   ┆ {9,2,5}   ┆ true       ┆ {2,{null,null,null,null,n │
# │ "OH(4)"]       ┆                            ┆           ┆            ┆ ull,n…                    │
# │ ["C5H8O(825)", ┆ ["H2O(5)", "S(1314)"]      ┆ {9,2,5}   ┆ null       ┆ null                      │
# │ "OH(4)"]       ┆                            ┆           ┆            ┆                           │
# └────────────────┴────────────────────────────┴───────────┴────────────┴───────────────────────────┘ species=shape: (10, 7)
# ┌────────────┬───────────────┬─────────────────┬──────┬────────┬─────────────────┬─────────────────┐
# │ name       ┆ smiles        ┆ amchi           ┆ spin ┆ charge ┆ formula         ┆ thermo_string   │
# │ ---        ┆ ---           ┆ ---             ┆ ---  ┆ ---    ┆ ---             ┆ ---             │
# │ str        ┆ str           ┆ str             ┆ i64  ┆ i64    ┆ struct[7]       ┆ str             │
# ╞════════════╪═══════════════╪═════════════════╪══════╪════════╪═════════════════╪═════════════════╡
# │ C5H8(522)  ┆ C1CC=CC1      ┆ AMChI=1/C5H8/c1 ┆ 0    ┆ 0      ┆ {8,null,null,nu ┆ C   5H   8      │
# │            ┆               ┆ -2-4-5-3-1/h1-2 ┆      ┆        ┆ ll,null,5,null} ┆ G   298.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ C5H8O(825) ┆ O1C2C1CCC2    ┆ AMChI=1/C5H8O/c ┆ 0    ┆ 0      ┆ {8,1,null,null, ┆ C   5H   8O   1 │
# │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5,null}    ┆ G   300.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ OH(4)      ┆ [OH]          ┆ AMChI=1/HO/h1H  ┆ 1    ┆ 0      ┆ {1,1,null,null, ┆ H   1O   1      │
# │            ┆               ┆                 ┆      ┆        ┆ null,null,null} ┆ G   200.00…     │
# │ C5H7(1202) ┆ C1CC=[C]C1    ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
# │            ┆               ┆ -2-4-5-3-1/h2H, ┆      ┆        ┆ ll,null,5,null} ┆ G   100.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ H2O(5)     ┆ O             ┆ AMChI=1/H2O/h1H ┆ 0    ┆ 0      ┆ {2,1,null,null, ┆ H   2O   1      │
# │            ┆               ┆ 2               ┆      ┆        ┆ null,null,null} ┆ G   200.00…     │
# │ C5H7(500)  ┆ C1C[CH]C=C1   ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
# │            ┆               ┆ -2-4-5-3-1/h1-3 ┆      ┆        ┆ ll,null,5,null} ┆ G   298.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ C5H7(504)  ┆ C1[CH]CC=C1   ┆ AMChI=1/C5H7/c1 ┆ 1    ┆ 0      ┆ {7,null,null,nu ┆ C   5H   7      │
# │            ┆               ┆ -2-5-3-4-1/h1-3 ┆      ┆        ┆ ll,null,5,null} ┆ G   298.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ S(1289)    ┆ O1C2C1C[CH]C2 ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
# │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5,null}    ┆ G   100.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ C5H7O(758) ┆ O1C2C1[CH]CC2 ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
# │            ┆               ┆ 1-2-3-5-4(1)6-5 ┆      ┆        ┆ null,5,null}    ┆ G   298.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# │ S(1314)    ┆ O1C2CCC[C]12  ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null, ┆ C   5H   7O   1 │
# │            ┆               ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ null,5,null}    ┆ G   100.00…     │
# │            ┆               ┆ …               ┆      ┆        ┆                 ┆                 │
# └────────────┴───────────────┴─────────────────┴──────┴────────┴─────────────────┴─────────────────┘ thermo_temps=None
#
# Expanding stereochemistry...
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/A_rh-oh_p1v0_raw.json
# ../data/A_rh-oh_p1v0.json
# ../data/mechanalyzer/A_rh-oh_p1v0.dat
# ../data/mechanalyzer/A_rh-oh_p1v0.csv
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Stereoexpansion errors:

# %%
# Read
workflow.read(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/2068 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/A_rh-oh_p1v0_calc.json
# ../data/full_A_rh-oh_p1v0_control.json
# ../data/full_A_rh-oh_p1v0_calc.json
# ../data/chemkin/full_A_rh-oh_p1v0_control.dat
# ../data/chemkin/full_A_rh-oh_p1v0_calc.dat
#
# Compare calculated mechanism to parent mechanism...
#
# 1. Original (compare):
# C5H8O(825) + OH(4) = C5H7O(758) + H2O(5)           33500000      1.779     -193.0
# C5H8(522) + OH(4) = C5H7(504) + H2O(5)             16700000      1.779     -193.0
# C5H8(522) + OH(4) = C5H7(500) + H2O(5)              4040000      2.200     -437.0
#
# 2. Calculated (compare):
# C5H8(522) + OH(4) = C5H7(500) + H2O(5)                     73880      2.456      -2610
# C5H8O(825)rs + OH(4) = C5H7O(758)rs0 + H2O(5)            1531000      2.169      -1510
# C5H8O(825)rs + OH(4) = C5H7O(758)rs1 + H2O(5)            1531000      2.169      -1510
# C5H8(522) + OH(4) = C5H7(504) + H2O(5)                    722000      2.138      -1342
#
# 3. Calculated (new):
# C5H8O(825)rs + OH(4) = H2O(5) + S(1289)rs              54950      2.580      -1162
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r0             169800      2.388      -1007
# C5H8(522) + OH(4) = C5H7(1202) + H2O(5)                 4649      2.788       1079
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r1             169800      2.388      -1007
#
#
# 4. Calculated (all together):
# C5H8O(825)rs + OH(4) = H2O(5) + S(1289)rs                  54950      2.580      -1162
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r0                 169800      2.388      -1007
# C5H8(522) + OH(4) = C5H7(500) + H2O(5)                     73880      2.456      -2610
# C5H8O(825)rs + OH(4) = C5H7O(758)rs0 + H2O(5)            1531000      2.169      -1510
# C5H8O(825)rs + OH(4) = C5H7O(758)rs1 + H2O(5)            1531000      2.169      -1510
# C5H8(522) + OH(4) = C5H7(1202) + H2O(5)                     4649      2.788       1079
# C5H8(522) + OH(4) = C5H7(504) + H2O(5)                    722000      2.138      -1342
# C5H8O(825)rs + OH(4) = H2O(5) + S(1314)r1                 169800      2.388      -1007

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)

# %%
# Plot
charts = workflow.plot(
    full_tag=f"full_{tag}_calc",
    x_col="O2_molecules",
    y_col_=["C5H8(522)", "C5H8O(825)rs"],
    root_path=root_path,
    line_source_=["hill", "lokachari"],
    point_source="experiment",
)
for chart in charts:
    chart.show()
# Out:
# alt.LayerChart(...)
# alt.LayerChart(...)
