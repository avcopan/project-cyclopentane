# %%
from pathlib import Path

from mechdriver.subtasks import display, fs

tag = "A_rh-oh_p2v2"
root_path = Path("..")
calc_path = root_path / "calc" / tag

# %%
subtask_key = "1: 20"

display("find_ts", subtask_key, path=calc_path)
# Out:
# Lowest frequency mode:
#   frequency: -2120.6833709043344
# <div id="3dmolviewer_17377528114918833"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17377528114918833" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17377528114918833 = null;
# var warn = document.getElementById("3dmolwarning_17377528114918833");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17377528114918833 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17377528114918833"),{backgroundColor:"white"});
# viewer_17377528114918833.zoomTo();
# 	viewer_17377528114918833.addModel(" 15\n\nC   -0.714983  -0.015820  -0.153637    0.009079   0.003369  -0.013517\nC   -0.016332   1.198218   0.446525    0.001639   0.000445  -0.000131\nO   -2.062194  -0.218861  -0.136701    0.000456   0.000230  -0.000236\nC    1.204424   0.826469  -0.386495    0.011391   0.005292   0.013284\nH    0.109212   1.197846   1.546072    0.007231   0.003441  -0.000543\nH   -0.474009   2.146683   0.125855   -0.001274  -0.001936  -0.000342\nC    1.558888  -0.592911   0.016386   -0.001280   0.000486  -0.002499\nH    1.970768   1.550824  -0.682301    0.007667   0.010590  -0.019668\nH    0.119635   0.366831  -1.225274   -0.913052  -0.399549   0.071481\nC    0.148026  -1.214694   0.180125    0.000217  -0.000768   0.002209\nH    2.120222  -0.616975   0.967598    0.000836   0.010655  -0.005026\nH    2.173385  -1.108086  -0.736499    0.003098  -0.003939  -0.000030\nH   -0.043835  -2.060376  -0.496821   -0.002908   0.006819   0.000513\nH   -0.050829  -1.561992   1.208939    0.004511  -0.000588   0.003755\nH   -2.507137   0.628555  -0.231386    0.000382  -0.002605  -0.008332","xyz",{"vibrate": {"frames": 10, "amplitude": 1}});
# 	viewer_17377528114918833.setStyle({"stick": {}, "sphere": {"radius": 0.3}});
# 	viewer_17377528114918833.setBackgroundColor("0xeeeeee");
# 	viewer_17377528114918833.animate({"loop": "backAndForth"});
# 	viewer_17377528114918833.zoomTo();
# viewer_17377528114918833.render();
# });
# </script>

# %%
for path in fs.task_paths("find_ts", subtask_key, path=calc_path):
    print(path)

display("rpath_scan", subtask_key, path=calc_path)
