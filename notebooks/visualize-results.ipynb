# %%
from pathlib import Path

from automech.subtasks import display, fs

tag = "A_rh-oh_p2v1"
root_path = Path("..")
calc_path = root_path / tag

# %%
subtask_key = "1: 5"
for path in fs.task_paths("find_ts", subtask_key, path=calc_path):
    print(path)

display("find_ts", subtask_key, path=calc_path)
display("rpath_scan", subtask_key, path=calc_path)
# Out:
# /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save/RXN/C5H9O/MPAMKJKBAJNWEI/0/2/RXMQYKEDSA-N/C5H9O/ZOCQCVFDVWWLHS/0/2/YFKPBYRVSA-N/2/u-unGOU/TS/00
# /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save/RXN/C5H9O/MPAMKJKBAJNWEI/0/2/RXMQYKEDSA-N/C5H9O/ZOCQCVFDVWWLHS/0/2/YFKPBYRVSA-N/2/u-unGOU/TS/01
# Lowest frequency mode:
#   frequency: -2183.7488807273444
# <div id="3dmolviewer_17373911557733517"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17373911557733517" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17373911557733517 = null;
# var warn = document.getElementById("3dmolwarning_17373911557733517");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17373911557733517 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17373911557733517"),{backgroundColor:"white"});
# viewer_17373911557733517.zoomTo();
# 	viewer_17373911557733517.addModel(" 15\n\nC   -1.426832   0.581795  -0.002294    0.002501  -0.006178  -0.016327\nC   -1.168236  -0.827002   0.514568    0.001188  -0.001530  -0.000563\nC   -0.087095   1.283290   0.035336    0.001120   0.000602   0.001934\nH   -2.378051   1.112451   0.124435    0.017514  -0.005116   0.020621\nC   -0.176018  -0.979438  -0.635853    0.010128  -0.009928   0.009667\nH   -0.766922  -0.906998   1.542686    0.001277  -0.002070  -0.000667\nH   -2.036473  -1.492143   0.418214    0.001438  -0.002655  -0.000400\nH    0.098951  -1.941116  -1.085510   -0.005748  -0.011065  -0.019518\nH   -1.113216  -0.088998  -1.195590   -0.569214   0.701912   0.280476\nC    0.846707   0.134167  -0.464548   -0.001344   0.000709  -0.001278\nH    0.207005   1.575489   1.059149    0.006350   0.001680   0.000711\nH   -0.043347   2.185677  -0.591340   -0.002572  -0.003562  -0.000402\nH    1.328800   0.392648  -1.418744    0.000774   0.005222  -0.001639\nO    1.905256  -0.186462   0.403903   -0.000103  -0.000207  -0.000141\nH    1.530045  -0.502189   1.232218   -0.001854  -0.000543  -0.000455","xyz",{"vibrate": {"frames": 10, "amplitude": 3}});
# 	viewer_17373911557733517.setStyle({"stick": {}, "sphere": {"radius": 0.3}});
# 	viewer_17373911557733517.setBackgroundColor("0xeeeeee");
# 	viewer_17373911557733517.animate({"loop": "backAndForth"});
# 	viewer_17373911557733517.zoomTo();
# viewer_17373911557733517.render();
# });
# </script>
# Lowest frequency mode:
#   frequency: -2163.4415929503157
# <div id="3dmolviewer_17373911558192"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17373911558192" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17373911558192 = null;
# var warn = document.getElementById("3dmolwarning_17373911558192");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17373911558192 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17373911558192"),{backgroundColor:"white"});
# viewer_17373911558192.zoomTo();
# 	viewer_17373911558192.addModel(" 15\n\nC    1.231075   0.706725  -0.470304    0.009135   0.009574   0.011664\nC    1.580231  -0.596345   0.237754    0.000929   0.001761  -0.000479\nC   -0.010559   1.218181   0.230221    0.000020  -0.001085  -0.002249\nH    1.977091   1.370815  -0.922651    0.003917   0.005201  -0.024383\nC    0.199045  -1.100000  -0.159416    0.001306   0.008859  -0.014482\nH    2.393738  -1.150473  -0.249086    0.000942   0.002667  -0.000738\nH    1.779889  -0.523284   1.322105    0.000457   0.002382  -0.000839\nH   -0.058306  -2.159081  -0.286150    0.004086   0.013940   0.019709\nH    0.493858  -0.222880  -1.231567   -0.464695  -0.812397   0.140142\nC   -0.798433  -0.115848   0.424922   -0.000652  -0.000097   0.002263\nH   -0.602767   1.931524  -0.362459   -0.003603   0.002716   0.001376\nH    0.231514   1.705550   1.190910    0.006755   0.000025  -0.005468\nH   -0.977585  -0.320821   1.494327   -0.006820   0.007116   0.003169\nO   -2.063780  -0.150101  -0.175669    0.000243  -0.000027   0.000041\nH   -1.935349  -0.106817  -1.129144    0.002413  -0.001072  -0.000646","xyz",{"vibrate": {"frames": 10, "amplitude": 3}});
# 	viewer_17373911558192.setStyle({"stick": {}, "sphere": {"radius": 0.3}});
# 	viewer_17373911558192.setBackgroundColor("0xeeeeee");
# 	viewer_17373911558192.animate({"loop": "backAndForth"});
# 	viewer_17373911558192.zoomTo();
# viewer_17373911558192.render();
# });
# </script>
# <div id="3dmolviewer_17373911593683558"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17373911593683558" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17373911593683558 = null;
# var warn = document.getElementById("3dmolwarning_17373911593683558");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17373911593683558 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17373911593683558"),{backgroundColor:"white"});
# viewer_17373911593683558.zoomTo();
# 	viewer_17373911593683558.addModelsAsFrames(" 15\n\nC   -1.233898   0.697632  -0.785641\nC   -1.352591   0.348353   0.660656\nC    0.169448   0.429576  -1.225456\nH   -2.019237   1.130047  -1.406798\nC   -0.478644  -0.914872   0.712384\nH   -0.907197   1.145776   1.296034\nH   -2.380641   0.203392   1.021981\nH   -0.168557  -1.233466   1.718304\nH   -1.035910  -1.744280   0.248719\nC    0.741574  -0.555540  -0.157577\nH    0.791487   1.347548  -1.218113\nH    0.238331   0.033434  -2.251995\nH    1.170314  -1.447903  -0.634625\nO    1.795867  -0.014890   0.605094\nH    1.458300   0.740513   1.096646\n 15\n\nC   -1.244208   0.677762  -0.790975\nC   -1.340717   0.360981   0.664173\nC    0.167304   0.436300  -1.221400\nH   -2.043444   1.071064  -1.420012\nC   -0.483001  -0.913954   0.704040\nH   -0.864220   1.160393   1.273666\nH   -2.361098   0.237220   1.052956\nH   -0.184508  -1.258074   1.705087\nH   -1.049277  -1.724612   0.218429\nC    0.742919  -0.552906  -0.156913\nH    0.770484   1.366447  -1.188782\nH    0.258452   0.057875  -2.252272\nH    1.170730  -1.443369  -0.638230\nO    1.797794  -0.018782   0.609948\nH    1.461958   0.733755   1.107062\n 15\n\nC   -1.254002   0.656210  -0.794761\nC   -1.329847   0.374518   0.668755\nC    0.164908   0.440671  -1.217151\nH   -2.061946   1.024586  -1.427493\nC   -0.488617  -0.912184   0.693369\nH   -0.826590   1.175697   1.253434\nH   -2.342528   0.268762   1.081426\nH   -0.207500  -1.290411   1.687139\nH   -1.063514  -1.698285   0.178095\nC    0.745246  -0.550131  -0.155291\nH    0.747682   1.382873  -1.162222\nH    0.276650   0.078445  -2.251285\nH    1.172158  -1.439518  -0.639308\nO    1.801076  -0.021386   0.614346\nH    1.467453   0.729148   1.115988\n 15\n\nC   -1.262654   0.633195  -0.796813\nC   -1.320650   0.388664   0.674740\nC    0.162884   0.442978  -1.212938\nH   -2.075034   0.989714  -1.430525\nC   -0.494794  -0.908948   0.681074\nH   -0.797919   1.192649   1.237309\nH   -2.326584   0.295020   1.105869\nH   -0.236733  -1.329396   1.664090\nH   -1.077370  -1.664568   0.129679\nC    0.748359  -0.547416  -0.153116\nH    0.724593   1.396711  -1.138948\nH    0.292730   0.095292  -2.249508\nH    1.173827  -1.436902  -0.638198\nO    1.805150  -0.023026   0.617895\nH    1.473792   0.726076   1.123178\n 15\n\nC   -1.269761   0.609153  -0.797329\nC   -1.313157   0.402895   0.682199\nC    0.161680   0.443935  -1.209120\nH   -2.083380   0.964061  -1.430399\nC   -0.500676  -0.903944   0.668235\nH   -0.779544   1.211922   1.225960\nH   -2.313899   0.314128   1.125906\nH   -0.271322  -1.373631   1.635952\nH   -1.089478  -1.623415   0.076120\nC    0.751858  -0.544931  -0.150784\nH    0.702643   1.408270  -1.119352\nH    0.306654   0.108842  -2.247482\nH    1.174848  -1.435797  -0.635569\nO    1.809142  -0.024123   0.620436\nH    1.479541   0.723882   1.128464\n 15\n\nC   -1.275248   0.584600  -0.796796\nC   -1.306977   0.416521   0.690889\nC    0.161443   0.444350  -1.205992\nH   -2.087816   0.945422  -1.428137\nC   -0.505579  -0.897122   0.656074\nH   -0.770910   1.233385   1.218990\nH   -2.304240   0.325646   1.141731\nH   -0.311094  -1.422025   1.602770\nH   -1.098945  -1.574700   0.020095\nC    0.755295  -0.542820  -0.148561\nH    0.682987   1.417988  -1.103619\nH    0.318386   0.119481  -2.245603\nH    1.174558  -1.436149  -0.632222\nO    1.812387  -0.025012   0.622014\nH    1.483661   0.722119   1.131834\n 15\n\nC   -1.279266   0.560073  -0.795837\nC   -1.301638   0.428817   0.700336\nC    0.162076   0.444866  -1.203654\nH   -2.089207   0.932184  -1.424490\nC   -0.509073  -0.888712   0.645777\nH   -0.770196   1.255856   1.215595\nH   -2.297063   0.330484   1.153541\nH   -0.355774  -1.473200   1.564576\nH   -1.105893  -1.517186  -0.036562\nC    0.758234  -0.541209  -0.146681\nH    0.666556   1.426165  -1.091646\nH    0.327718   0.127478  -2.244044\nH    1.172816  -1.437573  -0.629022\nO    1.814604  -0.025859   0.622823\nH    1.485792   0.720582   1.133514\n 15\n\nC   -1.282052  ...
# <div id="3dmolviewer_17373911596295698"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17373911596295698" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17373911596295698 = null;
# var warn = document.getElementById("3dmolwarning_17373911596295698");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17373911596295698 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17373911596295698"),{backgroundColor:"white"});
# viewer_17373911596295698.zoomTo();
# 	viewer_17373911596295698.addModelsAsFrames(" 15\n\nC   -1.155896  -1.020068  -0.535946\nC   -1.270717  -0.682060   0.914543\nC    0.245576  -0.752827  -0.974630\nH   -1.928210  -1.494912  -1.142703\nC   -0.396348   0.575299   0.983841\nH   -2.298614  -0.538989   1.277572\nH   -0.817806  -1.481791   1.539101\nH   -0.107908   0.888548   1.997571\nH   -0.944248   1.412996   0.516457\nC    0.813876   0.227766   0.097848\nH    0.323769  -0.311749  -1.983670\nH    0.846290  -1.683360  -1.013565\nH    1.566606  -0.294504   0.708953\nO    1.481634   1.342799  -0.425733\nH    0.843282   1.861287  -0.925697\n 15\n\nC   -1.163598  -1.000500  -0.540708\nC   -1.258384  -0.693579   0.918033\nC    0.247011  -0.760397  -0.967698\nH   -1.951362  -1.433689  -1.158342\nC   -0.401728   0.576566   0.975271\nH   -2.279292  -0.572134   1.306580\nH   -0.774242  -1.493076   1.518625\nH   -0.124210   0.916006   1.983647\nH   -0.959776   1.394771   0.485633\nC    0.814724   0.227504   0.100591\nH    0.350286  -0.338952  -1.982091\nH    0.830303  -1.702925  -0.977230\nH    1.566320  -0.288802   0.718112\nO    1.479660   1.342583  -0.425633\nH    0.838193   1.862093  -0.920496\n 15\n\nC   -1.171224  -0.979379  -0.543982\nC   -1.246726  -0.705914   0.922633\nC    0.247781  -0.766193  -0.960914\nH   -1.969484  -1.382660  -1.168125\nC   -0.407024   0.576321   0.964034\nH   -2.260356  -0.602141   1.333814\nH   -0.735940  -1.505449   1.500072\nH   -0.144815   0.950120   1.964340\nH   -0.974599   1.369776   0.445091\nC    0.817375   0.226124   0.103590\nH    0.374032  -0.361874  -1.979009\nH    0.811335  -1.720706  -0.945478\nH    1.568258  -0.284237   0.726887\nO    1.477791   1.342670  -0.424909\nH    0.831784   1.862815  -0.913130\n 15\n\nC   -1.178354  -0.956811  -0.545607\nC   -1.236702  -0.718949   0.928604\nC    0.248301  -0.769963  -0.954456\nH   -1.982484  -1.342852  -1.173018\nC   -0.411948   0.574031   0.950860\nH   -2.243734  -0.626769   1.357777\nH   -0.706301  -1.519926   1.485137\nH   -0.169974   0.990159   1.939493\nH   -0.987748   1.337144   0.396187\nC    0.821962   0.223797   0.106778\nH    0.394627  -0.379849  -1.974865\nH    0.790599  -1.736234  -0.919198\nH    1.573016  -0.280580   0.734699\nO    1.475984   1.343167  -0.424064\nH    0.824243   1.863032  -0.904888\n 15\n\nC   -1.184572  -0.933319  -0.545797\nC   -1.228622  -0.732284   0.935981\nC    0.248924  -0.771990  -0.948707\nH   -1.990931  -1.313010  -1.174309\nC   -0.416345   0.569685   0.936991\nH   -2.230458  -0.644727   1.377746\nH   -0.686743  -1.537039   1.474598\nH   -0.199762   1.034931   1.909498\nH   -0.998726   1.296945   0.341892\nC    0.827853   0.220993   0.109927\nH    0.412049  -0.393291  -1.970449\nH    0.769733  -1.749297  -0.898325\nH    1.580120  -0.277647   0.740907\nO    1.474288   1.343963  -0.423417\nH    0.816507   1.862944  -0.896907\n 15\n\nC   -1.189660  -0.909404  -0.545026\nC   -1.222140  -0.745285   0.944555\nC    0.249863  -0.772937  -0.943997\nH   -1.995674  -1.291136  -1.173038\nC   -0.420128   0.563458   0.923763\nH   -2.220444  -0.655777   1.393666\nH   -0.676787  -1.556648   1.468184\nH   -0.234667   1.083564   1.874672\nH   -1.007588   1.249082   0.285067\nC    0.834034   0.218269   0.112797\nH    0.426506  -0.403139  -1.966440\nH    0.750293  -1.760026  -0.882171\nH    1.588496  -0.275306   0.745016\nO    1.472753   1.344846  -0.423062\nH    0.809701   1.863110  -0.889951\n 15\n\nC   -1.193603  -0.885493  -0.543880\nC   -1.216690  -0.757216   0.953914\nC    0.251200  -0.773524  -0.940449\nH   -1.997565  -1.275464  -1.169959\nC   -0.423106   0.555616   0.912414\nH   -2.213111  -0.660644   1.405628\nH   -0.674780  -1.577732   1.465147\nH   -0.274933   1.135016   1.835131\nH   -1.014936   1.192092   0.227551\nC    0.839463   0.216092   0.115182\nH    0.438050  -0.410195  -1.963176\nH    0.733574  -1.768709  -0.869973\nH    1.596799  -0.273446   0.746911\nO    1.471434   1.345631  -0.422965\nH    0.804602   1.863980  -0.884390\n 15\n\nC   -1.196489  ...
