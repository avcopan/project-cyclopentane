# %%
from pathlib import Path

import util
from util import workflow

browser = False
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")

# %%
# Build
from util import p_

import automech

sub_tags = [
    "A_rh-oh_p1v0",
    "B_rh-ho2_p1v0",
    "B_rh-ho2_p2v0",
    "C_r_p1v0",
    "C_r_p2v0",
    "C_r_p3v0",
    "D_r-o2_p1v0",
    "D_r-o2_p2v0",
    "D_r-o2_p3v0",
]
sub_paths = [p_.original_mechanism(t, "json", p_.data(root_path)) for t in sub_tags]
sub_mechs = [automech.io.read(p) for p in sub_paths]
mech = automech.combine_all(sub_mechs)
mech = automech.drop_duplicate_reactions(mech)
automech.display(mech)

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)
# Out:
# Finalizing build for...
# reactions=shape: (32, 5)
# ┌────────────────────────┬────────────────────────┬───────────┬────────────┬───────────────────────┐
# │ reactants              ┆ products               ┆ formula   ┆ reversible ┆ rate_constant         │
# │ ---                    ┆ ---                    ┆ ---       ┆ ---        ┆ ---                   │
# │ list[str]              ┆ list[str]              ┆ struct[3] ┆ bool       ┆ struct[17]            │
# ╞════════════════════════╪════════════════════════╪═══════════╪════════════╪═══════════════════════╡
# │ ["C5H8(522)", "OH(4)"] ┆ ["C5H7(1202)",         ┆ {5,9,1}   ┆ null       ┆ null                  │
# │                        ┆ "H2O(5)"]              ┆           ┆            ┆                       │
# │ ["C5H8(522)", "OH(4)"] ┆ ["C5H7(500)",          ┆ {5,9,1}   ┆ true       ┆ {2,{null,null,null,nu │
# │                        ┆ "H2O(5)"]              ┆           ┆            ┆ ll,null,n…            │
# │ ["C5H8(522)", "OH(4)"] ┆ ["C5H7(504)",          ┆ {5,9,1}   ┆ true       ┆ {2,{null,null,null,nu │
# │                        ┆ "H2O(5)"]              ┆           ┆            ┆ ll,null,n…            │
# │ ["C5H8O(825)",         ┆ ["S(1289)", "H2O(5)"]  ┆ {5,9,2}   ┆ null       ┆ null                  │
# │ "OH(4)"]               ┆                        ┆           ┆            ┆                       │
# │ ["C5H8O(825)",         ┆ ["C5H7O(758)",         ┆ {5,9,2}   ┆ true       ┆ {2,{null,null,null,nu │
# │ "OH(4)"]               ┆ "H2O(5)"]              ┆           ┆            ┆ ll,null,n…            │
# │ …                      ┆ …                      ┆ …         ┆ …          ┆ …                     │
# │ ["O2(6)", "S(1289)"]   ┆ ["S(1691)"]            ┆ {5,7,3}   ┆ true       ┆ {2,{null,null,null,nu │
# │                        ┆                        ┆           ┆            ┆ ll,null,n…            │
# │ ["S(1690)"]            ┆ ["HO2(8)", "S(1288)"]  ┆ {5,7,3}   ┆ true       ┆ {1,{null,null,null,nu │
# │                        ┆                        ┆           ┆            ┆ ll,null,n…            │
# │ ["C5H9O(852)",         ┆ ["S(594)"]             ┆ {5,9,3}   ┆ true       ┆ {2,{null,null,null,nu │
# │ "O2(6)"]               ┆                        ┆           ┆            ┆ ll,null,n…            │
# │ ["S(594)"]             ┆ ["HO2(8)", "S(1227)"]  ┆ {5,9,3}   ┆ true       ┆ {1,{null,null,null,nu │
# │                        ┆                        ┆           ┆            ┆ ll,null,n…            │
# │ ["S(594)"]             ┆ ["HO2(8)", "S(1228)"]  ┆ {5,9,3}   ┆ true       ┆ {1,{null,null,null,nu │
# │                        ┆                        ┆           ┆            ┆ ll,null,n…            │
# └────────────────────────┴────────────────────────┴───────────┴────────────┴───────────────────────┘ species=shape: (34, 10)
# ┌────────────┬────────────┬────────────┬──────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ name       ┆ smiles     ┆ amchi      ┆ spin ┆ … ┆ thermo_str ┆ jiirryjjm ┆ fmtmdfmpu ┆ fyobvsifi │
# │ ---        ┆ ---        ┆ ---        ┆ ---  ┆   ┆ ing        ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ str        ┆ str        ┆ i64  ┆   ┆ ---        ┆ str       ┆ str       ┆ str       │
# │            ┆            ┆            ┆      ┆   ┆ str        ┆           ┆           ┆           │
# ╞════════════╪════════════╪════════════╪══════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ C5H8(522)  ┆ C1CC=CC1   ┆ AMChI=1/C5 ┆ 0    ┆ … ┆ C   5H   8 ┆ AMChI=1/C ┆ null      ┆ null      │
# │            ┆            ┆ H8/c1-2-4- ┆      ┆   ┆ G          ┆ 5H8/c1-2- ┆           ┆           │
# │            ┆            ┆ 5-3-1/h1-2 ┆      ┆   ┆ 298.00…    ┆ 4-5-3-1/h ┆           ┆           │
# │            ┆            ┆ …          ┆      ┆   ┆            ┆ 1-2…      ┆           ┆           │
# │ OH(4)      ┆ [OH]       ┆ AMChI=1/HO ┆ 1    ┆ … ┆ H   1O   1 ┆ null      ┆ null      ┆ null      │
# │            ┆            ┆ /h1H       ┆      ┆   ┆ G          ┆           ┆           ┆           │
# │            ┆            ┆            ┆      ┆   ┆ 200.00…    ┆           ┆           ┆           │
# │ C5H7(1202) ┆ C1CC=[C]C1 ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ C   5H   7 ┆ AMChI=1/C ┆ null      ┆ null      │
# │            ┆            ┆ H7/c1-2-4- ┆      ┆   ┆ G          ┆ 5H7/c1-2- ┆           ┆           │
# │            ┆            ┆ 5-3-1/h2H, ┆      ┆   ┆ 100.00…    ┆ 4-5-3-1/h ┆           ┆           │
# │            ┆            ┆ …          ┆      ┆   ┆            ┆ 2H,…      ┆           ┆           │
# │ H2O(5)     ┆ O          ┆ AMChI=1/H2 ┆ 0    ┆ … ┆ H   2O   1 ┆ null      ┆ null      ┆ null      │
# │            ┆            ┆ O/h1H2     ┆      ┆   ┆ G          ┆           ┆           ┆           │
# │            ┆            ┆            ┆      ┆   ┆ 200.00…    ┆           ┆           ┆           │
# │ C5H7(500)  ┆ C1C[CH]C=C ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ C   5H   7 ┆ AMChI=1/C ┆ AMChI=1/C ┆ null      │
# │            ┆ 1          ┆ H7/c1-2-4- ┆      ┆   ┆ G          ┆ 5H7/c1-2- ┆ 5H7/c1-2- ┆           │
# │            ┆            ┆ 5-3-1/h1-3 ┆      ┆   ┆ 298.00…    ┆ 4-5-3-1/h ┆ 4-5-3-1/h ┆           │
# │            ┆            ┆ …          ┆      ┆   ┆            ┆ 1-3…      ┆ 1-3…      ┆           │
# │ …          ┆ …          ┆ …          ┆ …    ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ S(1688)    ┆ O1C2CCC=C1 ┆ AMChI=1/C5 ┆ 0    ┆ … ┆ C   5H     ┆ null      ┆ null      ┆ AMChI=1/C │
# │            ┆ 2          ┆ H6O/c1-2-3 ┆      ┆   ┆ 6O   1     ┆           ┆           ┆ 5H6O/c1-2 │
# │            ┆            ┆ -5-4(1)6-5 ┆      ┆   ┆ G          ┆           ┆           ┆ -3-5-4(1) │
# │            ┆            ┆ …          ┆      ┆   ┆ 100.00…    ┆           ┆           ┆ 6-5…      │
# │ S(1690)    ┆ [O]OC1C2OC ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ C   5H     ┆ null      ┆ null      ┆ AMChI=1/C │
# │            ┆ 2CC1       ┆ H7O3/c6-8- ┆      ┆   ┆ 7O   3     ┆           ┆           ┆ 5H7O3/c6- │
# │            ┆            ┆ 4-2-1-3-5( ┆      ┆   ┆ G          ┆           ┆           ┆ 8-4-2-1-3 │
# │            ┆            ┆ …          ┆      ┆   ┆ 100.00…    ┆           ┆           ┆ -5(…      │
# │ S(594)     ┆ OC1C(O[O]) ┆ AMChI=1/C5 ┆ 1    ┆ … ┆ C   5H     ┆ null      ┆ null      ┆ null      │
# │            ┆ CCC1       ┆ H9O3/c6-8- ┆      ┆   ┆ 9O   3     ┆           ┆           ┆           │
# │            ┆            ┆ 5-3-1-2-4( ┆      ┆   ┆ G          ┆           ┆           ┆           │
# │            ┆            ┆ …          ┆      ┆   ┆ 298.00…    ┆           ┆           ┆           │
# │ S(1227)    ┆ OC=1CCCC=1 ┆ AMChI=1/C5 ┆ 0    ┆ … ┆ C   5H     ┆ null      ┆ null      ┆ null      │
# │            ┆            ┆ H8O/c6-5-1 ┆      ┆   ┆ 8O   1     ┆           ┆           ┆           │
# │            ┆            ┆ -2-3-4-5/h ┆      ┆   ┆ G          ┆           ┆           ┆           │
# │            ┆            ┆ …          ┆      ┆   ┆ 100.00…    ┆           ┆           ┆           │
# │ S(1228)    ┆ OC1CCC=C1  ┆ AMChI=1/C5 ┆ 0    ┆ … ┆ C   5H     ┆ null      ┆ null      ┆ null      │
# │            ┆            ┆ H8O/c6-5-2 ┆      ┆   ┆ 8O   1     ┆           ┆           ┆           │
# │            ┆            ┆ -1-3-4-5/h ┆      ┆   ┆ G          ┆           ┆           ┆           │
# │            ┆            ┆ …          ┆      ┆   ┆ 100.00…    ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴──────┴───┴────────────┴───────────┴───────────┴───────────┘ thermo_temps=None
#
# Expanding stereochemistry...
#   0%|          | 0/34 [00:00<?, ?it/s]
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/Y_all_v0_orig.json
# ../data/Y_all_v0.json
# ../data/mechanalyzer/Y_all_v0.dat
# ../data/mechanalyzer/Y_all_v0.csv
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/59 [00:00<?, ?it/s]
# Stereoexpansion errors:

# %%
# # Read
# workflow.prepare_simulation(tag=tag, root_path=root_path)

# %%
# # Plot
# charts = workflow.plot(
#     full_tag=f"full_{tag}_calc",
#     x_col="O2_molecules",
#     y_col_=["C5H8(522)", "C5H8O(825)rs"],
#     root_path=root_path,
#     line_source_=["hill", "lokachari"],
#     point_source="experiment",
# )
# for chart in charts:
#     chart.show()

# %%
# import automech
# from mechdriver.subtasks import display

# chan = "2: 5"

# # TRANSITION STATE
# #   - Read in expanded mechanism
# mech_path = util.p_.mechanism(tag, ext="json", path=util.p_.data(root_path))
# mech = automech.io.read(mech_path)

# #   - Display the reaction
# automech.display_reactions(mech, chans=[chan])

# %%
# #   - Display the TS mode
# calc_path = util.p_.calc(root_path, tag)
# display("conf_opt", chan, path=calc_path)

# %%
# #   - Display the TS mode
# calc_path = util.p_.calc(root_path, tag)
# display("find_ts", chan, path=calc_path)

# %%
# # REACTION RATE
# #   - Read in calculated mechanism
# cal_mech = automech.io.read(data_path / f"{tag}_calc.json")

# #   - Read in other mechanisms for comparison
# par_mech = automech.io.read(data_path / "full_raw.json")
# tags0 = util.previous_tags(tag)
# trues = [True] * len(tags0)
# names0 = list(map(util.calculated_mechanism_name, tags0))
# mechs0 = [automech.io.read(data_path / f"{name}.json") for name in names0]

# #   - Display the reaction and calculated rate
# automech.display_reactions(
#     cal_mech,
#     chans=[chan],
#     comp_mechs=[par_mech, *mechs0],
#     comp_labels=["Hill", *tags0],
#     comp_stereo=[False, *trues],
# )
