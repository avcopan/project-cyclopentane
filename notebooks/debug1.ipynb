# %%
from importlib import reload

from mechlib.reaction import rxnid
# Out:
# <module 'mechlib.reaction.rxnid' from '/lcrc/project/PACC/copan/amech-dev/src/mechdriver/mechlib/reaction/rxnid.py'>

# %%
reload(rxnid)

rxnid.build_reaction(
    rxn_info=(
        (
            ("InChI=1S/C5H7O/c1-2-5-3-4(1)6-5/h3-5H,1-2H2/t4-,5+",),
            ("InChI=1S/C5H6O/c1-2-5-3-4(1)6-5/h3-4H,1-2H2/t4-/m1/s1", "InChI=1S/H"),
        ),
        ((0,), (0, 0)),
        ((2,), (1, 2)),
        2,
    ),
    ini_thy_info=("gaussian16", "wb97xd", "def2-svp", "RU"),
    zma_locs=(0,),
    save_prefix="/lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save",
    id_missing=True,
    re_id=False,
)
# Out:
#     Trying to find class info from fileysystem...
#     No info found. Identifying class...
#     Reaction ID from geometries from SAVE filesys
#      - reactant 1: /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save/SPC/C5H7O/SQBNIHHRZYUNFP/0/2/SYDPRGILSA-N/u-unGOU/CONFS/r6pKtVxVGU93D/cccEDlp_67rHa/geom.xyz
#      - product 1: /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save/SPC/C5H6O/VHYOFFONUACUGT/0/1/SCSAIBSYSA-N/u-unGOR/CONFS/r2GAK6EooHGgD/cBje1V1M7MW8Y/geom.xyz
#      - product 2: /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save/SPC/H/YZCKVEUIGOORGS/0/2/UHFFFAOYSA-N/u-unGOU/CONFS/r1GHOHhONlUfY/c1dW7tC9Nt2Ti/geom.xyz
# ...
