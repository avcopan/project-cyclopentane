# %%
import automol

# %%
chi = "InChI=1S/C5H6O/c1-2-4-5(3-1)6-4/h2,5H,1,3H2/t5-/m0/s1"
gra = automol.chi.graph(chi)
automol.graph.display(gra)

# %%
automol.graph.geometry(gra)
# Out:
# (('C', (-1.6695522628686985, -1.2312253822200707, -0.20227513074349418)),
#  ('C', (-1.9754620574377915, 1.531047814982717, -0.7738313756854461)),
#  ('C', (1.172526868464497, -1.5221197321370434, 0.34558719973877333)),
#  ('C', (0.06045031816523049, 2.904045284321626, -0.12547848669819636)),
#  ('C', (2.1912185062164506, 1.1277921784383529, 0.4041427187657437)),
#  ('O', (1.1925636896939773, 2.725656186621586, 2.232270243721339)),
#  ('H', (-2.2197282846406625, -2.396359463205004, -1.8200877672455262)),
#  ('H', (-2.822622651423839, -1.7752402685272908, 1.4265523589692422)),
#  ('H', (-3.485424515050609, 2.2521688918205047, -1.9457957606578287)),
#  ('H', (2.090934725221872, -2.609675140728209, -1.158222413150441)),
#  ('H', (1.4985103229474281, -2.5016516334720924, 2.138841365040101)),
#  ('H', (3.9665853407236877, 1.4955612641284077, -0.5217029520685846)))
