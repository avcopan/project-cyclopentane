# %%
from pathlib import Path

import util
from util import p_, workflow

import automech

file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
par_mech = workflow.read_parent_mechanism(root_path=root_path)

# %%
# # Generate submechanism
# from automol.graph import enum

# gen_mech = automech.from_smiles(
#     spc_smis=["C1=C[CH]CC1", "C1=CC[CH]C1"],
#     src_mech=par_mech,
# )
# #  - Ring-opening scissions
# gen_mech = automech.enumerate_reactions(
#     gen_mech,
#     enum.ReactionSmarts.ring_beta_scission,
#     src_mech=par_mech,
# )
# automech.display(gen_mech)

# %%
# # Expand stereochemistry
# ste_mech, *_, gen_mech = workflow.expand_stereo(
#     mech=gen_mech, tag=tag, root_path=root_path
# )

# %%
# # Prepare calculation
# workflow.prepare_calculation(
#     gen_mech=gen_mech, ste_mech=ste_mech, tag=tag, root_path=root_path
# )

# %%
# Gather statistics
workflow.gather_statistics(tag=tag, root_path=root_path)
# Out:
# New species and reactions:
#
# SPECIES
#
# END
#
#
# REACTIONS    CAL/MOL   MOL
#
# END
#
#
#
# Statistics summary:
#
# shape: (5, 3)
# ┌────────────────────┬───────────────┬────────────────┐
# │ Mechanism          ┆ Species Count ┆ Reaction Count │
# │ ---                ┆ ---           ┆ ---            │
# │ str                ┆ i64           ┆ i64            │
# ╞════════════════════╪═══════════════╪════════════════╡
# │ Parent             ┆ 2534          ┆ 10002          │
# │ Generated          ┆ 4             ┆ 2              │
# │ Stereo             ┆ 7             ┆ 2              │
# │ Generated - Parent ┆ 0             ┆ 0              │
# │ Stereo - Parent    ┆ 0             ┆ 0              │
# └────────────────────┴───────────────┴────────────────┘

# %%
# Prepare simulation
workflow.prepare_simulation(tag=tag, root_path=root_path)
workflow.prepare_simulation_species(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/96 [00:00<?, ?it/s]
# Writing mechanism to JSON...
#
# Writing mechanism to Chemkin...
# Control: ../data/chemkin/full_C_r_1e_v0_control.dat
# Calculated: ../data/chemkin/full_C_r_1e_v0_calc.dat
#
# Converting ChemKin mechanism to Cantera YAML...
# Wrote YAML mechanism file to '../data/cantera/full_C_r_1e_v0_control.yaml'.
# Mechanism contains 2537 species and 10097 reactions.
# Wrote YAML mechanism file to '../data/cantera/full_C_r_1e_v0_calc.yaml'.
# Mechanism contains 2537 species and 10097 reactions.
#
# Validating Cantera model...
#
# Reading in species...
#
# Writing simulation species names to CSV...
# ../data/cantera/C_r_1e_v0_species.csv
# shape: (20, 6)
# ┌────────────┬───────────────────────┬───────────┬────────────┬───────────────┬────────────┐
# │ orig_name  ┆ Experiment            ┆ Lokachari ┆ Hill       ┆ concentration ┆ name       │
# │ ---        ┆ ---                   ┆ ---       ┆ ---        ┆ ---           ┆ ---        │
# │ str        ┆ str                   ┆ str       ┆ str        ┆ str           ┆ str        │
# ╞════════════╪═══════════════════════╪═══════════╪════════════╪═══════════════╪════════════╡
# │ C5H8(522)  ┆ cyclopentene          ┆ CYC5H8    ┆ C5H8(522)  ┆ null          ┆ C5H8(522)  │
# │ C5H8O(825) ┆ 1,2-epoxycyclopentane ┆ CPTYO12   ┆ C5H8O(825) ┆ null          ┆ C5H8O(825) │
# │ CPT(563)   ┆ cyclopentane          ┆ CPT       ┆ CPT(563)   ┆ CPT_frac      ┆ CPT(563)   │
# │ O2(6)      ┆ O2                    ┆ O2        ┆ O2(6)      ┆ O2_frac       ┆ O2(6)      │
# │ N2         ┆ null                  ┆ N2        ┆ N2         ┆ N2_frac       ┆ N2         │
# │ …          ┆ …                     ┆ …         ┆ …          ┆ …             ┆ …          │
# │ C4H8(253)  ┆ 1-butene              ┆ C4H8-1    ┆ C4H8(253)  ┆ null          ┆ C4H8(253)  │
# │ C5H6(478)  ┆ cyclopentadiene       ┆ C5H6      ┆ C5H6(478)  ┆ null          ┆ C5H6(478)  │
# │ C6H6(970)  ┆ benzene               ┆ C6H6      ┆ C6H6(970)  ┆ null          ┆ C6H6(970)  │
# │ HO2(8)     ┆ null                  ┆ HO2       ┆ HO2(8)     ┆ null          ┆ HO2(8)     │
# │ OH(4)      ┆ null                  ┆ OH        ┆ OH(4)      ┆ null          ┆ OH(4)      │
# └────────────┴───────────────────────┴───────────┴────────────┴───────────────┴────────────┘

# %%
# Check rates
workflow.plot_rates(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Compare calculated mechanism to parent mechanism...
#
# *********
# Reaction: C5H7(487)e = C5H7(504)
# Translations:
#   smiles:
#     reactants = ['[H]/[C]=C/CC=C']
#     products = ['C1=CC[CH]C1']
# Rate parameters:
#   This work:
#     C5H7(487)e = C5H7(504)                                   1.502E+24     -4.270      16320
#   Hill:
#     C5H7(487) = C5H7(504)                                        1.000      0.000      0.000
#         PLOG  /   0.001000  5.540E+26     -8.105       2440/
#         PLOG  /    0.01000  1.260E+32     -9.071       4720/
#         PLOG  /     0.1000  2.170E+40     -10.77      10830/
#         PLOG  /      1.000  2.960E+46     -11.84      17388/
#         PLOG  /      10.00  9.720E+45     -11.03      21236/
#         PLOG  /      100.0  1.020E+35     -7.312      19527/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)
# *********
# Reaction: C5H7(507)zz = C5H7(500)
# Translations:
#   smiles:
#     reactants = ['C=/C/C=\\C\\[CH2]']
#     products = ['C1=CCC[CH]1']
# Rate parameters:
#   This work:
#     C5H7(507)zz = C5H7(500)                                      1.000      0.000      0.000
#         PLOG  /     0.1000  3.266E+41     -9.022      41588/
#         PLOG  /      1.000  6.950E+61     -14.53      58449/
#         PLOG  /      1.000  1.751E+37     -7.876      38818/
#         PLOG  /      10.00  4.957E+28     -5.117      36289/
#         PLOG  /      10.00  2.755E+55     -12.37      58919/
#         PLOG  /      100.0  8.606E+21     -2.970      34084/
#         PLOG  /      100.0  2.895E+44     -9.016      55574/
#   Hill:
#     C5H7(507) = C5H7(500)                                        1.000      0.000      0.000
#         PLOG  /   0.001000  2.300E+58     -15.41      44473/
#         PLOG  /    0.01000  7.530E+59     -15.36      48239/
#         PLOG  /     0.1000  2.670E+62     -15.61      52958/
#         PLOG  /      1.000  1.360E+58     -13.92      54075/
#         PLOG  /      10.00  1.220E+43     -9.184      48981/
#         PLOG  /      100.0  4.690E+27     -4.474      42601/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)

# %%
# # Plot simulation
# chart_dct = workflow.plot_simulation(
#     tag=tag,
#     x_col="O2_molecules",
#     root_path=root_path,
#     line_source_=["Hill", "Lokachari"],
#     point_source="Experiment",
#     control=False,
# )
# mech = automech.io.read(
#     p_.full_calculated_mechanism(tag, "json", path=p_.data(root_path))
# )
# for name, chart in chart_dct.items():
#     automech.display_species(mech, [name])
#     chart.show()

# %%
# # Check TS
# from mechdriver.subtasks import display

# chan = "2: 5"

# #   - Read in expanded mechanism
# mech_path = p_.mechanism(tag, ext="json", path=p_.data(root_path))
# mech = automech.io.read(mech_path)

# #   - Display the reaction
# automech.display_reactions(mech, chans=[chan])

# %%
# #   - Display the TS mode
# calc_path = p_.calc(root_path, tag)
# display("conf_opt", chan, path=calc_path)

# %%
# #   - Display the TS mode
# calc_path = p_.calc(root_path, tag)
# display("find_ts", chan, path=calc_path)
