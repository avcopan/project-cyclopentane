# %%
from pathlib import Path

from IPython import get_ipython

import automech

tag, *_ = Path(get_ipython().user_ns.get("__vsc_ipynb_file__")).stem.split(".")

# %%
DATA_PATH = Path("../data")

# %%
# Read
mech0 = automech.io.read(DATA_PATH / "1ene_named.json")
# Out:
#   0%|          | 0/1639 [00:00<?, ?it/s]
#   0%|          | 0/1639 [00:00<?, ?it/s]

# %%
# Build
#  - RMG selection: radius 1 neighborhood of *ene* on RH + OH PES
mech = automech.select_pes(mech0, "C5H9O")
mech = automech.neighborhood(mech, ["C5H8(522)"], radius=1)
mech = automech.without_duplicate_reactions(mech)
# Out:
#   0%|          | 0/1639 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/97 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Expand and sort
mech, err_mech = automech.expand_stereo(mech, distinct_ts=False)
mech = automech.with_sort_data(mech)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Write
automech.io.write(mech, DATA_PATH / f"{tag}.json")
automech.io.mechanalyzer.write.mechanism(
    mech,
    rxn_out=DATA_PATH / "mechanalyzer" / f"{tag}.dat",
    spc_out=DATA_PATH / "mechanalyzer" / f"{tag}.csv",
)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# ('REACTIONS    KCAL/MOLE   MOLES\n\nC5H8(522) + OH(4) = C5H9O(852)r0            9.240E+01      3.090      7.200   # pes.subpes.channel  1.1.1\nC5H8(522) + OH(4) = C5H9O(852)r1            9.240E+01      3.090      7.200   # pes.subpes.channel  1.2.2\n\nEND',
#  "name,smiles,inchi,inchikey,mult,charge,canon_enant_ich\nOH(4),[OH],InChI=1S/HO/h1H,TUJKJAMUKRIRHC-UHFFFAOYSA-N,2,0,InChI=1S/HO/h1H\nC5H8(522),C1=CCCC1,'InChI=1S/C5H8/c1-2-4-5-3-1/h1-2H,3-5H2',LPIQUOYDBNQMRZ-UHFFFAOYSA-N,1,0,'InChI=1S/C5H8/c1-2-4-5-3-1/h1-2H,3-5H2'\nC5H9O(852)r0,O[C@H]1[CH]CCC1,'InChI=1S/C5H9O/c6-5-3-1-2-4-5/h3,5-6H,1-2,4H2/t5-/m0/s1',ZOCQCVFDVWWLHS-YFKPBYRVSA-N,2,0,'InChI=1S/C5H9O/c6-5-3-1-2-4-5/h3,5-6H,1-2,4H2/t5-/m0/s1'\nC5H9O(852)r1,O[C@@H]1[CH]CCC1,'InChI=1S/C5H9O/c6-5-3-1-2-4-5/h3,5-6H,1-2,4H2/t5-/m1/s1',ZOCQCVFDVWWLHS-RXMQYKEDSA-N,2,0,'InChI=1/C5H9O/c6-5-3-1-2-4-5/h3,5-6H,1-2,4H2/t5-/m0/s1'\n")

# %%
# Display
automech.display(mech)

automech.display_reactions(err_mech)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
