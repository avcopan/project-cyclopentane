# %%
from pathlib import Path

import util
from util import workflow

browser = True
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# Build
from automol.graph import enum

import automech
from automech.species import Species

mech0 = automech.io.read(data_path / "full_raw.json")
mech = automech.from_smiles(spc_smis=["C1=CCCC1"], src_mech=mech0)
#  - add OH addition to *ene*
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.pi2_addition,
    rcts_=[None, "[OH]"],
    spc_col_=Species.smiles,
    src_mech=mech0,
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)
# Out:
# Finalizing build for...
# reactions=shape: (1, 5)
# ┌────────────────────────┬────────────────┬───────────┬────────────┬───────────────────────────────┐
# │ reactants              ┆ products       ┆ formula   ┆ reversible ┆ rate_constant                 │
# │ ---                    ┆ ---            ┆ ---       ┆ ---        ┆ ---                           │
# │ list[str]              ┆ list[str]      ┆ struct[3] ┆ bool       ┆ struct[17]                    │
# ╞════════════════════════╪════════════════╪═══════════╪════════════╪═══════════════════════════════╡
# │ ["C5H8(522)", "OH(4)"] ┆ ["C5H9O(852)"] ┆ {5,9,1}   ┆ true       ┆ {2,{null,null,null,null,null, │
# │                        ┆                ┆           ┆            ┆ n…                            │
# └────────────────────────┴────────────────┴───────────┴────────────┴───────────────────────────────┘ species=shape: (3, 7)
# ┌────────────┬─────────────┬──────────────────┬──────┬────────┬──────────────────┬─────────────────┐
# │ name       ┆ smiles      ┆ amchi            ┆ spin ┆ charge ┆ formula          ┆ thermo_string   │
# │ ---        ┆ ---         ┆ ---              ┆ ---  ┆ ---    ┆ ---              ┆ ---             │
# │ str        ┆ str         ┆ str              ┆ i64  ┆ i64    ┆ struct[7]        ┆ str             │
# ╞════════════╪═════════════╪══════════════════╪══════╪════════╪══════════════════╪═════════════════╡
# │ C5H8(522)  ┆ C1CC=CC1    ┆ AMChI=1/C5H8/c1- ┆ 0    ┆ 0      ┆ {8,null,null,nul ┆ C   5H   8      │
# │            ┆             ┆ 2-4-5-3-1/h1-2…  ┆      ┆        ┆ l,null,5,null}   ┆ G   298.00…     │
# │ OH(4)      ┆ [OH]        ┆ AMChI=1/HO/h1H   ┆ 1    ┆ 0      ┆ {1,1,null,null,n ┆ H   1O   1      │
# │            ┆             ┆                  ┆      ┆        ┆ ull,null,null}   ┆ G   200.00…     │
# │ C5H9O(852) ┆ OC1CCC[CH]1 ┆ AMChI=1/C5H9O/c6 ┆ 1    ┆ 0      ┆ {9,1,null,null,n ┆ C   5H   9O   1 │
# │            ┆             ┆ -5-1-2-3-4-5/h…  ┆      ┆        ┆ ull,5,null}      ┆ G   298.00…     │
# └────────────┴─────────────┴──────────────────┴──────┴────────┴──────────────────┴─────────────────┘ thermo_temps=None
#
# Expanding stereochemistry...
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/A_rh-oh_p2v0_raw.json
# ../data/A_rh-oh_p2v0.json
# ../data/mechanalyzer/A_rh-oh_p2v0.dat
# ../data/mechanalyzer/A_rh-oh_p2v0.csv
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Stereoexpansion errors:

# %%
# Read
workflow.read(tag=tag, root_path=root_path)
# Out:
# Reading mechanisms...
#
# Adding calculated thermo...
#
# Adding calculated rates...
#
# Expanding and updating parent...
#   0%|          | 0/1986 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/A_rh-oh_p2v0_calc.json
# ../data/full_A_rh-oh_p2v0_control.json
# ../data/full_A_rh-oh_p2v0_calc.json
# ../data/chemkin/full_A_rh-oh_p2v0_control.dat
# ../data/chemkin/full_A_rh-oh_p2v0_calc.dat
#
# Compare calculated mechanism to parent mechanism...
#
# *********
# Reaction: C5H8(522) + OH(4) = C5H9O(852)r0
# Translations:
#   smiles:
#     reactants = ['C1=CCCC1', '[OH]']
#     products = ['O[C@H]1[CH]CCC1']
# Rate parameters:
#   This work:
#     C5H8(522) + OH(4) = C5H9O(852)r0                             1.000      0.000      0.000
#         PLOG  /     0.1000  2.943E+68     -17.80      15946/
#         PLOG  /      1.000  6.065E+61     -15.34      15528/
#         PLOG  /      10.00  5.109E+49     -11.31      12742/
#         PLOG  /      100.0  2.625E+31     -5.669       5647/
#         PLOG  /      100.0 1.790E+152     -41.39      68944/
#   Hill:
#     C5H8(522) + OH(4) = C5H9O(852)                               1.000      0.000      0.000
#         PLOG  /    0.01000  3.650E+77     -20.00      33874/
#         PLOG  /    0.01000  9.700E+59     -15.51      12898/
#         PLOG  /     0.1000  1.380E+68     -17.01      27909/
#         PLOG  /     0.1000  1.800E+56     -14.04      12945/
#         PLOG  /      1.000  2.600E+59     -14.17      23079/
#         PLOG  /      1.000  2.070E+50     -12.04      11493/
#         PLOG  /      10.00  1.010E+54     -12.23      22976/
#         PLOG  /      10.00  8.550E+41     -9.350       8921/
#         PLOG  /      100.0  1.920E+48     -10.23      23772/
#         PLOG  /      100.0  3.060E+32     -6.310       6088/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)
# *********
# Reaction: C5H8(522) + OH(4) = C5H9O(852)r1
# Translations:
#   smiles:
#     reactants = ['C1=CCCC1', '[OH]']
#     products = ['O[C@@H]1[CH]CCC1']
# Rate parameters:
#   This work:
#     C5H8(522) + OH(4) = C5H9O(852)r1                             1.000      0.000      0.000
#         PLOG  /     0.1000  2.027E+68     -17.77      15771/
#         PLOG  /      1.000  1.378E+62     -15.47      15569/
#         PLOG  /      10.00  1.288E+50     -11.45      12828/
#         PLOG  /      100.0  3.197E+31     -5.702       5639/
#         PLOG  /      100.0 4.315E+150     -40.93      67897/
#   Hill:
#     C5H8(522) + OH(4) = C5H9O(852)                               1.000      0.000      0.000
#         PLOG  /    0.01000  3.650E+77     -20.00      33874/
#         PLOG  /    0.01000  9.700E+59     -15.51      12898/
#         PLOG  /     0.1000  1.380E+68     -17.01      27909/
#         PLOG  /     0.1000  1.800E+56     -14.04      12945/
#         PLOG  /      1.000  2.600E+59     -14.17      23079/
#         PLOG  /      1.000  2.070E+50     -12.04      11493/
#         PLOG  /      10.00  1.010E+54     -12.23      22976/
#         PLOG  /      10.00  8.550E+41     -9.350       8921/
#         PLOG  /      100.0  1.920E+48     -10.23      23772/
#         PLOG  /      100.0  3.060E+32     -6.310       6088/
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)
