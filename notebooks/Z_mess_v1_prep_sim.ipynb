# %%
from pathlib import Path

from project_utilities import workflow

tag = "Z_mess_v1"
therm_tag = "Z_combined_v0"
root_path = Path("..")
T_drop = (825.0,)
racemic = True

# %%
stoichs_kwargs = [
    ("C5H7", {}),
    ("C5H7O2", {}),
    ("C5H9O", {}),
    ("C5H9O2", {"clear_rates": [("C5H8O(833)+OH(4)", "C5H8O(829)rs+OH(4)")]}),
]

for stoich, kwargs in stoichs_kwargs:
    print(f"Running {stoich} with {kwargs}")
    mech, surf0 = workflow.postprocess_rate_data(
        stoich=stoich,
        tag=tag,
        therm_tag=therm_tag,
        root_path=root_path,
        T_drop=T_drop,
        racemic=racemic,
        **kwargs,
    )
    print()
# Out:
# Running C5H7 with {}
# Reading in primary source mechanism and selecting C5H7 PES...
# Adding thermochemistry data...
# Post-processing rate data...
#  - Reading in MESS input...
#  - Reading in MESS output...
#  - Integrating over fake nodes...
#  - Clearing unfittable pressure ranges...
#  - Removing unfittable well-skipping rates...
#  - Removing irrelevant well-skipping rates...
#  - Removing isolated nodes...
#  - Checking for bad pressure-independence well-skipping rates...
#  - Checking for non-irrelevant bad pressure-independence direct rates...
#  - Clearing bad pressure-independence direct rates that are irrelevant...
#  - Determining irrelevant pressures...
#  - Fitting rates...
# Fitting ('C5H7(500)', 'C5H7(504)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(500)', 'C5H7(507)zz')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(500)', 'C5H7(487)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(500)', 'C2H2(40)+C3H5(122)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(500)', 'C5H6(478)+H(1)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(504)', 'C5H7(500)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(504)', 'C5H7(507)zz')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(504)', 'C5H7(487)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(504)', 'C2H2(40)+C3H5(122)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(504)', 'C5H6(478)+H(1)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(507)zz', 'C5H7(500)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(507)zz', 'C5H7(504)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(507)zz', 'C5H7(487)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(507)zz', 'C5H6(478)+H(1)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(487)e', 'C5H7(500)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(487)e', 'C5H7(504)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(487)e', 'C5H7(507)zz')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(487)e', 'C2H2(40)+C3H5(122)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(487)e', 'C5H6(478)+H(1)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(487)z', 'C2H2(40)+C3H5(122)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C2H2(40)+C3H5(122)', 'C5H7(500)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C2H2(40)+C3H5(122)', 'C5H7(504)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C2H2(40)+C3H5(122)', 'C5H7(487)e')...
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=11.170372606269245 b=3.575816753461065 E=41199.07788669566 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=135989643668.2293 b=0.7805663772583085 E=44687.146129886234 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=40.75975125807722 b=3.4793782968923614 E=29285.908923473475 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=3260827697053.372 b=0.4583792664360522 E=44184.18856777419 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=148377424662.94998 b=0.39841023789546925 E=30251.144073209936 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=69542924.75699262 b=0.8782303167422043 E=10735.043611096327 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C2H2(40)+C3H5(122)', 'C5H7(487)z')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C2H2(40)+C3H5(122)', 'C5H6(478)+H(1)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+H(1)', 'C5H7(500)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+H(1)', 'C5H7(504)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+H(1)', 'C5H7(507)zz')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+H(1)', 'C5H7(487)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+H(1)', 'C2H2(40)+C3H5(122)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Adding rate data...
#  - Adding direct rate data...
# Writing mechanisms to JSON...
#  - Calculated: ../data/Z_mess_v1_calc_C5H7.json
# Writing mechanisms to Chemkin...
#  - Calculated: ../data/chemkin/Z_mess_v1_calc_C5H7.dat
# Writing mechanisms to Cantera...
#  - Calculated: ../data/cantera/Z_mess_v1_calc_C5H7.yaml
# Converting ChemKin mechanism to Cantera YAML...
# Wrote YAML mechanism file to '../data/cantera/Z_mess_v1_calc_C5H7.yaml'.
# Mechanism contains 9 species and 15 reactions.
# Validating Cantera model...
#
# Running C5H7O2 with {}
# Reading in primary source mechanism and selecting C5H7O2 PES...
# Adding thermochemistry data...
# Post-processing rate data...
#  - Reading in MESS input...
#  - Reading in MESS output...
# /home/avcopan/code/pm/autochem/src/autochem/rate/data.py:211: RuntimeWarning: divide by zero encountered in divide
#   k_data = self.k_data / other.k_data
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=1.0166649681728041e-05 b=4.998371008200516 E=24321.930665594125 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=0.00043547551919636066 b=4.322117207409702 E=20136.364044227055 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
#  - Integrating over fake nodes...
#  - Clearing unfittable pressure ranges...
#  - Removing unfittable well-skipping rates...
#  - Removing irrelevant well-skipping rates...
#  - Removing isolated nodes...
#  - Checking for bad pressure-independence well-skipping rates...
#  - Checking for non-irrelevant bad pressure-independence direct rates...
#  - Clearing bad pressure-independence direct rates that are irrelevant...
#  - Determining irrelevant pressures...
#  - Fitting rates...
# Fitting ('S(1206)rR', 'S(1209)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1206)rR', 'S(1210)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1206)rR', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1206)rR', 'C5H7(500)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1209)rR', 'S(1206)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1209)rR', 'S(1210)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1209)rR', 'C5O2pkpfsderR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1209)rR', 'C5O2sidwaoee')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1209)rR', 'C5O2sidwaoez')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1209)rR', 'CPND2(626)+OH(4)')...
# Fitting ('S(1209)rR', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1209)rR', 'OH(4)+S(1288)rsR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1210)rR', 'S(1206)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1210)rR', 'S(1209)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1210)rR', 'S(602)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1210)rR', 'C5H6O(645)z+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1210)rR', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1210)rR', 'OH(4)+S(1288)rsR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(1210)rR', 'C5Oqidgnvrs+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2pkpfsderR', 'S(1209)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2pkpfsderR', 'CPND2(626)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2pkpfsderR', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2pkpfsderR', 'OH(4)+S(1288)rsR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2pkpfsderR', 'C5H7(500)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2pkpfsderR', 'C2H2(40)+C3H4O(165)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2sidwaoee', 'S(1209)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2sidwaoee', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2sidwaoee', 'OH(4)+S(1288)rsR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2sidwaoee', 'C5H7(500)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2sidwaoee', 'C2H2(40)+C3H4O(165)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2sidwaoez', 'S(1209)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2sidwaoez', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2sidwaoez', 'OH(4)+S(1288)rsR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2sidwaoez', 'C5H7(500)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5O2sidwaoez', 'C2H2(40)+C3H4O(165)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(602)', 'S(1210)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(602)', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(602)', 'OH(4)+S(1288)rsR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(602)', 'C5H7(504)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('CPND2(626)+OH(4)', 'S(1209)rR')...
# Fitting ('CPND2(626)+OH(4)', 'C5O2pkpfsderR')...
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=0.0003286275885410276 b=4.226907297230952 E=10710.313602489576 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=238.90442646667174 b=3.1513893190462983 E=28263.774095381435 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=672192616241.6616 b=0.5165569225914681 E=44586.56169448815 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=2173591689720.8245 b=0.3992933007832531 E=43209.90160257753 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=2227819528.6751614 b=1.0895841404425797 E=44441.413692048205 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=0.02627459380433221 b=3.497820671288091 E=19388.47837791514 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=354.9885208360974 b=3.1279987935775333 E=41076.71629061984 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=4.484336107650174e-08 b=5.2728166556181595 E=14985.114127718558 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=2148366105.829056 b=0.5101265561474116 E=10429.877100181977 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/rate/data.py:646: RuntimeWarning: overflow encountered in exp
#   obj = cls(order=order, A=np.exp(lnA), b=b, E=E)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=2417591604.8200517 b=1.3841243180707474 E=22925.578918411695 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=69885912.05931595 b=1.0149220067521711 E=9977.257392932359 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=6202636768.677254 b=1.197391071898203 E=25460.927914690477 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=311390.0281964061 b=1.5242204804227484 E=11183.053353247442 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=6178234480.716736 b=1.1809153311732985 E=24388.579810866497 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# /home/avcopan/code/pm/autochem/src/autochem/unit_/_manager.py:60: UserWarning: Currently not fitting high-pressure limit T_min=None T_max=None order=1 efficiencies={} A=1.5530876251927595e-08 b=5.892272128734434 E=16634.92974652615 type='arrhenius'
#   return func0(self, *args, units=units, **kwargs)
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6O(645)z+OH(4)', 'S(1210)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6O(645)z+OH(4)', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6O(645)z+OH(4)', 'OH(4)+S(1288)rsR')...
# Fitting ('C5H6(478)+HO2(8)', 'S(1206)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'S(1209)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'S(1210)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'C5O2pkpfsderR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'C5O2sidwaoee')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'C5O2sidwaoez')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'S(602)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'C5H6O(645)z+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'OH(4)+S(1288)rsR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'C5Oqidgnvrs+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'C5H7(500)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H6(478)+HO2(8)', 'C5H7(504)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('OH(4)+S(1288)rsR', 'S(1209)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('OH(4)+S(1288)rsR', 'S(1210)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('OH(4)+S(1288)rsR', 'C5O2pkpfsderR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('OH(4)+S(1288)rsR', 'C5O2sidwaoee')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('OH(4)+S(1288)rsR', 'C5O2sidwaoez')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('OH(4)+S(1288)rsR', 'S(602)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('OH(4)+S(1288)rsR', 'C5H6O(645)z+OH(4)')...
# Fitting ('OH(4)+S(1288)rsR', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('OH(4)+S(1288)rsR', 'C5Oqidgnvrs+OH(4)')...
# Fitting ('OH(4)+S(1288)rsR', 'C5H7(504)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5Oqidgnvrs+OH(4)', 'S(1210)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5Oqidgnvrs+OH(4)', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5Oqidgnvrs+OH(4)', 'OH(4)+S(1288)rsR')...
# Fitting ('C5H7(500)+O2(6)', 'S(1206)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(500)+O2(6)', 'C5O2pkpfsderR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(500)+O2(6)', 'C5O2sidwaoee')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(500)+O2(6)', 'C5O2sidwaoez')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(500)+O2(6)', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(504)+O2(6)', 'S(602)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(504)+O2(6)', 'C5H6(478)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(504)+O2(6)', 'OH(4)+S(1288)rsR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C2H2(40)+C3H4O(165)+OH(4)', 'C5O2pkpfsderR')...
# Fitting ('C2H2(40)+C3H4O(165)+OH(4)', 'C5O2sidwaoee')...
# Fitting ('C2H2(40)+C3H4O(165)+OH(4)', 'C5O2sidwaoez')...
# Adding rate data...
#  - Adding direct rate data...
# Writing mechanisms to JSON...
#  - Calculated: ../data/Z_mess_v1_calc_C5H7O2.json
# Writing mechanisms to Chemkin...
#  - Calculated: ../data/chemkin/Z_mess_v1_calc_C5H7O2.dat
# Writing mechanisms to Cantera...
#  - Calculated: ../data/cantera/Z_mess_v1_calc_C5H7O2.yaml
# Converting ChemKin mechanism to Cantera YAML...
# Wrote YAML mechanism file to '../data/cantera/Z_mess_v1_calc_C5H7O2.yaml'.
# Mechanism contains 19 species and 40 reactions.
# Validating Cantera model...
#
# Running C5H9O with {}
# Reading in primary source mechanism and selecting C5H9O PES...
# Adding thermochemistry data...
# Post-processing rate data...
#  - Reading in MESS input...
#  - Reading in MESS output...
#  - Integrating over fake nodes...
#  - Clearing unfittable pressure ranges...
#  - Removing unfittable well-skipping rates...
#  - Removing irrelevant well-skipping rates...
#  - Removing isolated nodes...
#  - Checking for bad pressure-independence well-skipping rates...
#  - Checking for non-irrelevant bad pressure-independence direct rates...
#  - Clearing bad pressure-independence direct rates that are irrelevant...
#  - Determining irrelevant pressures...
#  - Fitting rates...
# Fitting ('C5H9O(852)rR', 'C5H9O(853)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(852)rR', 'C5H9O(853)z')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(852)rR', 'C5H9O(878)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(852)rR', 'S(1247)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(852)rR', 'S(1248)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(852)rR', 'H(1)+S(1227)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(852)rR', 'H(1)+S(1228)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(852)rR', 'C5H8(522)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(852)rR', 'C5H7(1202)+H2O(5)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(852)rR', 'C5H7(504)+H2O(5)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(852)rR', 'C5H7(500)+H2O(5)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(853)e', 'C5H9O(852)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(853)e', 'C5H9O(878)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(853)e', 'C2H4(52)+C3H5O(168)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(853)e', 'C5H8(522)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(853)e', 'C5H7(504)+H2O(5)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(853)e', 'C5H7(500)+H2O(5)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(853)z', 'C5H9O(852)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(853)z', 'C2H4(52)+C3H5O(168)z')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(853)z', 'C5H8(522)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(853)z', 'C5H7(500)+H2O(5)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(878)rR', 'C5H9O(852)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(878)rR', 'C5H9O(853)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(878)rR', 'C2H4(52)+C3H5O(168)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(878)rR', 'C2H4(52)+C3H5O(168)z')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9O(878)rR', 'C5H8(522)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# ...
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(731)rR', 'S(722)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(731)rR', 'C5H8(522)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(731)rR', 'C5H8O(825)rs+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(731)rR', 'C2H4(52)+C3H4O(165)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(734)rR', 'S(719)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(734)rR', 'S(725)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(734)rR', 'C5H8O(829)rs+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(734)rR', 'C2H4O2(58)+C3H5(122)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('S(734)rR', 'C5H8(524)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(833)+OH(4)', 'S(725)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(833)+OH(4)', 'C2H4O2(58)+C3H5(122)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(833)+OH(4)', 'C5H8(524)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(833)+OH(4)', 'C5H9(553)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(522)+HO2(8)', 'S(719)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(522)+HO2(8)', 'S(722)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(522)+HO2(8)', 'S(728)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(522)+HO2(8)', 'S(728)z')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(522)+HO2(8)', 'S(731)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(522)+HO2(8)', 'C5H8O(825)rs+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(522)+HO2(8)', 'C5H9(553)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(522)+HO2(8)', 'C5H7(500)+H2O2(10)')...
# Fitting ('C5H8(522)+HO2(8)', 'C5H7(504)+H2O2(10)')...
# Fitting ('C5H8(522)+HO2(8)', 'C5H7(1202)+H2O2(10)')...
# Fitting ('C5H8O(825)rs+OH(4)', 'S(719)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(825)rs+OH(4)', 'S(722)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(825)rs+OH(4)', 'S(728)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(825)rs+OH(4)', 'S(728)z')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(825)rs+OH(4)', 'S(731)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(825)rs+OH(4)', 'C5H8(522)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(825)rs+OH(4)', 'C5H9(553)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(829)rs+OH(4)', 'S(719)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(829)rs+OH(4)', 'S(725)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(829)rs+OH(4)', 'S(728)e')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(829)rs+OH(4)', 'S(734)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(829)rs+OH(4)', 'C2H4O2(58)+C3H5(122)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(829)rs+OH(4)', 'C5H8(524)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8O(829)rs+OH(4)', 'C5H9(553)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C2H4O2(58)+C3H5(122)', 'S(734)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C2H4O2(58)+C3H5(122)', 'C5H8O(833)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C2H4O2(58)+C3H5(122)', 'C5H8O(829)rs+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C2H4O2(58)+C3H5(122)', 'C5H8(524)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(524)+HO2(8)', 'S(734)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(524)+HO2(8)', 'C5H8O(833)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(524)+HO2(8)', 'C5H8O(829)rs+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(524)+HO2(8)', 'C2H4O2(58)+C3H5(122)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H8(524)+HO2(8)', 'C5H9(553)+O2(6)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9(553)+O2(6)', 'S(719)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9(553)+O2(6)', 'S(725)rR')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9(553)+O2(6)', 'C5H8O(833)+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9(553)+O2(6)', 'C5H8(522)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9(553)+O2(6)', 'C5H8O(825)rs+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9(553)+O2(6)', 'C5H8O(829)rs+OH(4)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H9(553)+O2(6)', 'C5H8(524)+HO2(8)')...
# Fitting Arrhenius rate for P = 0.1
# Fitting Arrhenius rate for P = 0.32
# Fitting Arrhenius rate for P = 1.0
# Fitting Arrhenius rate for P = 3.2
# Fitting Arrhenius rate for P = 10.0
# Fitting Arrhenius rate for P = 32.0
# Fitting Arrhenius rate for P = 100.0
# Fitting ('C5H7(500)+H2O2(10)', 'C5H8(522)+HO2(8)')...
# Fitting ('C5H7(504)+H2O2(10)', 'C5H8(522)+HO2(8)')...
# Fitting ('C5H7(1202)+H2O2(10)', 'C5H8(522)+HO2(8)')...
# Fitting ('C2H4(52)+C3H4O(165)+OH(4)', 'S(728)e')...
# Fitting ('C2H4(52)+C3H4O(165)+OH(4)', 'S(728)z')...
# Fitting ('C2H4(52)+C3H4O(165)+OH(4)', 'S(731)rR')...
# Adding rate data...
#  - Adding direct rate data...
# Writing mechanisms to JSON...
#  - Calculated: ../data/Z_mess_v1_calc_C5H9O2.json
# Writing mechanisms to Chemkin...
#  - Calculated: ../data/chemkin/Z_mess_v1_calc_C5H9O2.dat
# Writing mechanisms to Cantera...
#  - Calculated: ../data/cantera/Z_mess_v1_calc_C5H9O2.yaml
# Converting ChemKin mechanism to Cantera YAML...
# Wrote YAML mechanism file to '../data/cantera/Z_mess_v1_calc_C5H9O2.yaml'.
# Mechanism contains 24 species and 44 reactions.
# Validating Cantera model...

# %%
stoichs, _ = zip(*stoichs_kwargs, strict=True)
workflow.prepare_simulation(tag, stoichs=stoichs, root_path=root_path)
# Out:
# Reading mechanisms...
#  - Parent: ../data/full_parent.json
#  - Calculated: [PosixPath('../data/Z_mess_v1_calc_C5H7.json'), PosixPath('../data/Z_mess_v1_calc_C5H7O2.json'), PosixPath('../data/Z_mess_v1_calc_C5H9O.json'), PosixPath('../data/Z_mess_v1_calc_C5H9O2.json')]
# Expanding and updating parent...
#   0%|          | 0/6166 [00:00<?, ?it/s]
# Writing mechanism to JSON...
#  - Full control: ../data/full_Z_mess_v1_control.json
#  - Full calculated: ../data/full_Z_mess_v1_calc.json
#  - Calculated: ../data/Z_mess_v1_calc.json
# Writing mechanism to Chemkin...
#  - Full control: ../data/chemkin/full_Z_mess_v1_control.dat
#  - Full calculated: ../data/chemkin/full_Z_mess_v1_calc.dat
#  - Calculated: ../data/chemkin/Z_mess_v1_calc.dat
# Converting ChemKin mechanism to Cantera YAML...
# Wrote YAML mechanism file to '../data/cantera/full_Z_mess_v1_control.yaml'.
# Mechanism contains 2538 species and 10082 reactions.
# Wrote YAML mechanism file to '../data/cantera/full_Z_mess_v1_calc.yaml'.
# Mechanism contains 2542 species and 10159 reactions.
# Validating Cantera model...

# %%
workflow.prepare_simulation_species(tag, root_path=root_path)
# Out:
# Reading in species...
#
# Writing simulation species names to CSV...
# ../data/cantera/Z_mess_v1_species.csv
# shape: (20, 6)
# ┌────────────┬───────────────────────┬───────────┬────────────┬───────────────┬──────────────┐
# │ orig_name  ┆ Experiment            ┆ Lokachari ┆ Hill       ┆ concentration ┆ name         │
# │ ---        ┆ ---                   ┆ ---       ┆ ---        ┆ ---           ┆ ---          │
# │ str        ┆ str                   ┆ str       ┆ str        ┆ str           ┆ str          │
# ╞════════════╪═══════════════════════╪═══════════╪════════════╪═══════════════╪══════════════╡
# │ C5H8(522)  ┆ cyclopentene          ┆ CYC5H8    ┆ C5H8(522)  ┆ null          ┆ C5H8(522)    │
# │ C5H8O(825) ┆ 1,2-epoxycyclopentane ┆ CPTYO12   ┆ C5H8O(825) ┆ null          ┆ C5H8O(825)rs │
# │ CPT(563)   ┆ cyclopentane          ┆ CPT       ┆ CPT(563)   ┆ CPT_frac      ┆ CPT(563)     │
# │ O2(6)      ┆ O2                    ┆ O2        ┆ O2(6)      ┆ O2_frac       ┆ O2(6)        │
# │ N2         ┆ null                  ┆ N2        ┆ N2         ┆ N2_frac       ┆ N2           │
# │ …          ┆ …                     ┆ …         ┆ …          ┆ …             ┆ …            │
# │ C4H8(253)  ┆ 1-butene              ┆ C4H8-1    ┆ C4H8(253)  ┆ null          ┆ C4H8(253)    │
# │ C5H6(478)  ┆ cyclopentadiene       ┆ C5H6      ┆ C5H6(478)  ┆ null          ┆ C5H6(478)    │
# │ C6H6(970)  ┆ benzene               ┆ C6H6      ┆ C6H6(970)  ┆ null          ┆ C6H6(970)    │
# │ HO2(8)     ┆ null                  ┆ HO2       ┆ HO2(8)     ┆ null          ┆ HO2(8)       │
# │ OH(4)      ┆ null                  ┆ OH        ┆ OH(4)      ┆ null          ┆ OH(4)        │
# └────────────┴───────────────────────┴───────────┴────────────┴───────────────┴──────────────┘
