# %%
from pathlib import Path

import util
from util import workflow

browser = True
file = util.notebook_file() if util.is_notebook() else __file__
tag = util.file_tag(file)
root_path = Path("..")
data_path = util.data_path(root_path)

# %%
# Build
from automol.graph import enum

import automech
from automech.species import Species

mech0 = automech.io.read(data_path / "full_raw.json")
mech = automech.from_smiles(
    spc_smis=["C12C(O2)[CH]CC1", "C12C(O2)C[CH]C1"],
    src_mech=mech0,
)
#  - O2 additions
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.o2_addition,
    rcts_=[None, "[O][O]"],
    spc_col_=Species.smiles,
    src_mech=mech0,
)
#  - HO2 elimination
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.ho2_elimination,
    spc_col_=Species.smiles,
    src_mech=mech0,
)
#  - RO2 -> QOOH
mech = automech.enumerate_reactions(
    mech,
    enum.ReactionSmarts.qooh_formation,
    spc_col_=Species.smiles,
    src_mech=mech0,
)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Write
workflow.write(mech=mech, tag=tag, root_path=root_path, browser=browser)
# Out:
# Finalizing build for...
# reactions=shape: (11, 5)
# ┌────────────────────────┬───────────────────────┬───────────┬────────────┬────────────────────────┐
# │ reactants              ┆ products              ┆ formula   ┆ reversible ┆ rate_constant          │
# │ ---                    ┆ ---                   ┆ ---       ┆ ---        ┆ ---                    │
# │ list[str]              ┆ list[str]             ┆ struct[3] ┆ bool       ┆ struct[17]             │
# ╞════════════════════════╪═══════════════════════╪═══════════╪════════════╪════════════════════════╡
# │ ["S(1704)"]            ┆ ["S(1690)"]           ┆ {5,7,3}   ┆ true       ┆ {1,{null,null,null,nul │
# │                        ┆                       ┆           ┆            ┆ l,null,n…              │
# │ ["S(1690)"]            ┆ ["C5O3ddrkjl"]        ┆ {5,7,3}   ┆ null       ┆ null                   │
# │ ["S(1690)"]            ┆ ["S(1703)"]           ┆ {5,7,3}   ┆ true       ┆ {1,{null,null,null,nul │
# │                        ┆                       ┆           ┆            ┆ l,null,n…              │
# │ ["S(1690)"]            ┆ ["S(1702)"]           ┆ {5,7,3}   ┆ true       ┆ {1,{null,null,null,nul │
# │                        ┆                       ┆           ┆            ┆ l,null,n…              │
# │ ["S(1700)"]            ┆ ["S(1691)"]           ┆ {5,7,3}   ┆ true       ┆ {1,{null,null,null,nul │
# │                        ┆                       ┆           ┆            ┆ l,null,n…              │
# │ …                      ┆ …                     ┆ …         ┆ …          ┆ …                      │
# │ ["S(1691)"]            ┆ ["HO2(8)", "S(1288)"] ┆ {5,7,3}   ┆ true       ┆ {1,{null,null,null,nul │
# │                        ┆                       ┆           ┆            ┆ l,null,n…              │
# │ ["O2(6)", "S(1289)"]   ┆ ["S(1691)"]           ┆ {5,7,3}   ┆ true       ┆ {2,{null,null,null,nul │
# │                        ┆                       ┆           ┆            ┆ l,null,n…              │
# │ ["S(1690)"]            ┆ ["HO2(8)", "S(1688)"] ┆ {5,7,3}   ┆ true       ┆ {1,{null,null,null,nul │
# │                        ┆                       ┆           ┆            ┆ l,null,n…              │
# │ ["O2(6)",              ┆ ["S(1690)"]           ┆ {5,7,3}   ┆ true       ┆ {2,{null,null,null,nul │
# │ "C5H7O(758)"]          ┆                       ┆           ┆            ┆ l,null,n…              │
# │ ["S(1690)"]            ┆ ["HO2(8)", "S(1288)"] ┆ {5,7,3}   ┆ true       ┆ {1,{null,null,null,nul │
# │                        ┆                       ┆           ┆            ┆ l,null,n…              │
# └────────────────────────┴───────────────────────┴───────────┴────────────┴────────────────────────┘ species=shape: (14, 7)
# ┌────────────┬─────────────────┬─────────────────┬──────┬────────┬────────────────┬────────────────┐
# │ name       ┆ smiles          ┆ amchi           ┆ spin ┆ charge ┆ formula        ┆ thermo_string  │
# │ ---        ┆ ---             ┆ ---             ┆ ---  ┆ ---    ┆ ---            ┆ ---            │
# │ str        ┆ str             ┆ str             ┆ i64  ┆ i64    ┆ struct[7]      ┆ str            │
# ╞════════════╪═════════════════╪═════════════════╪══════╪════════╪════════════════╪════════════════╡
# │ C5H7O(758) ┆ O1C2C1[CH]CC2   ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null ┆ C   5H   7O    │
# │            ┆                 ┆ 1-2-3-5-4(1)6-5 ┆      ┆        ┆ ,null,5,null}  ┆ 1     G        │
# │            ┆                 ┆ …               ┆      ┆        ┆                ┆ 298.00…        │
# │ O2(6)      ┆ O=O             ┆ AMChI=1/O2/c1-2 ┆ 2    ┆ 0      ┆ {null,2,null,n ┆ O   2          │
# │            ┆                 ┆                 ┆      ┆        ┆ ull,null,null, ┆ G   200.00…    │
# │            ┆                 ┆                 ┆      ┆        ┆ nu…            ┆                │
# │ S(1690)    ┆ [O]OC1C2OC2CC1  ┆ AMChI=1/C5H7O3/ ┆ 1    ┆ 0      ┆ {7,3,null,null ┆ C   5H   7O    │
# │            ┆                 ┆ c6-8-4-2-1-3-5( ┆      ┆        ┆ ,null,5,null}  ┆ 3     G        │
# │            ┆                 ┆ …               ┆      ┆        ┆                ┆ 100.00…        │
# │ S(1289)    ┆ O1C2C1C[CH]C2   ┆ AMChI=1/C5H7O/c ┆ 1    ┆ 0      ┆ {7,1,null,null ┆ C   5H   7O    │
# │            ┆                 ┆ 1-2-4-5(6-4)3-1 ┆      ┆        ┆ ,null,5,null}  ┆ 1     G        │
# │            ┆                 ┆ …               ┆      ┆        ┆                ┆ 100.00…        │
# │ S(1691)    ┆ [O]OC1CC2OC2C1  ┆ AMChI=1/C5H7O3/ ┆ 1    ┆ 0      ┆ {7,3,null,null ┆ C   5H   7O    │
# │            ┆                 ┆ c6-8-3-1-4-5(7- ┆      ┆        ┆ ,null,5,null}  ┆ 3     G        │
# │            ┆                 ┆ …               ┆      ┆        ┆                ┆ 100.00…        │
# │ …          ┆ …               ┆ …               ┆ …    ┆ …      ┆ …              ┆ …              │
# │ S(1701)    ┆ OOC1CC2O[C]2C1  ┆ AMChI=1/C5H7O3/ ┆ 1    ┆ 0      ┆ {7,3,null,null ┆ C   5H   7O    │
# │            ┆                 ┆ c6-8-4-1-3-5(7- ┆      ┆        ┆ ,null,5,null}  ┆ 3     G        │
# │            ┆                 ┆ …               ┆      ┆        ┆                ┆ 100.00…        │
# │ S(1703)    ┆ OOC1C2O[C]2CC1  ┆ AMChI=1/C5H7O3/ ┆ 1    ┆ 0      ┆ {7,3,null,null ┆ C   5H   7O    │
# │            ┆                 ┆ c6-8-4-2-1-3-5( ┆      ┆        ┆ ,null,5,null}  ┆ 3     G        │
# │            ┆                 ┆ …               ┆      ┆        ┆                ┆ 100.00…        │
# │ S(1700)    ┆ OOC1CC2OC2[CH]1 ┆ AMChI=1/C5H7O3/ ┆ 1    ┆ 0      ┆ {7,3,null,null ┆ C   5H   7O    │
# │            ┆                 ┆ c6-8-3-1-4-5(7- ┆      ┆        ┆ ,null,5,null}  ┆ 3     G        │
# │            ┆                 ┆ …               ┆      ┆        ┆                ┆ 100.00…        │
# │ C5O3ddrkjl ┆ OOC1[CH]CC2C1O2 ┆ AMChI=1/C5H7O3/ ┆ 1    ┆ 0      ┆ {7,3,null,null ┆ null           │
# │            ┆                 ┆ c6-8-3-1-2-4-5( ┆      ┆        ┆ ,null,5,null}  ┆                │
# │            ┆                 ┆ …               ┆      ┆        ┆                ┆                │
# │ S(1702)    ┆ OOC1CCC2O[C]12  ┆ AMChI=1/C5H7O3/ ┆ 1    ┆ 0      ┆ {7,3,null,null ┆ C   5H   7O    │
# │            ┆                 ┆ c6-8-5-2-1-4-3( ┆      ┆        ┆ ,null,5,null}  ┆ 3     G        │
# │            ┆                 ┆ …               ┆      ┆        ┆                ┆ 100.00…        │
# └────────────┴─────────────────┴─────────────────┴──────┴────────┴────────────────┴────────────────┘ thermo_temps=None
#
# Expanding stereochemistry...
#   0%|          | 0/14 [00:00<?, ?it/s]
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
# Writing mechanism...
# ../data/D_r-o2_p2v1_raw.json
# ../data/D_r-o2_p2v1.json
# ../data/mechanalyzer/D_r-o2_p2v1.dat
# ../data/mechanalyzer/D_r-o2_p2v1.csv
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/39 [00:00<?, ?it/s]
# Stereoexpansion errors:
#
# *********
# Reaction: S(1690) = S(1703)
# Translations:
#   smiles:
#     reactants = ['[O]OC1C2OC2CC1']
#     products = ['OOC1C2O[C]2CC1']
# Rate parameters:
#   This work:
#     S(1690) = S(1703)                                        1.170E+11     0.4300      15400
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
# alt.Chart(...)

# %%
# # Read
# workflow.read(tag=tag, root_path=root_path)

# %%
# # Simulate
# workflow.simulate(full_tag=f"full_{tag}_calc", root_path=root_path)
# workflow.simulate(full_tag=f"full_{tag}_control", root_path=root_path)

# %%
# # Plot
# charts = workflow.plot(
#     full_tag=f"full_{tag}_calc",
#     x_col="O2_molecules",
#     y_col_=["C5H8(522)", "C5H8O(825)rs"],
#     root_path=root_path,
#     line_source_=["hill", "lokachari"],
#     point_source="experiment",
# )
# for chart in charts:
#     chart.show()
