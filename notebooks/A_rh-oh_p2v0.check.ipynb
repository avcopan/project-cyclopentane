# %%
from pathlib import Path

import util

from automech.subtasks import display, fs

tag = util.notebook_prefix()
root_path = Path("..")
calc_path = root_path / tag

# %%
for path in fs.task_paths("find_ts", "1: 1", path=calc_path):
    print(path)
# Out:
# /lcrc/project/PACC/copan/amech-dev/work/project-cyclopentane/save/RXN/C5H9O/ZOCQCVFDVWWLHS/0/2/YFKPBYRVSA-N/C5H8.HO/UGZOASBOAAXKSP/0_0/1_2/UHFFFAOYSA-N/2/u-unGOU/TS/00

# %%
display("find_ts", "1: 2", path=calc_path)
# Out:
# Lowest frequency mode:
#   frequency: -80.64442207043903
# <div id="3dmolviewer_1737145754578879"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1737145754578879" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
# ...
