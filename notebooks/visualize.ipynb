# %%
from pathlib import Path

import automech

# %%
dir_path = Path("..") / "01_submech_ene" / "generate"
print(dir_path.resolve())
print(list(dir_path.iterdir()))

num = "01"
mech_path = dir_path / f"mechanism{num}.dat"
spc_path = dir_path / f"species{num}.csv"
# Out:
# /home/avcopan/code/amech-proto/work/project-cyclopentane/01_submech_ene/generate
# [PosixPath('../01_submech_ene/generate/species00.csv'), PosixPath('../01_submech_ene/generate/mechanism01.dat'), PosixPath('../01_submech_ene/generate/sort.dat'), PosixPath('../01_submech_ene/generate/mechanism00.dat'), PosixPath('../01_submech_ene/generate/species01.csv'), PosixPath('../01_submech_ene/generate/run.sh'), PosixPath('../01_submech_ene/generate/build.dat'), PosixPath('../01_submech_ene/generate/build01.dat')]

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (18, 2)
#     ┌────────────────────────────────┬─────────────────────────────────┐
#     │ eq                             ┆ rate                            │
#     │ ---                            ┆ ---                             │
#     │ str                            ┆ object                          │
#     ╞════════════════════════════════╪═════════════════════════════════╡
#     │ cyC5e1 + H = cyC5e1r1 + H2     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1 + H = cyC5e1r3 + H2     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1 + H = cyC5e1r4 + H2     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1 + O = cyC5e1r1 + OH     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1 + O = cyC5e1r3 + OH     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                              ┆ …                               │
#     │ cyC5e1 + HO2 = cyC5e1r3 + H2O2 ┆ SimpleRate(k=ArrheniusFunction… │
# ...

# %%
automech.display(mech)
# Out:
# ...
#   0%|          | 0/18 [00:00<?, ?it/s]
