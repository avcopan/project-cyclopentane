# %%
from pathlib import Path

import automech

# %%
mech_num = "01"
# dir_leaf = "1generate"
dir_leaf = "2stereoexpand"

dir_path = Path("..") / "1submech_ene" / dir_leaf
assert dir_path.exists()

mech_path = dir_path / f"mechanism{mech_num}.dat_full"
spc_path = dir_path / f"species{mech_num}.csv_full"
# Out:
# [PosixPath('../1submech_ene/2stereoexpand/species01.csv_orig'), PosixPath('../1submech_ene/2stereoexpand/mechanism01.dat_orig'), PosixPath('../1submech_ene/2stereoexpand/mechanism01.dat_full'), PosixPath('../1submech_ene/2stereoexpand/sort.dat'), PosixPath('../1submech_ene/2stereoexpand/run.sh'), PosixPath('../1submech_ene/2stereoexpand/build.dat'), PosixPath('../1submech_ene/2stereoexpand/species01.csv_full')]

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (18, 2)
#     ┌────────────────────────────────┬─────────────────────────────────┐
#     │ eq                             ┆ rate                            │
#     │ ---                            ┆ ---                             │
#     │ str                            ┆ object                          │
#     ╞════════════════════════════════╪═════════════════════════════════╡
#     │ cyC5e1 + H = cyC5e1r1 + H2     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1 + H = cyC5e1r3 + H2     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1 + H = cyC5e1r4 + H2     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1 + O = cyC5e1r1 + OH     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5e1 + O = cyC5e1r3 + OH     ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                              ┆ …                               │
#     │ cyC5e1 + HO2 = cyC5e1r3 + H2O2 ┆ SimpleRate(k=ArrheniusFunction… │
# ...

# %%
automech.display(mech)
# Out:
# ...
#   0%|          | 0/18 [00:00<?, ?it/s]
