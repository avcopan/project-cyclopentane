# %%
from pathlib import Path

import automech

# %%
DATA_PATH = Path("../data")

# %%
mech = automech.io.read(DATA_PATH / "full_raw.json")

# %%
automech.display_reactions(mech, ["S(1431) <=> C5H9O(852)"])
