# %%
from pathlib import Path

import automech

# %%
DATA_PATH = Path("../data")

# %%
mech = automech.io.read(DATA_PATH / "full_raw.json")

# %%
automech.display_reactions(mech, ["S(1687) = S(1314)", "C5H7O(690) = S(1314)"])
# Out:
# *********
# Reaction: C5H7O(690) = S(1314)
# Translations:
#   smiles:
#     reactants = ['[O]C=1CCCC=1']
#     products = ['O1C2CCC[C]12']
# Rate parameters:
#   This work:
#     C5H7O(690) = S(1314)                                     5.382E+13    -0.3370      40857
# ...
# alt.Chart(...)
# *********
# Reaction: S(1687) = S(1314)
# Translations:
#   smiles:
#     reactants = ['[CH2]CC1OC1=C']
#     products = ['O1C2CCC[C]12']
# Rate parameters:
#   This work:
#     S(1687) = S(1314)                                        9.900E+10    0.06000      17730
# ...
# alt.Chart(...)
