# %%
from pathlib import Path

import automech

# %%
mech_num = "04"
# submech_leaf = "1submech_ene"
submech_leaf = "2submech_12epoxy"
# submech_leaf = "3submech_13epoxy"
task_leaf = "1generate"
mech_tag = ""
# task_leaf = "2stereoexpand"
# mech_tag = "_full"

dir_path = Path("..") / submech_leaf / task_leaf
assert dir_path.exists()

mech_path = dir_path / f"mechanism{mech_num}.dat{mech_tag}"
spc_path = dir_path / f"species{mech_num}.csv{mech_tag}"

# %%
mech = automech.io.mechanalyzer.read.mechanism(
    inp=mech_path,
    spc_inp=spc_path,
)
mech
# Out:
#   0%|          | 0/77 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (86, 2)
#     ┌─────────────────────────────────┬─────────────────────────────────┐
#     │ eq                              ┆ rate                            │
#     │ ---                             ┆ ---                             │
#     │ str                             ┆ object                          │
#     ╞═════════════════════════════════╪═════════════════════════════════╡
#     │ cyC5x12 + OH = cyC5x12r1 + H2O  ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12 + CH3 = cyC5x12r4 + CH… ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12 + O = cyC5x12r3 + OH    ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12r3 = C5H7O-prCPs7        ┆ SimpleRate(k=ArrheniusFunction… │
#     │ cyC5x12r1 = cyC5x12r4           ┆ SimpleRate(k=ArrheniusFunction… │
#     │ …                               ┆ …                               │
#     │ C5H7O3-ToPn7G = C5H7O3-ToPNLM   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-ToPn7G = C5H7O3-ToPLiq   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-ToPn7G = C5H7O3-ToPtUp   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-ToPn7G = C5H7O3-ToPXaz   ┆ SimpleRate(k=ArrheniusFunction… │
#     │ C5H7O3-ToPn7G = C5H7O3-ToPoOQ   ┆ SimpleRate(k=ArrheniusFunction… │
#     └─────────────────────────────────┴─────────────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (77, 8)
#     ┌───────────────┬──────────────┬──────────────┬──────┬────────┬──────────────┬──────────────┬──────┐
#     │ name          ┆ smiles       ┆ amchi        ┆ spin ┆ charge ┆ inchi        ┆ inchikey     ┆ mult │
#     │ ---           ┆ ---          ┆ ---          ┆ ---  ┆ ---    ┆ ---          ┆ ---          ┆ ---  │
#     │ str           ┆ str          ┆ str          ┆ i64  ┆ i64    ┆ str          ┆ str          ┆ i64  │
#     ╞═══════════════╪══════════════╪══════════════╪══════╪════════╪══════════════╪══════════════╪══════╡
#     │ H             ┆ [H]          ┆ AMChI=1/H    ┆ 1    ┆ 0      ┆ InChI=1S/H   ┆ YZCKVEUIGOOR ┆ 2    │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ GS-UHFFFAOYS ┆      │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ H2            ┆ [H][H]       ┆ AMChI=1/H2/h ┆ 0    ┆ 0      ┆ InChI=1S/H2/ ┆ UFHFLCQGNIYN ┆ 1    │
#     │               ┆              ┆ 1H           ┆      ┆        ┆ h1H          ┆ RP-UHFFFAOYS ┆      │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ O             ┆ [O]          ┆ AMChI=1/O    ┆ 2    ┆ 0      ┆ InChI=1S/O   ┆ QVGXLLKOCUKJ ┆ 3    │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ ST-UHFFFAOYS ┆      │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ OH            ┆ [OH]         ┆ AMChI=1/HO/h ┆ 1    ┆ 0      ┆ InChI=1S/HO/ ┆ TUJKJAMUKRIR ┆ 2    │
#     │               ┆              ┆ 1H           ┆      ┆        ┆ h1H          ┆ HC-UHFFFAOYS ┆      │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ H2O           ┆ O            ┆ AMChI=1/H2O/ ┆ 0    ┆ 0      ┆ InChI=1S/H2O ┆ XLYOFNOQVPJJ ┆ 1    │
#     │               ┆              ┆ h1H2         ┆      ┆        ┆ /h1H2        ┆ NP-UHFFFAOYS ┆      │
#     │               ┆              ┆              ┆      ┆        ┆              ┆ A-N          ┆      │
#     │ …             ┆ …            ┆ …            ┆ …    ┆ …      ┆ …            ┆ …            ┆ …    │
#     │ C5H7O3-ToPNLM ┆ [CH]=CCC1C(O ┆ AMChI=1/C5H7 ┆ 1    ┆ 0      ┆ InChI=1S/C5H ┆ YZVCEUBGMFQB ┆ 2    │
#     │               ┆ 1)OO         ┆ O3/c1-2-3-4- ┆      ┆        ┆ 7O3/c1-2-3-4 ┆ EK-UHFFFAOYS ┆      │
#     │               ┆              ┆ 5(7-4)…      ┆      ┆        ┆ -5(7-4…      ┆ A-N          ┆      │
#     │ C5H7O3-ToPLiq ┆ C=[C]CC1C(O1 ┆ AMChI=1/C5H7 ┆ 1    ┆ 0      ┆ InChI=1S/C5H ┆ UCCAMKOJYYNG ┆ 2    │
#     │               ┆ )OO          ┆ O3/c1-2-3-4- ┆      ┆        ┆ 7O3/c1-2-3-4 ┆ RE-UHFFFAOYS ┆      │
#     │               ┆              ┆ 5(7-4)…      ┆      ┆        ┆ -5(7-4…      ┆ A-N          ┆      │
#     │ C5H7O3-ToPtUp ┆ C=C[CH]C1C(O ┆ AMChI=1/C5H7 ┆ 1    ┆ 0      ┆ InChI=1S/C5H ┆ IUEOZPKXCWSX ┆ 2    │
#     │               ┆ 1)OO         ┆ O3/c1-2-3-4- ┆      ┆        ┆ 7O3/c1-2-3-4 ┆ NP-UHFFFAOYS ┆      │
#     │               ┆              ┆ 5(7-4)…      ┆      ┆        ┆ -5(7-4…      ┆ A-N          ┆      │
#     │ C5H7O3-ToPXaz ┆ C=CC[C]1C(O1 ┆ AMChI=1/C5H7 ┆ 1    ┆ 0      ┆ InChI=1S/C5H ┆ BNZLNIDBASCH ┆ 2    │
#     │               ┆ )OO          ┆ O3/c1-2-3-4- ┆      ┆        ┆ 7O3/c1-2-3-4 ┆ AX-UHFFFAOYS ┆      │
#     │               ┆              ┆ 5(7-4)…      ┆      ┆        ┆ -5(7-4…      ┆ A-N          ┆      │
#     │ C5H7O3-ToPoOQ ┆ C=CCC1[C](O1 ┆ AMChI=1/C5H7 ┆ 1    ┆ 0      ┆ InChI=1S/C5H ┆ JSXKLNNKWMMG ┆ 2    │
#     │               ┆ )OO          ┆ O3/c1-2-3-5- ┆      ┆        ┆ 7O3/c1-2-3-4 ┆ JK-UHFFFAOYS ┆      │
#     │               ┆              ┆ 4(7-5)…      ┆      ┆        ┆ -5(7-4…      ┆ A-N          ┆      │
#     └───────────────┴──────────────┴──────────────┴──────┴────────┴──────────────┴──────────────┴──────┘
#   ),
# )

# %%
automech.display_reactions(mech, eqs=["C5H7O3-i1GPs7 = C5H7O3-i1GtUp"])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# eq: C5H7O3-i1GPs7 = C5H7O3-i1GtUp
# Species `name`=>`smiles` translation
#   reactants = ('[O]OC1CCC2C1O2',)
#   products = ('OOC1[CH]CC2C1O2',)
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…

# %%
import automech

# Example 1
mech = automech.from_smiles(
    ["CCC", "[OH]", "CC[CH2]", "O"],
    rxn_smis=["CCC.[OH]>>CC[CH2].O"],
    name_dct={"CCC": "C3H8", "[OH]": "OH", "CC[CH2]": "C3H7y1"},
)
print(mech)
automech.display_reactions(mech, eqs=["C3H8+OH=C3H7y1+H2O"])
# automech.display_reactions(mech)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# Mechanism(
#   reactions=DataFrame(
#     shape: (1, 1)
#     ┌──────────────────────────┐
#     │ eq                       │
#     │ ---                      │
#     │ str                      │
#     ╞══════════════════════════╡
#     │ C3H8 + OH = C3H7y1 + H2O │
#     └──────────────────────────┘
#   ),
#   species=DataFrame(
#     shape: (4, 5)
#     ┌────────┬─────────┬────────────────────────────────┬──────┬────────┐
#     │ name   ┆ smiles  ┆ amchi                          ┆ spin ┆ charge │
#     │ ---    ┆ ---     ┆ ---                            ┆ ---  ┆ ---    │
#     │ str    ┆ str     ┆ str                            ┆ i64  ┆ i64    │
#     ╞════════╪═════════╪════════════════════════════════╪══════╪════════╡
#     │ C3H8   ┆ CCC     ┆ AMChI=1/C3H8/c1-3-2/h3H2,1-2H3 ┆ 0    ┆ 0      │
#     │ OH     ┆ [OH]    ┆ AMChI=1/HO/h1H                 ┆ 1    ┆ 0      │
#     │ C3H7y1 ┆ CC[CH2] ┆ AMChI=1/C3H7/c1-3-2/h1,3H2,2H3 ┆ 1    ┆ 0      │
#     │ H2O    ┆ O       ┆ AMChI=1/H2O/h1H2               ┆ 0    ┆ 0      │
#     └────────┴─────────┴────────────────────────────────┴──────┴────────┘
#   ),
# )
#   0%|          | 0/1 [00:00<?, ?it/s]
# eq: C3H8 + OH = C3H7y1 + H2O
# Species `name`=>`smiles` translation
#   reactants = ('CCC', '[OH]')
#   products = ('CC[CH2]', 'O')
# HBox(children=(Image(value=b"<?xml version='1.0' encoding='iso-8859-1...", format='svg+xml', height='300', wid…
