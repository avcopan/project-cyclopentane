# %%
import mecha

# %%
inp = 'cyclopentene_species.csv'
# inp = '12epoxycyclopentane_species.csv'
# inp = '13epoxyCPT_species.csv'

out = inp.replace('.csv', '_stereo.csv')
spc_df = mecha.expand_species_stereo(inp, out=out, enant=True)
spc_df
# Out:
#   0%|          | 0/687 [00:00<?, ?it/s]
#            name  mult  charge  \
# 0            N2     1       0
# 1            Ar     1       0
# 2            He     1       0
# 3            Ne     1       0
# 4       C5H7(1)     2       0
# ..          ...   ...     ...
# 684  S(2046)rr1     2       0
# 685    S(1488)z     1       0
# 685    S(1488)e     1       0
# 686    S(603)r0     2       0
# 686    S(603)r1     2       0
#
#                                                    chi orig_name  \
# 0                                      AMChI=1/N2/c1-2        N2
# 1                                           AMChI=1/Ar        Ar
# 2                                           AMChI=1/He        He
# 3                                           AMChI=1/Ne        Ne
# 4                  AMChI=1/C5H7/c1-2-4-5-3-1/h2H,3-5H2   C5H7(1)
# ..                                                 ...       ...
# 684  AMChI=1/C5H7O/c1-4-2-5(4)3-6/h2-5H,1H3/t4-,5-/...   S(2046)
# ...
