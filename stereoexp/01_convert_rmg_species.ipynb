# %%
import mecha

# %%
inp = 'cyclopentene_species_dictionary.txt'
inp = '12epoxycyclopentane_species_dictionary.txt'
inp = '13epoxyCPT_species_dictionary.txt'

out = inp.replace('species_dictionary.txt', 'species.csv')
df = mecha.io.rmg.read.species(inp=inp, out=out)
df
# Out:
#   0%|          | 0/345 [00:00<?, ?it/s]
#            name  mult  charge  \
# 0            N2     1       0
# 1            Ar     1       0
# 2            He     1       0
# 3            Ne     1       0
# 4      C5H7O(1)     2       0
# ..          ...   ...     ...
# 340      S(613)     2       0
# 341  C5H7O(377)     2       0
# 342  C5H7O(212)     2       0
# 343  C5H7O(447)     2       0
# 344      S(469)     2       0
#
#                                                   chi              smi
# 0                                    InChI=1S/N2/c1-2              N#N
# 1                                         InChI=1S/Ar             [Ar]
# 2                                         InChI=1S/He             [He]
# 3                                         InChI=1S/Ne             [Ne]
# 4         InChI=1S/C5H7O/c1-2-5-3-4(1)6-5/h3-5H,1-2H2    O1C2[CH]C1CC2
# ..                                                ...              ...
# ...
