# %%
import mecha

# %%
id = '08'

rxn_df, spc_df = mecha.from_mechanalyzer(
    inp=f'mechanism{id}.dat',
    spc_inp=f'species{id}.csv',
)

mecha.display(rxn_df, spc_df, out=f'network{id}.html')
# Out:
# ...
#   0%|          | 0/114 [00:00<?, ?it/s]
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# ...
#   0%|          | 0/151 [00:00<?, ?it/s]
#         <iframe
#             width="100%"
#             height="600px"
#             src="network08.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
