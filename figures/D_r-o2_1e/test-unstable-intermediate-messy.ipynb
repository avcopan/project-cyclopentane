# %%
import autochem as ac

# %%
# S(1210)r0 = C5O2nexammzze = C5H6O(645)z + OH(4)
open_mess_out_well = """
W2->W11

P\T           500       600       700       800       900     1e+03   1.1e+03   1.2e+03   1.3e+03   1.4e+03   1.5e+03   1.6e+03   1.7e+03   1.8e+03   1.9e+03     2e+03
0.1       1.5e-10     1e-08 -1.87e-08  9.54e-08  4.31e-08  6.41e-07  5.11e-05   0.00406     0.222      5.32       ***       ***  2.16e+03       ***       ***       ***
1       -6.27e-11  1.44e-08 -8.25e-07  6.24e-06  4.58e-05  0.000261   0.00576     0.241       5.2      69.8       584  3.09e+03  1.32e+04  4.77e+04  1.48e+05  3.59e+05
10       1.33e-10  1.06e-07  1.12e-05  0.000351   0.00414    0.0293     0.403      8.51      96.1       786   4.6e+03  1.97e+04  7.31e+04   2.3e+05  6.47e+05  1.47e+06
100      1.79e-10   4.5e-07  -0.00194    0.0053    0.0927      1.08        14       168  1.27e+03  7.57e+03  3.33e+04  1.14e+05  3.52e+05   9.7e+05  2.46e+06  5.25e+06
O-O      5.24e-06   0.00632      1.04      48.4       977  1.09e+04  7.89e+04  4.13e+05  1.68e+06   5.6e+06  1.59e+07  3.99e+07  8.97e+07  1.84e+08  3.51e+08  6.29e+08
"""
open_mess_out_fake = """
W2->W13

P\T           500       600       700       800       900     1e+03   1.1e+03   1.2e+03   1.3e+03   1.4e+03   1.5e+03   1.6e+03   1.7e+03   1.8e+03   1.9e+03     2e+03
0.1     -9.03e-05  2.23e-07  -0.00852  -0.00477     0.017  -0.00177  -0.00317  -0.00572   0.00955    0.0488     0.213      3.56       166       399  1.96e+03  9.03e+03
1        5.11e-05  -0.00227   -0.0025   0.00462  -0.00505  0.000896    0.0246   0.00695     0.169      1.56      16.1      -178       780  4.44e+03  1.78e+04  6.07e+04
10       6.43e-07 -0.000354  -0.00165    0.0224     0.264     0.328      2.03      11.8      57.8       277  1.22e+03  4.68e+03  1.84e+04  5.89e+04  1.65e+05  4.27e+05
100      0.000512   -0.0424    -0.152     0.407     -14.5     -24.5     -81.6      -306 -1.17e+03  9.56e+04   2.1e+05  4.25e+05  8.45e+05  1.55e+06  2.76e+06  4.75e+06
O-O           ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***
"""
open_mess_out_skip = """
W2->P1

P\T           500       600       700       800       900     1e+03   1.1e+03   1.2e+03   1.3e+03   1.4e+03   1.5e+03   1.6e+03   1.7e+03   1.8e+03   1.9e+03     2e+03
0.1       -0.0859    0.0724      1.39     -1.19   -0.0621    -0.164    0.0154      1.53      8.56      45.9       334  1.67e+03  4.98e+03  2.34e+04  6.81e+04  1.57e+05
1           0.352     -4.76     -14.7      1.54      3.23      5.34        25      77.3       255       809  2.87e+03  9.65e+03  3.22e+04  8.29e+04     2e+05  3.99e+05
10         0.0446      1.17    -0.219      8.07      79.5       394  1.32e+03  3.52e+03  8.43e+03  1.83e+04  4.02e+04  8.63e+04  1.92e+05   3.9e+05  7.91e+05  1.41e+06
100       -0.0168  -0.00308      8.23      41.7       460  3.58e+03  1.67e+04  5.33e+04  1.32e+05  2.68e+05  4.89e+05  8.23e+05  1.33e+06  2.01e+06  3.05e+06  4.34e+06
O-O           ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***
"""
# open_rxn_well = ac.rate.from_mess_channel_output(open_mess_out_well)
open_rxn_fake = ac.rate.from_mess_channel_output(open_mess_out_fake)
open_rxn_skip = ac.rate.from_mess_channel_output(open_mess_out_skip)
# open_rxn_data = open_rxn_well + open_rxn_fake + open_rxn_skip
open_rxn_data = open_rxn_fake + open_rxn_skip
open_rxn_fit = ac.rate.fit_plog(open_rxn_data, sanitize=False)
# ac.rate.display([open_rxn_fake, open_rxn_skip, open_rxn_data, open_rxn_fit])
ac.rate.display([open_rxn_data, open_rxn_fit], label=["MESS output", "fit"])
# Out:
# alt.LayerChart(...)

# %%
# S(1210)r0 = C5O2nexammzze = C5H6O(645)z + OH(4)
open_mess_out_fake2 = """
W2->W12

P\T           500       600       700       800       900     1e+03   1.1e+03   1.2e+03   1.3e+03   1.4e+03   1.5e+03   1.6e+03   1.7e+03   1.8e+03   1.9e+03     2e+03
0.1     -2.03e-05  0.000285 -0.000289  -0.00278  -0.00136    -0.874       3.1     -4.09      1.78     -4.47     0.748     -2.77      2.83      6.91      29.5       118
1        6.29e-05 -9.25e-05   0.00059  -0.00714  0.000922     -41.2     -6.97        26     -1.62       -20     -4.93     -24.4      82.4       209       639   1.7e+03
10       9.57e-06 -4.43e-05  6.36e-05   0.00416    0.0366       392       755      -239       156      91.5       340       665  2.49e+03   6.1e+03  1.33e+04  2.63e+04
100      -0.00243    -0.093  0.000494   0.00737     0.117  -2.2e+03 -1.14e+04  1.33e+04   2.6e+04  5.66e+04  9.87e+04  1.63e+05  2.53e+05  3.62e+05  5.01e+05  6.96e+05
O-O      5.24e-06   0.00632      1.04      48.4       977  1.09e+04  7.89e+04  4.13e+05  1.68e+06   5.6e+06  1.59e+07  3.99e+07  8.97e+07  1.84e+08  3.51e+08  6.29e+08
"""
open_mess_out_skip2 = """
W2->P1

P\T           500       600       700       800       900     1e+03   1.1e+03   1.2e+03   1.3e+03   1.4e+03   1.5e+03   1.6e+03   1.7e+03   1.8e+03   1.9e+03     2e+03
0.1       -0.0343    -0.308    -0.103    -0.934    -0.487     0.426     -0.31     0.376     0.888      1.04      2.49      6.07      12.5      23.1      39.6      64.5
1           0.534       2.4      1.39      2.34      2.23      5.09      12.6      23.1      42.5      76.1       125       225       356       513       685       859
10      -0.000218     -0.62     -1.05      8.53      73.4       339       977  2.03e+03  3.47e+03  5.42e+03  7.44e+03  1.04e+04   1.3e+04  1.49e+04  1.64e+04  1.71e+04
100         -1.52    -0.355     0.644      34.5       457  3.47e+03  1.53e+04  4.41e+04  9.31e+04  1.58e+05  2.23e+05  2.96e+05  3.52e+05  3.82e+05  4.02e+05  4.02e+05
O-O           ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***
"""
open_rxn_fake2 = ac.rate.from_mess_channel_output(open_mess_out_fake2)
open_rxn_skip2 = ac.rate.from_mess_channel_output(open_mess_out_skip2)
open_rxn_data2 = open_rxn_fake2 + open_rxn_skip2
open_rxn_fit2 = ac.rate.fit_plog(open_rxn_data2, sanitize=False)
ac.rate.display(
    [open_rxn_data, open_rxn_fit, open_rxn_data2, open_rxn_fit2],
    label=["MESS output", "fit", "MESS output 2", "fit 2"],
)
# Out:
# alt.LayerChart(...)

# %%
# S(1210)r0 = C5O2nexammzze = C5H6O(645)z + OH(4)
open_mess_out_well4 = """
W2->W11

P\T           500       600       700       800       900     1e+03   1.1e+03   1.2e+03   1.3e+03   1.4e+03   1.5e+03   1.6e+03   1.7e+03   1.8e+03   1.9e+03     2e+03
0.1      4.43e-09  1.08e-07 -1.32e-07 -1.74e-07 -2.58e-07   1.1e-07 -2.46e-06 -2.48e-06  4.18e-06  9.24e-06  0.000122   0.00198     0.023     0.136     0.653      3.71
1        1.18e-07  1.58e-07 -5.54e-06  9.41e-06  9.62e-06  2.15e-05  3.29e-05  0.000126  0.000284   0.00188    0.0139     0.128     0.927         4      14.6      59.1
10      -4.87e-07 -1.44e-06 -7.79e-06  0.000231  0.000969   0.00478    0.0125     0.029    0.0653     0.219     0.889      4.52        21        68       202       680
100     -1.44e-06 -5.11e-05   4.2e-05   0.00121    0.0199     0.161     0.732      2.56      6.98      19.2      48.5       140       415       985  2.27e+03  6.12e+03
O-O      5.24e-06   0.00632      1.04      48.4       977  1.09e+04  7.89e+04  4.13e+05  1.68e+06   5.6e+06  1.59e+07  3.99e+07  8.97e+07  1.84e+08  3.51e+08  6.29e+08
"""
open_mess_out_skip4 = """
W2->P1

P\T           500       600       700       800       900     1e+03   1.1e+03   1.2e+03   1.3e+03   1.4e+03   1.5e+03   1.6e+03   1.7e+03   1.8e+03   1.9e+03     2e+03
0.1      9.63e-09  3.42e-06  0.000124   0.00133   0.00714    0.0259    0.0757     0.193     0.466      1.17      2.53      6.13      13.5      30.3      70.4       177
1        7.93e-07  0.000363    0.0196     0.268      1.51      4.99        12      23.8      42.5      76.1       125       233       407       722  1.31e+03  2.49e+03
10       3.69e-06   0.00322     0.327       8.1      74.6       342       974  2.03e+03  3.49e+03  5.51e+03  7.72e+03  1.12e+04  1.55e+04  2.11e+04  2.93e+04  4.28e+04
100         5e-06   0.00574     0.854      33.8       526  4.09e+03  1.85e+04  5.49e+04   1.2e+05  2.15e+05  3.23e+05  4.59e+05  6.04e+05  7.44e+05  9.01e+05  1.09e+06
O-O           ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***
"""
open_rxn_well4 = ac.rate.from_mess_channel_output(open_mess_out_well4)
open_rxn_skip4 = ac.rate.from_mess_channel_output(open_mess_out_skip4)
open_rxn_data4 = open_rxn_well4 + open_rxn_skip4
open_rxn_fit4 = ac.rate.fit_plog(open_rxn_data4, sanitize=False)
ac.rate.display(
    [open_rxn_data, open_rxn_fit, open_rxn_data4, open_rxn_fit4],
    label=["MESS output", "fit", "MESS output 4", "fit 4"],
)
# Out:
# alt.LayerChart(...)

# %%
# S(1210)r0 = C5H6O(645)z + OH(4)
open_mess_out_direct = """
W2->P1

P\T           500       600       700       800       900     1e+03   1.1e+03   1.2e+03   1.3e+03   1.4e+03   1.5e+03   1.6e+03   1.7e+03   1.8e+03   1.9e+03     2e+03
0.1      1.24e-08  3.41e-06  0.000124   0.00133   0.00714    0.0259    0.0757     0.193     0.466      1.17      2.53      6.13      13.5      30.4      71.1       181
1        7.88e-07  0.000363    0.0196     0.268      1.51      4.99        12      23.8      42.5      76.1       125       233       408       726  1.33e+03  2.55e+03
10       3.69e-06   0.00322     0.327       8.1      74.6       342       975  2.03e+03  3.49e+03  5.51e+03  7.72e+03  1.12e+04  1.55e+04  2.11e+04  2.95e+04  4.35e+04
100      5.01e-06   0.00574     0.854      33.8       527  4.09e+03  1.85e+04   5.5e+04   1.2e+05  2.15e+05  3.23e+05   4.6e+05  6.05e+05  7.45e+05  9.03e+05   1.1e+06
O-O      5.24e-06   0.00632      1.04      48.4       977  1.09e+04  7.89e+04  4.13e+05  1.68e+06   5.6e+06  1.59e+07  3.99e+07  8.97e+07  1.84e+08  3.51e+08  6.29e+08
"""
open_rxn_data3 = ac.rate.from_mess_channel_output(open_mess_out_direct)
open_rxn_fit3 = ac.rate.fit_plog(open_rxn_data3, sanitize=False)
chart = ac.rate.display(
    [
        open_rxn_data2,
        open_rxn_fit2,
        open_rxn_data3,
        open_rxn_fit3,
    ],
    label=[
        "data (fake well)",
        "fit (fake well)",
        "data (no fake well)",
        "fit (no fake well)",
    ],
)
chart.save("fake-well-woes.png", ppi=300)
# Out:
# /home/avcopan/code/amech-dev/src/autochem/autochem/rate/data.py:583: UserWarning: Currently not fitting high-pressure limit order=1 efficiencies={} A=116219869318.61479 b=0.6960242232526881 E=41712.38520594692 type='arrhenius'
#   warnings.warn(f"Currently not fitting high-pressure limit {k_high_fit}")
