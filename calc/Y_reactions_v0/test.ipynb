# %%
import automol
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import automol
#
# File ~/proj/project-cyclopentane/code/autochem/src/automol/__init__.py:68
#       1 """ molecular descriptor libraries
#       2
#       3 automol module hierarchy
#    (...)     60  - symm         [L5 dependencies: reac, rotor]
#      61 """
#      63 # L1
#      64 # L2
#      65 # L3
#      66 # L4
#      67 # L5
# ---> 68 from . import (
#      69     _deprecated,
#      70     amchi,
#      71     combine,
#      72     const,
#      73     data,
#      74     embed,
#      75     error,
#      76     etrans,
#      77     extern,
#      78     form,
#      79     geom,
#      80     graph,
#      81     inchi,
#      82     inchi_key,
#      83     mult,
#      84     prop,
#      85     reac,
#      86     smarts,
#      87     smiles,
#      88     symm,
#      89     util,
# ...
