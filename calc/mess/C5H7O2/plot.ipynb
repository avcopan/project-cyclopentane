# %%
import autochem as ac

# %%
mess_outs = [
    """
W2->P3

P\T           500       600       700       800       900     1e+03   1.1e+03   1.2e+03   1.3e+03   1.4e+03   1.5e+03   1.6e+03   1.7e+03   1.8e+03   1.9e+03     2e+03
0.1        0.0493     0.585      2.38      6.99      20.1        42      21.2      -281 -1.27e+03 -3.89e+03 -9.04e+03  -1.7e+04 -2.06e+04 -3.26e+04  -3.1e+04  -3.4e+04
1           0.953      15.6      68.6       139       197       259       310       255     -56.6 -1.09e+03 -3.46e+03 -7.28e+03 -9.34e+03 -2.39e+04 -2.82e+04 -4.73e+04
10           6.17       174  1.14e+03  2.81e+03  3.67e+03  3.52e+03  2.95e+03  2.53e+03  2.45e+03  2.41e+03  2.19e+03  1.23e+03       410 -2.67e+03 -4.61e+03 -1.16e+04
100          13.5       644  7.44e+03  3.08e+04  6.11e+04  7.54e+04  6.66e+04     5e+04  3.72e+04  2.87e+04  2.39e+04  1.89e+04  1.49e+04  1.75e+04  1.46e+04  1.64e+04
O-O           ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***       ***
    """
]
rxns = [ac.rate.from_mess_channel_output(mess_out) for mess_out in mess_outs]
rxn = sum(rxns[1:], start=rxns[0])
fit = ac.rate.fit_plog(rxn, sanitize=False)
ac.rate.display([*rxns, fit])
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\T'
# <>:5: SyntaxWarning: invalid escape sequence '\T'
# /tmp/ipykernel_65956/1972241526.py:5: SyntaxWarning: invalid escape sequence '\T'
#   P\T           500       600       700       800       900     1e+03   1.1e+03   1.2e+03   1.3e+03   1.4e+03   1.5e+03   1.6e+03   1.7e+03   1.8e+03   1.9e+03     2e+03
# alt.LayerChart(...)
