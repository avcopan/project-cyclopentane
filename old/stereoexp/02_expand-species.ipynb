# %%
import mecha

# %%
inp = 'cyclopentene_species.csv'
inp = '12epoxycyclopentane_species.csv'
inp = '13epoxyCPT_species.csv'

out = inp.replace('.csv', '_stereo.csv')
spc_df = mecha.expand_species_stereo(inp, out=out, enant=True)
spc_df
# Out:
#   0%|          | 0/345 [00:00<?, ?it/s]
#              name  mult  charge  \
# 0              N2     1       0
# 1              Ar     1       0
# 2              He     1       0
# 3              Ne     1       0
# 4      C5H7O(1)rs     2       0
# ..            ...   ...     ...
# 342   C5H7O(212)e     2       0
# 343  C5H7O(447)r0     2       0
# 343  C5H7O(447)r1     2       0
# 344      S(469)r0     2       0
# 344      S(469)r1     2       0
#
#                                                    chi   orig_name  \
# 0                                      AMChI=1/N2/c1-2          N2
# 1                                           AMChI=1/Ar          Ar
# 2                                           AMChI=1/He          He
# 3                                           AMChI=1/Ne          Ne
# 4    AMChI=1/C5H7O/c1-4-2-3-5(1)6-4/h1,4-5H,2-3H2/t...    C5H7O(1)
# ..                                                 ...         ...
# 342     AMChI=1/C5H7O/c1-4-6-5(2)3/h1,4H,2H2,3H3/b4-1+  C5H7O(212)
# 343  AMChI=1/C5H7O/c1-2-6-5-3-4-5/h2-3,5H,1,4H2/t5-...  C5H7O(447)
# 343  AMChI=1/C5H7O/c1-2-6-5-3-4-5/h2-3,5H,1,4H2/t5-...  C5H7O(447)
# 344  AMChI=1/C5H7O3/c1-3-4-5(2-6)8-7/h3,5,7H,1,4H2/...      S(469)
# 344  AMChI=1/C5H7O3/c1-3-4-5(2-6)8-7/h3,5,7H,1,4H2/...      S(469)
#
#                                            orig_chi        orig_smi
# 0                                  InChI=1S/N2/c1-2             N#N
# 1                                       InChI=1S/Ar            [Ar]
# 2                                       InChI=1S/He            [He]
# 3                                       InChI=1S/Ne            [Ne]
# 4       InChI=1S/C5H7O/c1-2-5-3-4(1)6-5/h3-5H,1-2H2   O1C2CCC1[CH]2
# ..                                              ...             ...
# 342       InChI=1S/C5H7O/c1-4-6-5(2)3/h1,4H,2H2,3H3   CC(OC=[CH])=C
# 343     InChI=1S/C5H7O/c1-2-6-5-3-4-5/h2-3,5H,1,4H2    C=COC1C[CH]1
# 343     InChI=1S/C5H7O/c1-2-6-5-3-4-5/h2-3,5H,1,4H2    C=COC1C[CH]1
# 344  InChI=1S/C5H7O3/c1-2-3-5(4-6)8-7/h2,5,7H,1,3H2  OOC(CC=C)[C]=O
# 344  InChI=1S/C5H7O3/c1-2-3-5(4-6)8-7/h2,5,7H,1,3H2  OOC(CC=C)[C]=O
#
# [700 rows x 7 columns]
