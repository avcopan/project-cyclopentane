# %%
import mecha

# %%
inp = 'cyclopentene_reactions.csv'
spc_inp = 'cyclopentene_species_stereo.csv'
inp = '12epoxycyclopentane_reactions.csv'
spc_inp = '12epoxycyclopentane_species_stereo.csv'
inp = '13epoxyCPT_reactions.csv'
spc_inp = '13epoxyCPT_species_stereo.csv'

out = inp.replace('.csv', '_stereo.csv')
err_out = inp.replace('.csv', '_stereo_failed.csv')

rxn_df, err_df = mecha.expand_reaction_stereo(inp, spc_inp, out=out, err_out=err_out)
err_df
# Out:
#   0%|          | 0/696 [00:00<?, ?it/s]
#   0%|          | 0/696 [00:00<?, ?it/s]
#                          eq  \
# 24      C5H7O(1) = C5H7O(2)
# 25      C5H7O(1) = C5H7O(3)
# 27    C5H7O(10) = C5H7O(56)
# 36   C5H7O(123) = C5H7O(27)
# 37   C5H7O(123) = C5H7O(63)
# ..                      ...
# 664        S(574) = S(1285)
# 667        S(606) = S(1082)
# 674         S(630) = S(938)
# 690         S(938) = S(128)
# 691         S(938) = S(937)
#
#                                                    obj  \
# 24   (atoms:\n  0: {symbol: C, implicit_hydrogens: ...
# 25   (atoms:\n  0: {symbol: C, implicit_hydrogens: ...
# 27   (atoms:\n  0: {symbol: C, implicit_hydrogens: ...
# 36   (atoms:\n  0: {symbol: C, implicit_hydrogens: ...
# 37   (atoms:\n  0: {symbol: C, implicit_hydrogens: ...
# ..                                                 ...
# 664  (atoms:\n  0: {symbol: C, implicit_hydrogens: ...
# 667  (atoms:\n  0: {symbol: C, implicit_hydrogens: ...
# 674  (atoms:\n  0: {symbol: C, implicit_hydrogens: ...
# 690  (atoms:\n  0: {symbol: C, implicit_hydrogens: ...
# 691  (atoms:\n  0: {symbol: C, implicit_hydrogens: ...
#
#                                               orig_chi
# 24   AMChI=1/C5H7O/c1-4-2(7-1)3-5(1)6-4/h1-2,4-5H,3...
# 25   AMChI=1/C5H7O/c1-4(7-1)2-3-5(1)6-4/h1,5H,2-3H2...
# 27   AMChI=1/C5H7O/c1-2-3-4-5(2)6-3/h2-3,5H,1,4H2/k...
# 36   AMChI=1/C5H7O/c1-2-3(6-2)5-4-1/h1-3H,4-5H2/k3-...
# 37   AMChI=1/C5H7O/c1-2-3(6-1)5-4-2/h1-3H,4-5H2/k3-...
# ..                                                 ...
# 664  AMChI=1/C5H7O3/c7-8-4-1-2-5(6-2)3-4/h1-2,4-5,7...
# 667  AMChI=1/C5H7O3/c1-2-6-8-5(7-2)4-3-1/h1-2,5H,3-...
# 674  AMChI=1/C5H7O3/c7-8-5-3-1-2-4(5)6-2/h1-2,4-5,7...
# 690  AMChI=1/C5H7O3/c1-2-4(8-6-9-1)5-3(1)7-5/h1,3-5...
# 691  AMChI=1/C5H7O3/c6-8-4-2-1-3(9-1)5(4)7-3/h1,4-6...
#
# [74 rows x 3 columns]
